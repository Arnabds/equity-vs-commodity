# %% [markdown]
# ## Granger Causality Test

# %% [markdown]
# Companies that Granger Causes Apple’s close differencing will be implemented in VAR.

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from statsmodels.tsa.stattools import grangercausalitytests

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
#warnings.filterwarnings("ignore", category=ValueError)
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=ValueError)

# %% [markdown]
# ## Function that export p-values for Granger Causality Test

# %%
## https://www.machinelearningplus.com/time-series/granger-causality-test-in-python/
def grangers_causation_matrix(data, variables,test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=10, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(10)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            #opt_lag = 1 + np.argmin(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

# %% [markdown]
# ## Import stock data from Yahoo Finance

# %%
tickers = ['DNZOY','ALV','BAC','CADUSD=X','CL=F','F','FDX',
           'GM','JCI','JPM','TM',
           'TRYUSD=X','WFC','X','^DJI','^GSPC','^IXIC','ALI=F']


data = yf.download(tickers, period="5y")
df = data['Close'].diff().copy()
# Out:
# [*********************100%***********************]  18 of 18 completed

# %%
df
# Out:
# Ticker                     ALI=F       ALV       BAC  CADUSD=X      CL=F  \
# Date
# 2019-10-29 00:00:00+00:00    NaN       NaN       NaN       NaN       NaN
# 2019-10-30 00:00:00+00:00  15.25       NaN       NaN       NaN -0.480000
# 2019-10-31 00:00:00+00:00   2.75 -0.250000 -0.350000 -0.004434 -0.880001
# 2019-11-01 00:00:00+00:00  31.00  1.580002  0.529999 -0.000121  2.020000
# 2019-11-04 00:00:00+00:00  15.50  3.310005  0.600002  0.001589  0.340000
# ...                          ...       ...       ...       ...       ...
# 2024-10-24 00:00:00+00:00 -15.00 -1.459999  0.310001 -0.001072 -0.579994
# 2024-10-25 00:00:00+00:00  31.75 -0.300003 -0.760002 -0.000866  1.589996
# 2024-10-28 00:00:00+00:00 -38.50  2.340004  0.730000 -0.002197 -4.400002
# 2024-10-29 00:00:00+00:00  44.75 -1.060005 -0.090000  0.000300 -0.009995
# 2024-10-30 00:00:00+00:00    NaN       NaN       NaN -0.001164       NaN
#
# Ticker                        DNZOY         F       FDX        GM       JCI  \
# Date
# 2019-10-29 00:00:00+00:00       NaN       NaN       NaN       NaN       NaN
# 2019-10-30 00:00:00+00:00       NaN       NaN       NaN       NaN       NaN
# 2019-10-31 00:00:00+00:00  0.075000  0.050000 -3.179993 -0.750000  0.120003
# 2019-11-01 00:00:00+00:00 -0.195000  0.300000  3.860001  0.810001  0.489998
# 2019-11-04 00:00:00+00:00  0.005000  0.110000  8.319992  0.419998  0.639999
# ...                             ...       ...       ...       ...       ...
# 2024-10-24 00:00:00+00:00 -0.030000  0.179999  4.820007 -0.199997  0.379997
# 2024-10-25 00:00:00+00:00 -0.010000 -0.170000 -0.750000 -0.650002 -0.120003
# 2024-10-28 00:00:00+00:00  0.179999  0.300000  3.330017  0.660000  0.990005
# 2024-10-29 00:00:00+00:00  0.030001 -0.960000 -0.410004 -1.189999 -0.660004
# 2024-10-30 00:00:00+00:00       NaN       NaN       NaN       NaN       NaN
#
# Ticker                          JPM        TM  TRYUSD=X       WFC         X  \
# Date
# 2019-10-29 00:00:00+00:00       NaN       NaN       NaN       NaN       NaN
# 2019-10-30 00:00:00+00:00       NaN       NaN       NaN       NaN       NaN
# 2019-10-31 00:00:00+00:00 -0.810005 -0.470001  0.001522 -0.399998 -0.500000
# 2019-11-01 00:00:00+00:00  2.880005  1.279999 -0.000301  0.549999  1.700000
# 2019-11-04 00:00:00+00:00  1.020004  0.729996  0.000246  0.540001  0.090000
# ...                             ...       ...       ...       ...       ...
# 2024-10-24 00:00:00+00:00  1.569992 -0.900009 -0.000013  0.870003 -0.009998
# 2024-10-25 00:00:00+00:00 -2.669998  1.570007 -0.000016 -0.900002 -0.709999
# 2024-10-28 00:00:00+00:00  3.190002  4.630005  0.000004  1.080002 -0.360001
# 2024-10-29 00:00:00+00:00 -2.600006 -0.600006 -0.000004 -0.309998  1.029999
# 2024-10-30 00:00:00+00:00       NaN       NaN  0.000024       NaN       NaN
#
# Ticker                           ^DJI      ^GSPC       ^IXIC
# Date
# 2019-10-29 00:00:00+00:00         NaN        NaN         NaN
# 2019-10-30 00:00:00+00:00         NaN        NaN         NaN
# 2019-10-31 00:00:00+00:00 -140.458984  -9.209961  -11.620117
# 2019-11-01 00:00:00+00:00  301.128906  29.349854   94.040039
# 2019-11-04 00:00:00+00:00  114.750000  11.360107   46.799805
# ...                               ...        ...         ...
# 2024-10-24 00:00:00+00:00 -140.589844  12.439941  138.839844
# 2024-10-25 00:00:00+00:00 -259.960938  -1.739746  103.119141
# 2024-10-28 00:00:00+00:00  273.171875  15.399902   48.580078
# 2024-10-29 00:00:00+00:00 -154.519531   9.399902  145.558594
# 2024-10-30 00:00:00+00:00         NaN        NaN         NaN
#
# [1307 rows x 18 columns]

# %% [markdown]
# ## Apply Granger Causality test

# %%
ticker = ['DNZOY','ALV','BAC','CADUSD=X','CL=F','FDX',
           'GM','JCI','JPM','TM',
           'TRYUSD=X','WFC','X','^DJI','^GSPC','^IXIC','ALI=F']

GC_stock = []
optimal_lag = []

for t in ticker:
    df1 = df[['F', t]].copy()
    test_result = grangercausalitytests(df1.dropna(), maxlag=10)
    p_values = [round(test_result[i+1][0]['ssr_ftest'][1],4) for i in range(10)]
    min_p_value = np.min(p_values)
    if min_p_value < 0.05:
        GC_stock.append(t)
        optimal_lag.append(1 + np.argmin(p_values))
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5489  , p=0.4589  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.5502  , p=0.4582  , df=1
# likelihood ratio test: chi2=0.5501  , p=0.4583  , df=1
# parameter F test:         F=0.5489  , p=0.4589  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2853  , p=0.7518  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=0.5730  , p=0.7509  , df=2
# likelihood ratio test: chi2=0.5729  , p=0.7509  , df=2
# parameter F test:         F=0.2853  , p=0.7518  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9316  , p=0.4247  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=2.8110  , p=0.4217  , df=3
# likelihood ratio test: chi2=2.8077  , p=0.4222  , df=3
# parameter F test:         F=0.9316  , p=0.4247  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7264  , p=0.5739  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=2.9276  , p=0.5700  , df=4
# likelihood ratio test: chi2=2.9240  , p=0.5706  , df=4
# parameter F test:         F=0.7264  , p=0.5739  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5765  , p=0.7181  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=2.9089  , p=0.7140  , df=5
# likelihood ratio test: chi2=2.9054  , p=0.7146  , df=5
# parameter F test:         F=0.5765  , p=0.7181  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5636  , p=0.7596  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=3.4184  , p=0.7548  , df=6
# likelihood ratio test: chi2=3.4135  , p=0.7554  , df=6
# parameter F test:         F=0.5636  , p=0.7596  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4993  , p=0.8355  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=3.5389  , p=0.8311  , df=7
# likelihood ratio test: chi2=3.5337  , p=0.8316  , df=7
# parameter F test:         F=0.4993  , p=0.8355  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8115  , p=0.5924  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=6.5852  , p=0.5820  , df=8
# likelihood ratio test: chi2=6.5673  , p=0.5840  , df=8
# parameter F test:         F=0.8115  , p=0.5924  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7636  , p=0.6503  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=6.9833  , p=0.6389  , df=9
# likelihood ratio test: chi2=6.9631  , p=0.6410  , df=9
# parameter F test:         F=0.7636  , p=0.6503  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8578  , p=0.5728  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=8.7309  , p=0.5578  , df=10
# likelihood ratio test: chi2=8.6993  , p=0.5609  , df=10
# parameter F test:         F=0.8578  , p=0.5728  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3433  , p=0.5580  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.3442  , p=0.5574  , df=1
# likelihood ratio test: chi2=0.3441  , p=0.5575  , df=1
# parameter F test:         F=0.3433  , p=0.5580  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4832  , p=0.6169  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=0.9704  , p=0.6156  , df=2
# likelihood ratio test: chi2=0.9700  , p=0.6157  , df=2
# parameter F test:         F=0.4832  , p=0.6169  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4826  , p=0.6945  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=1.4561  , p=0.6924  , df=3
# likelihood ratio test: chi2=1.4552  , p=0.6926  , df=3
# parameter F test:         F=0.4826  , p=0.6945  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9561  , p=0.4307  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=3.8532  , p=0.4262  , df=4
# likelihood ratio test: chi2=3.8471  , p=0.4271  , df=4
# parameter F test:         F=0.9561  , p=0.4307  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8092  , p=0.5430  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=4.0835  , p=0.5375  , df=5
# likelihood ratio test: chi2=4.0766  , p=0.5384  , df=5
# parameter F test:         F=0.8092  , p=0.5430  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7265  , p=0.6283  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=4.4068  , p=0.6218  , df=6
# likelihood ratio test: chi2=4.3988  , p=0.6229  , df=6
# parameter F test:         F=0.7265  , p=0.6283  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6560  , p=0.7095  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=4.6498  , p=0.7026  , df=7
# likelihood ratio test: chi2=4.6408  , p=0.7037  , df=7
# parameter F test:         F=0.6560  , p=0.7095  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5555  , p=0.8147  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=4.5075  , p=0.8087  , df=8
# likelihood ratio test: chi2=4.4991  , p=0.8095  , df=8
# parameter F test:         F=0.5555  , p=0.8147  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6130  , p=0.7868  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=5.6053  , p=0.7787  , df=9
# likelihood ratio test: chi2=5.5923  , p=0.7799  , df=9
# parameter F test:         F=0.6130  , p=0.7868  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8612  , p=0.5695  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=8.7652  , p=0.5545  , df=10
# likelihood ratio test: chi2=8.7334  , p=0.5576  , df=10
# parameter F test:         F=0.8612  , p=0.5695  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8763  , p=0.3494  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.8785  , p=0.3486  , df=1
# likelihood ratio test: chi2=0.8782  , p=0.3487  , df=1
# parameter F test:         F=0.8763  , p=0.3494  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8766  , p=0.4165  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=1.7605  , p=0.4147  , df=2
# likelihood ratio test: chi2=1.7592  , p=0.4149  , df=2
# parameter F test:         F=0.8766  , p=0.4165  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6527  , p=0.5813  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=1.9694  , p=0.5788  , df=3
# likelihood ratio test: chi2=1.9678  , p=0.5791  , df=3
# parameter F test:         F=0.6527  , p=0.5813  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5517  , p=0.6978  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=2.2232  , p=0.6948  , df=4
# likelihood ratio test: chi2=2.2212  , p=0.6952  , df=4
# parameter F test:         F=0.5517  , p=0.6978  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0004  , p=0.4162  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=5.0480  , p=0.4101  , df=5
# likelihood ratio test: chi2=5.0374  , p=0.4113  , df=5
# parameter F test:         F=1.0004  , p=0.4162  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8619  , p=0.5224  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=5.2276  , p=0.5150  , df=6
# likelihood ratio test: chi2=5.2163  , p=0.5164  , df=6
# parameter F test:         F=0.8619  , p=0.5224  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.9756  , p=0.4474  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=6.9156  , p=0.4377  , df=7
# likelihood ratio test: chi2=6.8958  , p=0.4398  , df=7
# parameter F test:         F=0.9756  , p=0.4474  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8323  , p=0.5741  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=6.7537  , p=0.5634  , df=8
# likelihood ratio test: chi2=6.7348  , p=0.5655  , df=8
# parameter F test:         F=0.8323  , p=0.5741  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0276  , p=0.4155  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=9.3967  , p=0.4015  , df=9
# likelihood ratio test: chi2=9.3601  , p=0.4047  , df=9
# parameter F test:         F=1.0276  , p=0.4155  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2630  , p=0.2466  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=12.8548 , p=0.2319  , df=10
# likelihood ratio test: chi2=12.7865 , p=0.2359  , df=10
# parameter F test:         F=1.2630  , p=0.2466  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=7.6405  , p=0.0058  , df_denom=1204, df_num=1
# ssr based chi2 test:   chi2=7.6596  , p=0.0056  , df=1
# likelihood ratio test: chi2=7.6354  , p=0.0057  , df=1
# parameter F test:         F=7.6405  , p=0.0058  , df_denom=1204, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.6201  , p=0.0100  , df_denom=1201, df_num=2
# ssr based chi2 test:   chi2=9.2787  , p=0.0097  , df=2
# likelihood ratio test: chi2=9.2432  , p=0.0098  , df=2
# parameter F test:         F=4.6201  , p=0.0100  , df_denom=1201, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.3107  , p=0.0195  , df_denom=1198, df_num=3
# ssr based chi2 test:   chi2=9.9902  , p=0.0186  , df=3
# likelihood ratio test: chi2=9.9490  , p=0.0190  , df=3
# parameter F test:         F=3.3107  , p=0.0195  , df_denom=1198, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.6125  , p=0.0340  , df_denom=1195, df_num=4
# ssr based chi2 test:   chi2=10.5287 , p=0.0324  , df=4
# likelihood ratio test: chi2=10.4829 , p=0.0330  , df=4
# parameter F test:         F=2.6125  , p=0.0340  , df_denom=1195, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.0979  , p=0.0088  , df_denom=1192, df_num=5
# ssr based chi2 test:   chi2=15.6324 , p=0.0080  , df=5
# likelihood ratio test: chi2=15.5317 , p=0.0083  , df=5
# parameter F test:         F=3.0979  , p=0.0088  , df_denom=1192, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.2008  , p=0.0040  , df_denom=1189, df_num=6
# ssr based chi2 test:   chi2=19.4149 , p=0.0035  , df=6
# likelihood ratio test: chi2=19.2598 , p=0.0037  , df=6
# parameter F test:         F=3.2008  , p=0.0040  , df_denom=1189, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.7539  , p=0.0077  , df_denom=1186, df_num=7
# ssr based chi2 test:   chi2=19.5210 , p=0.0067  , df=7
# likelihood ratio test: chi2=19.3641 , p=0.0071  , df=7
# parameter F test:         F=2.7539  , p=0.0077  , df_denom=1186, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.7845  , p=0.0047  , df_denom=1183, df_num=8
# ssr based chi2 test:   chi2=22.5965 , p=0.0039  , df=8
# likelihood ratio test: chi2=22.3864 , p=0.0042  , df=8
# parameter F test:         F=2.7845  , p=0.0047  , df_denom=1183, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.4860  , p=0.0082  , df_denom=1180, df_num=9
# ssr based chi2 test:   chi2=22.7342 , p=0.0068  , df=9
# likelihood ratio test: chi2=22.5213 , p=0.0074  , df=9
# parameter F test:         F=2.4860  , p=0.0082  , df_denom=1180, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.7239  , p=0.0026  , df_denom=1177, df_num=10
# ssr based chi2 test:   chi2=27.7250 , p=0.0020  , df=10
# likelihood ratio test: chi2=27.4090 , p=0.0022  , df=10
# parameter F test:         F=2.7239  , p=0.0026  , df_denom=1177, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0451  , p=0.8319  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.0452  , p=0.8317  , df=1
# likelihood ratio test: chi2=0.0452  , p=0.8317  , df=1
# parameter F test:         F=0.0451  , p=0.8319  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3149  , p=0.7299  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=0.6324  , p=0.7289  , df=2
# likelihood ratio test: chi2=0.6322  , p=0.7290  , df=2
# parameter F test:         F=0.3149  , p=0.7299  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.2572  , p=0.8562  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=0.7760  , p=0.8552  , df=3
# likelihood ratio test: chi2=0.7758  , p=0.8553  , df=3
# parameter F test:         F=0.2572  , p=0.8562  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2171  , p=0.9290  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=0.8748  , p=0.9282  , df=4
# likelihood ratio test: chi2=0.8745  , p=0.9282  , df=4
# parameter F test:         F=0.2171  , p=0.9290  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.2077  , p=0.9593  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=1.0479  , p=0.9586  , df=5
# likelihood ratio test: chi2=1.0474  , p=0.9587  , df=5
# parameter F test:         F=0.2077  , p=0.9593  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4066  , p=0.8750  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=2.4662  , p=0.8722  , df=6
# likelihood ratio test: chi2=2.4637  , p=0.8725  , df=6
# parameter F test:         F=0.4066  , p=0.8750  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4354  , p=0.8803  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=3.0865  , p=0.8769  , df=7
# likelihood ratio test: chi2=3.0825  , p=0.8773  , df=7
# parameter F test:         F=0.4354  , p=0.8803  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.4301  , p=0.9034  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=3.4905  , p=0.8999  , df=8
# likelihood ratio test: chi2=3.4854  , p=0.9003  , df=8
# parameter F test:         F=0.4301  , p=0.9034  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.3675  , p=0.9506  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=3.3605  , p=0.9483  , df=9
# likelihood ratio test: chi2=3.3559  , p=0.9485  , df=9
# parameter F test:         F=0.3675  , p=0.9506  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.3910  , p=0.9510  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=3.9800  , p=0.9482  , df=10
# likelihood ratio test: chi2=3.9734  , p=0.9485  , df=10
# parameter F test:         F=0.3910  , p=0.9510  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0498  , p=0.8234  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.0500  , p=0.8231  , df=1
# likelihood ratio test: chi2=0.0500  , p=0.8231  , df=1
# parameter F test:         F=0.0498  , p=0.8234  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5019  , p=0.6055  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=1.0080  , p=0.6041  , df=2
# likelihood ratio test: chi2=1.0075  , p=0.6043  , df=2
# parameter F test:         F=0.5019  , p=0.6055  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3689  , p=0.7755  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=1.1131  , p=0.7739  , df=3
# likelihood ratio test: chi2=1.1126  , p=0.7740  , df=3
# parameter F test:         F=0.3689  , p=0.7755  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3211  , p=0.8639  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=1.2942  , p=0.8624  , df=4
# likelihood ratio test: chi2=1.2935  , p=0.8625  , df=4
# parameter F test:         F=0.3211  , p=0.8639  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.3998  , p=0.8492  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=2.0174  , p=0.8467  , df=5
# likelihood ratio test: chi2=2.0157  , p=0.8470  , df=5
# parameter F test:         F=0.3998  , p=0.8492  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4461  , p=0.8480  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=2.7061  , p=0.8447  , df=6
# likelihood ratio test: chi2=2.7031  , p=0.8451  , df=6
# parameter F test:         F=0.4461  , p=0.8480  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.7976  , p=0.5893  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=5.6539  , p=0.5807  , df=7
# likelihood ratio test: chi2=5.6406  , p=0.5823  , df=7
# parameter F test:         F=0.7976  , p=0.5893  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7267  , p=0.6680  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=5.8971  , p=0.6588  , df=8
# likelihood ratio test: chi2=5.8827  , p=0.6604  , df=8
# parameter F test:         F=0.7267  , p=0.6680  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9598  , p=0.4719  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=8.7775  , p=0.4581  , df=9
# likelihood ratio test: chi2=8.7455  , p=0.4611  , df=9
# parameter F test:         F=0.9598  , p=0.4719  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3018  , p=0.2242  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=13.2499 , p=0.2100  , df=10
# likelihood ratio test: chi2=13.1773 , p=0.2139  , df=10
# parameter F test:         F=1.3018  , p=0.2242  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.5325  , p=0.2160  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=1.5363  , p=0.2152  , df=1
# likelihood ratio test: chi2=1.5353  , p=0.2153  , df=1
# parameter F test:         F=1.5325  , p=0.2160  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.3936  , p=0.0339  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=6.8154  , p=0.0331  , df=2
# likelihood ratio test: chi2=6.7962  , p=0.0334  , df=2
# parameter F test:         F=3.3936  , p=0.0339  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.4104  , p=0.0654  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=7.2733  , p=0.0637  , df=3
# likelihood ratio test: chi2=7.2515  , p=0.0643  , df=3
# parameter F test:         F=2.4104  , p=0.0654  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.3440  , p=0.0530  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=9.4465  , p=0.0509  , df=4
# likelihood ratio test: chi2=9.4097  , p=0.0516  , df=4
# parameter F test:         F=2.3440  , p=0.0530  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.8956  , p=0.0923  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=9.5656  , p=0.0885  , df=5
# likelihood ratio test: chi2=9.5278  , p=0.0898  , df=5
# parameter F test:         F=1.8956  , p=0.0923  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5734  , p=0.1513  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=9.5437  , p=0.1452  , df=6
# likelihood ratio test: chi2=9.5061  , p=0.1471  , df=6
# parameter F test:         F=1.5734  , p=0.1513  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4488  , p=0.1819  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=10.2695 , p=0.1738  , df=7
# likelihood ratio test: chi2=10.2259 , p=0.1761  , df=7
# parameter F test:         F=1.4488  , p=0.1819  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2920  , p=0.2434  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=10.4846 , p=0.2326  , df=8
# likelihood ratio test: chi2=10.4391 , p=0.2355  , df=8
# parameter F test:         F=1.2920  , p=0.2434  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.1243  , p=0.3420  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=10.2811 , p=0.3282  , df=9
# likelihood ratio test: chi2=10.2373 , p=0.3316  , df=9
# parameter F test:         F=1.1243  , p=0.3420  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9871  , p=0.4526  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=10.0470 , p=0.4364  , df=10
# likelihood ratio test: chi2=10.0052 , p=0.4400  , df=10
# parameter F test:         F=0.9871  , p=0.4526  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.1070  , p=0.2930  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=1.1097  , p=0.2921  , df=1
# likelihood ratio test: chi2=1.1092  , p=0.2923  , df=1
# parameter F test:         F=1.1070  , p=0.2930  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.7509  , p=0.0643  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=5.5246  , p=0.0631  , df=2
# likelihood ratio test: chi2=5.5120  , p=0.0635  , df=2
# parameter F test:         F=2.7509  , p=0.0643  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.1240  , p=0.0954  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=6.4093  , p=0.0933  , df=3
# likelihood ratio test: chi2=6.3923  , p=0.0940  , df=3
# parameter F test:         F=2.1240  , p=0.0954  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.9223  , p=0.1044  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=7.7471  , p=0.1013  , df=4
# likelihood ratio test: chi2=7.7223  , p=0.1023  , df=4
# parameter F test:         F=1.9223  , p=0.1044  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.9769  , p=0.0794  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=9.9758  , p=0.0759  , df=5
# likelihood ratio test: chi2=9.9347  , p=0.0771  , df=5
# parameter F test:         F=1.9769  , p=0.0794  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.2753  , p=0.0345  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=13.8009 , p=0.0319  , df=6
# likelihood ratio test: chi2=13.7224 , p=0.0329  , df=6
# parameter F test:         F=2.2753  , p=0.0345  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.2181  , p=0.0306  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=15.7226 , p=0.0278  , df=7
# likelihood ratio test: chi2=15.6207 , p=0.0288  , df=7
# parameter F test:         F=2.2181  , p=0.0306  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.1932  , p=0.0257  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=17.7971 , p=0.0228  , df=8
# likelihood ratio test: chi2=17.6666 , p=0.0239  , df=8
# parameter F test:         F=2.1932  , p=0.0257  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.0891  , p=0.0278  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=19.1039 , p=0.0243  , df=9
# likelihood ratio test: chi2=18.9535 , p=0.0256  , df=9
# parameter F test:         F=2.0891  , p=0.0278  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.9659  , p=0.0337  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=20.0089 , p=0.0292  , df=10
# likelihood ratio test: chi2=19.8440 , p=0.0308  , df=10
# parameter F test:         F=1.9659  , p=0.0337  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.8787  , p=0.1707  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=1.8834  , p=0.1699  , df=1
# likelihood ratio test: chi2=1.8819  , p=0.1701  , df=1
# parameter F test:         F=1.8787  , p=0.1707  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.6343  , p=0.0722  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=5.2904  , p=0.0710  , df=2
# likelihood ratio test: chi2=5.2789  , p=0.0714  , df=2
# parameter F test:         F=2.6343  , p=0.0722  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.8168  , p=0.1423  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=5.4822  , p=0.1397  , df=3
# likelihood ratio test: chi2=5.4698  , p=0.1405  , df=3
# parameter F test:         F=1.8168  , p=0.1423  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3513  , p=0.2489  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=5.4460  , p=0.2445  , df=4
# likelihood ratio test: chi2=5.4337  , p=0.2456  , df=4
# parameter F test:         F=1.3513  , p=0.2489  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.8351  , p=0.1032  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=9.2602  , p=0.0991  , df=5
# likelihood ratio test: chi2=9.2248  , p=0.1004  , df=5
# parameter F test:         F=1.8351  , p=0.1032  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.6993  , p=0.1177  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=10.3071 , p=0.1123  , df=6
# likelihood ratio test: chi2=10.2633 , p=0.1140  , df=6
# parameter F test:         F=1.6993  , p=0.1177  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4743  , p=0.1724  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=10.4501 , p=0.1645  , df=7
# likelihood ratio test: chi2=10.4050 , p=0.1668  , df=7
# parameter F test:         F=1.4743  , p=0.1724  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2759  , p=0.2520  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=10.3540 , p=0.2411  , df=8
# likelihood ratio test: chi2=10.3097 , p=0.2440  , df=8
# parameter F test:         F=1.2759  , p=0.2520  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2004  , p=0.2906  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=10.9773 , p=0.2773  , df=9
# likelihood ratio test: chi2=10.9275 , p=0.2807  , df=9
# parameter F test:         F=1.2004  , p=0.2906  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1057  , p=0.3542  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=11.2535 , p=0.3381  , df=10
# likelihood ratio test: chi2=11.2010 , p=0.3421  , df=10
# parameter F test:         F=1.1057  , p=0.3542  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.5688  , p=0.0328  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=4.5802  , p=0.0323  , df=1
# likelihood ratio test: chi2=4.5716  , p=0.0325  , df=1
# parameter F test:         F=4.5688  , p=0.0328  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.9412  , p=0.0532  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=5.9069  , p=0.0522  , df=2
# likelihood ratio test: chi2=5.8925  , p=0.0525  , df=2
# parameter F test:         F=2.9412  , p=0.0532  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.0921  , p=0.0995  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=6.3130  , p=0.0973  , df=3
# likelihood ratio test: chi2=6.2965  , p=0.0980  , df=3
# parameter F test:         F=2.0921  , p=0.0995  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.1728  , p=0.0700  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=8.7564  , p=0.0675  , df=4
# likelihood ratio test: chi2=8.7248  , p=0.0684  , df=4
# parameter F test:         F=2.1728  , p=0.0700  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.8134  , p=0.1073  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=9.1507  , p=0.1032  , df=5
# likelihood ratio test: chi2=9.1161  , p=0.1045  , df=5
# parameter F test:         F=1.8134  , p=0.1073  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.6526  , p=0.1293  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=10.0239 , p=0.1236  , df=6
# likelihood ratio test: chi2=9.9824  , p=0.1254  , df=6
# parameter F test:         F=1.6526  , p=0.1293  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.5303  , p=0.1529  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=10.8474 , p=0.1454  , df=7
# likelihood ratio test: chi2=10.7988 , p=0.1476  , df=7
# parameter F test:         F=1.5303  , p=0.1529  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3385  , p=0.2201  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=10.8612 , p=0.2097  , df=8
# likelihood ratio test: chi2=10.8125 , p=0.2126  , df=8
# parameter F test:         F=1.3385  , p=0.2201  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2797  , p=0.2433  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=11.7027 , p=0.2306  , df=9
# likelihood ratio test: chi2=11.6460 , p=0.2340  , df=9
# parameter F test:         F=1.2797  , p=0.2433  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1760  , p=0.3027  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=11.9695 , p=0.2871  , df=10
# likelihood ratio test: chi2=11.9102 , p=0.2911  , df=10
# parameter F test:         F=1.1760  , p=0.3027  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.3038  , p=0.2538  , df_denom=1204, df_num=1
# ssr based chi2 test:   chi2=1.3070  , p=0.2529  , df=1
# likelihood ratio test: chi2=1.3063  , p=0.2531  , df=1
# parameter F test:         F=1.3038  , p=0.2538  , df_denom=1204, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.0064  , p=0.1349  , df_denom=1201, df_num=2
# ssr based chi2 test:   chi2=4.0294  , p=0.1334  , df=2
# likelihood ratio test: chi2=4.0227  , p=0.1338  , df=2
# parameter F test:         F=2.0064  , p=0.1349  , df_denom=1201, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.8514  , p=0.0093  , df_denom=1198, df_num=3
# ssr based chi2 test:   chi2=11.6216 , p=0.0088  , df=3
# likelihood ratio test: chi2=11.5659 , p=0.0090  , df=3
# parameter F test:         F=3.8514  , p=0.0093  , df_denom=1198, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.1446  , p=0.0024  , df_denom=1195, df_num=4
# ssr based chi2 test:   chi2=16.7033 , p=0.0022  , df=4
# likelihood ratio test: chi2=16.5885 , p=0.0023  , df=4
# parameter F test:         F=4.1446  , p=0.0024  , df_denom=1195, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.5422  , p=0.0035  , df_denom=1192, df_num=5
# ssr based chi2 test:   chi2=17.8744 , p=0.0031  , df=5
# likelihood ratio test: chi2=17.7429 , p=0.0033  , df=5
# parameter F test:         F=3.5422  , p=0.0035  , df_denom=1192, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.5983  , p=0.0015  , df_denom=1189, df_num=6
# ssr based chi2 test:   chi2=21.8262 , p=0.0013  , df=6
# likelihood ratio test: chi2=21.6304 , p=0.0014  , df=6
# parameter F test:         F=3.5983  , p=0.0015  , df_denom=1189, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=3.6017  , p=0.0008  , df_denom=1186, df_num=7
# ssr based chi2 test:   chi2=25.5306 , p=0.0006  , df=7
# likelihood ratio test: chi2=25.2630 , p=0.0007  , df=7
# parameter F test:         F=3.6017  , p=0.0008  , df_denom=1186, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.9323  , p=0.0001  , df_denom=1183, df_num=8
# ssr based chi2 test:   chi2=31.9104 , p=0.0001  , df=8
# likelihood ratio test: chi2=31.4935 , p=0.0001  , df=8
# parameter F test:         F=3.9323  , p=0.0001  , df_denom=1183, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=4.4989  , p=0.0000  , df_denom=1180, df_num=9
# ssr based chi2 test:   chi2=41.1424 , p=0.0000  , df=9
# likelihood ratio test: chi2=40.4523 , p=0.0000  , df=9
# parameter F test:         F=4.4989  , p=0.0000  , df_denom=1180, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=4.0129  , p=0.0000  , df_denom=1177, df_num=10
# ssr based chi2 test:   chi2=40.8454 , p=0.0000  , df=10
# likelihood ratio test: chi2=40.1645 , p=0.0000  , df=10
# parameter F test:         F=4.0129  , p=0.0000  , df_denom=1177, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0228  , p=0.8801  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.0228  , p=0.8799  , df=1
# likelihood ratio test: chi2=0.0228  , p=0.8799  , df=1
# parameter F test:         F=0.0228  , p=0.8801  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4445  , p=0.6413  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=0.8927  , p=0.6400  , df=2
# likelihood ratio test: chi2=0.8923  , p=0.6401  , df=2
# parameter F test:         F=0.4445  , p=0.6413  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3185  , p=0.8120  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=0.9611  , p=0.8107  , df=3
# likelihood ratio test: chi2=0.9608  , p=0.8107  , df=3
# parameter F test:         F=0.3185  , p=0.8120  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2621  , p=0.9023  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=1.0562  , p=0.9012  , df=4
# likelihood ratio test: chi2=1.0558  , p=0.9012  , df=4
# parameter F test:         F=0.2621  , p=0.9023  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6853  , p=0.6346  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=3.4583  , p=0.6297  , df=5
# likelihood ratio test: chi2=3.4533  , p=0.6305  , df=5
# parameter F test:         F=0.6853  , p=0.6346  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5974  , p=0.7326  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=3.6235  , p=0.7275  , df=6
# likelihood ratio test: chi2=3.6180  , p=0.7282  , df=6
# parameter F test:         F=0.5974  , p=0.7326  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.9064  , p=0.5005  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=6.4251  , p=0.4911  , df=7
# likelihood ratio test: chi2=6.4080  , p=0.4930  , df=7
# parameter F test:         F=0.9064  , p=0.5005  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7918  , p=0.6099  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=6.4251  , p=0.5997  , df=8
# likelihood ratio test: chi2=6.4080  , p=0.6016  , df=8
# parameter F test:         F=0.7918  , p=0.6099  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0849  , p=0.3708  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=9.9215  , p=0.3569  , df=9
# likelihood ratio test: chi2=9.8807  , p=0.3602  , df=9
# parameter F test:         F=1.0849  , p=0.3708  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9865  , p=0.4531  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=10.0408 , p=0.4369  , df=10
# likelihood ratio test: chi2=9.9990  , p=0.4406  , df=10
# parameter F test:         F=0.9865  , p=0.4531  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.7867  , p=0.1816  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=1.7912  , p=0.1808  , df=1
# likelihood ratio test: chi2=1.7898  , p=0.1809  , df=1
# parameter F test:         F=1.7867  , p=0.1816  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3947  , p=0.2483  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=2.8010  , p=0.2465  , df=2
# likelihood ratio test: chi2=2.7977  , p=0.2469  , df=2
# parameter F test:         F=1.3947  , p=0.2483  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0320  , p=0.3774  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=3.1142  , p=0.3744  , df=3
# likelihood ratio test: chi2=3.1102  , p=0.3749  , df=3
# parameter F test:         F=1.0320  , p=0.3774  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7830  , p=0.5362  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=3.1555  , p=0.5322  , df=4
# likelihood ratio test: chi2=3.1514  , p=0.5328  , df=4
# parameter F test:         F=0.7830  , p=0.5362  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6182  , p=0.6860  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=3.1195  , p=0.6816  , df=5
# likelihood ratio test: chi2=3.1154  , p=0.6822  , df=5
# parameter F test:         F=0.6182  , p=0.6860  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5147  , p=0.7976  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=3.1219  , p=0.7934  , df=6
# likelihood ratio test: chi2=3.1178  , p=0.7939  , df=6
# parameter F test:         F=0.5147  , p=0.7976  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4433  , p=0.8751  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=3.1421  , p=0.8715  , df=7
# likelihood ratio test: chi2=3.1380  , p=0.8719  , df=7
# parameter F test:         F=0.4433  , p=0.8751  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5381  , p=0.8283  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=4.3665  , p=0.8226  , df=8
# likelihood ratio test: chi2=4.3586  , p=0.8234  , df=8
# parameter F test:         F=0.5381  , p=0.8283  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5344  , p=0.8502  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=4.8867  , p=0.8441  , df=9
# likelihood ratio test: chi2=4.8767  , p=0.8449  , df=9
# parameter F test:         F=0.5344  , p=0.8502  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.4910  , p=0.8967  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=4.9974  , p=0.8914  , df=10
# likelihood ratio test: chi2=4.9870  , p=0.8920  , df=10
# parameter F test:         F=0.4910  , p=0.8967  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.8856  , p=0.3469  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.8878  , p=0.3461  , df=1
# likelihood ratio test: chi2=0.8875  , p=0.3462  , df=1
# parameter F test:         F=0.8856  , p=0.3469  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9249  , p=0.3969  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=1.8574  , p=0.3951  , df=2
# likelihood ratio test: chi2=1.8560  , p=0.3953  , df=2
# parameter F test:         F=0.9249  , p=0.3969  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8718  , p=0.4551  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=2.6307  , p=0.4521  , df=3
# likelihood ratio test: chi2=2.6278  , p=0.4526  , df=3
# parameter F test:         F=0.8718  , p=0.4551  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6379  , p=0.6355  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=2.5709  , p=0.6320  , df=4
# likelihood ratio test: chi2=2.5681  , p=0.6325  , df=4
# parameter F test:         F=0.6379  , p=0.6355  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7770  , p=0.5663  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=3.9210  , p=0.5608  , df=5
# likelihood ratio test: chi2=3.9146  , p=0.5618  , df=5
# parameter F test:         F=0.7770  , p=0.5663  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0525  , p=0.3895  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=6.3842  , p=0.3816  , df=6
# likelihood ratio test: chi2=6.3673  , p=0.3833  , df=6
# parameter F test:         F=1.0525  , p=0.3895  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8970  , p=0.5079  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=6.3586  , p=0.4986  , df=7
# likelihood ratio test: chi2=6.3418  , p=0.5005  , df=7
# parameter F test:         F=0.8970  , p=0.5079  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8025  , p=0.6004  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=6.5122  , p=0.5900  , df=8
# likelihood ratio test: chi2=6.4947  , p=0.5920  , df=8
# parameter F test:         F=0.8025  , p=0.6004  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0494  , p=0.3981  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=9.5964  , p=0.3841  , df=9
# likelihood ratio test: chi2=9.5583  , p=0.3874  , df=9
# parameter F test:         F=1.0494  , p=0.3981  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1876  , p=0.2947  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=12.0880 , p=0.2792  , df=10
# likelihood ratio test: chi2=12.0276 , p=0.2832  , df=10
# parameter F test:         F=1.1876  , p=0.2947  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.8858  , p=0.1699  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=1.8905  , p=0.1691  , df=1
# likelihood ratio test: chi2=1.8891  , p=0.1693  , df=1
# parameter F test:         F=1.8858  , p=0.1699  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2175  , p=0.2963  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=2.4451  , p=0.2945  , df=2
# likelihood ratio test: chi2=2.4426  , p=0.2948  , df=2
# parameter F test:         F=1.2175  , p=0.2963  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1435  , p=0.3304  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=3.4505  , p=0.3272  , df=3
# likelihood ratio test: chi2=3.4456  , p=0.3279  , df=3
# parameter F test:         F=1.1435  , p=0.3304  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8845  , p=0.4725  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=3.5646  , p=0.4681  , df=4
# likelihood ratio test: chi2=3.5593  , p=0.4689  , df=4
# parameter F test:         F=0.8845  , p=0.4725  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7582  , p=0.5801  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=3.8260  , p=0.5747  , df=5
# likelihood ratio test: chi2=3.8200  , p=0.5756  , df=5
# parameter F test:         F=0.7582  , p=0.5801  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6563  , p=0.6851  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=3.9810  , p=0.6793  , df=6
# likelihood ratio test: chi2=3.9744  , p=0.6801  , df=6
# parameter F test:         F=0.6563  , p=0.6851  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6768  , p=0.6919  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=4.7971  , p=0.6847  , df=7
# likelihood ratio test: chi2=4.7876  , p=0.6859  , df=7
# parameter F test:         F=0.6768  , p=0.6919  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5704  , p=0.8028  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=4.6284  , p=0.7965  , df=8
# likelihood ratio test: chi2=4.6195  , p=0.7974  , df=8
# parameter F test:         F=0.5704  , p=0.8028  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9584  , p=0.4731  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=8.7643  , p=0.4593  , df=9
# likelihood ratio test: chi2=8.7324  , p=0.4623  , df=9
# parameter F test:         F=0.9584  , p=0.4731  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3413  , p=0.2031  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=13.6517 , p=0.1895  , df=10
# likelihood ratio test: chi2=13.5746 , p=0.1933  , df=10
# parameter F test:         F=1.3413  , p=0.2031  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.1170  , p=0.0427  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=4.1273  , p=0.0422  , df=1
# likelihood ratio test: chi2=4.1202  , p=0.0424  , df=1
# parameter F test:         F=4.1170  , p=0.0427  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.2761  , p=0.1031  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=4.5711  , p=0.1017  , df=2
# likelihood ratio test: chi2=4.5624  , p=0.1022  , df=2
# parameter F test:         F=2.2761  , p=0.1031  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6935  , p=0.1666  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=5.1103  , p=0.1639  , df=3
# likelihood ratio test: chi2=5.0995  , p=0.1647  , df=3
# parameter F test:         F=1.6935  , p=0.1666  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3758  , p=0.2401  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=5.5447  , p=0.2358  , df=4
# likelihood ratio test: chi2=5.5320  , p=0.2369  , df=4
# parameter F test:         F=1.3758  , p=0.2401  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1867  , p=0.3134  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=5.9883  , p=0.3074  , df=5
# likelihood ratio test: chi2=5.9735  , p=0.3088  , df=5
# parameter F test:         F=1.1867  , p=0.3134  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9491  , p=0.4587  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=5.7568  , p=0.4510  , df=6
# likelihood ratio test: chi2=5.7431  , p=0.4526  , df=6
# parameter F test:         F=0.9491  , p=0.4587  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2006  , p=0.2993  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=8.5100  , p=0.2898  , df=7
# likelihood ratio test: chi2=8.4800  , p=0.2922  , df=7
# parameter F test:         F=1.2006  , p=0.2993  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.0465  , p=0.3987  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=8.4924  , p=0.3869  , df=8
# likelihood ratio test: chi2=8.4625  , p=0.3896  , df=8
# parameter F test:         F=1.0465  , p=0.3987  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.4320  , p=0.1692  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=13.0955 , p=0.1583  , df=9
# likelihood ratio test: chi2=13.0246 , p=0.1615  , df=9
# parameter F test:         F=1.4320  , p=0.1692  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.9367  , p=0.0369  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=19.7117 , p=0.0321  , df=10
# likelihood ratio test: chi2=19.5515 , p=0.0338  , df=10
# parameter F test:         F=1.9367  , p=0.0369  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.7446  , p=0.1868  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=1.7489  , p=0.1860  , df=1
# likelihood ratio test: chi2=1.7477  , p=0.1862  , df=1
# parameter F test:         F=1.7446  , p=0.1868  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2853  , p=0.2770  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=2.5812  , p=0.2751  , df=2
# likelihood ratio test: chi2=2.5785  , p=0.2755  , df=2
# parameter F test:         F=1.2853  , p=0.2770  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1150  , p=0.3419  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=3.3645  , p=0.3388  , df=3
# likelihood ratio test: chi2=3.3598  , p=0.3394  , df=3
# parameter F test:         F=1.1150  , p=0.3419  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3324  , p=0.2558  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=5.3698  , p=0.2514  , df=4
# likelihood ratio test: chi2=5.3579  , p=0.2525  , df=4
# parameter F test:         F=1.3324  , p=0.2558  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.3322  , p=0.2479  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=6.7226  , p=0.2421  , df=5
# likelihood ratio test: chi2=6.7039  , p=0.2436  , df=5
# parameter F test:         F=1.3322  , p=0.2479  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5169  , p=0.1690  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=9.2007  , p=0.1626  , df=6
# likelihood ratio test: chi2=9.1657  , p=0.1645  , df=6
# parameter F test:         F=1.5169  , p=0.1690  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.7564  , p=0.0924  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=12.4498 , p=0.0867  , df=7
# likelihood ratio test: chi2=12.3859 , p=0.0886  , df=7
# parameter F test:         F=1.7564  , p=0.0924  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.5536  , p=0.1344  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=12.6072 , p=0.1261  , df=8
# likelihood ratio test: chi2=12.5416 , p=0.1286  , df=8
# parameter F test:         F=1.5536  , p=0.1344  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.4172  , p=0.1755  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=12.9602 , p=0.1644  , df=9
# likelihood ratio test: chi2=12.8908 , p=0.1676  , df=9
# parameter F test:         F=1.4172  , p=0.1755  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3734  , p=0.1871  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=13.9790 , p=0.1740  , df=10
# likelihood ratio test: chi2=13.8982 , p=0.1777  , df=10
# parameter F test:         F=1.3734  , p=0.1871  , df_denom=1179, df_num=10

# %%
GC_stock
# Out:
# ['CADUSD=X', 'GM', 'JCI', 'TM', 'TRYUSD=X', '^IXIC']

# %%
optimal_lag
# Out:
# [10, 2, 8, 1, 9, 10]
