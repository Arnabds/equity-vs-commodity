# %% [markdown]
# ## Granger Causality Test

# %% [markdown]
# Companies that Granger Causes Apple’s close differencing will be implemented in VAR.

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from statsmodels.tsa.stattools import grangercausalitytests

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
#warnings.filterwarnings("ignore", category=ValueError)
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=ValueError)

# %% [markdown]
# ## Function that export p-values for Granger Causality Test

# %%
## https://www.machinelearningplus.com/time-series/granger-causality-test-in-python/
def grangers_causation_matrix(data, variables,test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=10, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(10)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            #opt_lag = 1 + np.argmin(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

# %% [markdown]
# ## Import stock data from Yahoo Finance

# %%
tickers = ['DNZOY','ALV','ASEKY','BAC','CADUSD=X','CHFUSD=X','CL=F','F','FDX','GBPUSD=X','GBPUSD=X','GM','JCI','JPM','TM',
         'TRYUSD=X','WFC','X','^DJI','^GSPC','^IXIC','ALI=F']

data = yf.download(tickers, period="5y")
df = data['Close'].diff().copy()
# Out:
# [*********************100%***********************]  21 of 21 completed

# %%
df
# Out:
# Ticker                     ALI=F       ALV     ASEKY       BAC  CADUSD=X  \
# Date
# 2019-10-25 00:00:00+00:00    NaN       NaN       NaN       NaN       NaN
# 2019-10-28 00:00:00+00:00  10.50 -0.589996  0.000000  0.120001  0.000445
# 2019-10-29 00:00:00+00:00  -6.00 -1.770004  0.430333  0.230000  0.000434
# 2019-10-30 00:00:00+00:00  15.25 -1.620003  0.000000 -0.449999 -0.001955
# 2019-10-31 00:00:00+00:00   2.75 -0.250000  1.369667 -0.350000 -0.004434
# ...                          ...       ...       ...       ...       ...
# 2024-10-21 00:00:00+00:00 -24.75 -2.719994  0.030000 -0.560001 -0.000205
# 2024-10-22 00:00:00+00:00  33.00  0.599998  0.000000  0.540001 -0.001776
# 2024-10-23 00:00:00+00:00  37.75 -0.900002  0.200000  0.040001  0.000905
# 2024-10-24 00:00:00+00:00 -15.00 -1.459999  0.000000  0.310001 -0.001072
# 2024-10-25 00:00:00+00:00  60.75 -0.309998       NaN -0.780003 -0.003100
#
# Ticker                     CHFUSD=X      CL=F     DNZOY         F       FDX  \
# Date
# 2019-10-25 00:00:00+00:00       NaN       NaN       NaN       NaN       NaN
# 2019-10-28 00:00:00+00:00 -0.001875 -0.849998 -0.040000 -0.110001  0.309998
# 2019-10-29 00:00:00+00:00 -0.000566 -0.270000  0.129999  0.030001 -0.389999
# 2019-10-30 00:00:00+00:00  0.000647 -0.480000  0.030001 -0.100000 -2.169998
# 2019-10-31 00:00:00+00:00  0.005095 -0.880001  0.075000  0.050000 -3.179993
# ...                             ...       ...       ...       ...       ...
# 2024-10-21 00:00:00+00:00  0.001335  1.339996 -0.160000 -0.220000 -5.589996
# 2024-10-22 00:00:00+00:00 -0.000641  1.529999 -0.099999  0.230000  0.980011
# 2024-10-23 00:00:00+00:00 -0.000160 -1.320000  0.160000 -0.049999 -1.740021
# 2024-10-24 00:00:00+00:00 -0.001613 -0.579994 -0.030000  0.179999  4.820007
# 2024-10-25 00:00:00+00:00  0.000373  1.479996  0.020000 -0.179999 -0.635010
#
# Ticker                     ...        GM       JCI       JPM        TM  \
# Date                       ...
# 2019-10-25 00:00:00+00:00  ...       NaN       NaN       NaN       NaN
# 2019-10-28 00:00:00+00:00  ... -0.100002  0.109997  0.480003  0.059998
# 2019-10-29 00:00:00+00:00  ...  1.570000  0.690002 -0.080002  0.339996
# 2019-10-30 00:00:00+00:00  ... -0.299999 -0.150002 -0.699997  0.340012
# 2019-10-31 00:00:00+00:00  ... -0.750000  0.120003 -0.810005 -0.470001
# ...                        ...       ...       ...       ...       ...
# 2024-10-21 00:00:00+00:00  ... -0.250000 -0.270004 -2.369995 -2.360001
# 2024-10-22 00:00:00+00:00  ...  4.799999 -0.529999  1.119995  0.759995
# 2024-10-23 00:00:00+00:00  ... -0.810001 -0.159996 -0.709991  1.400009
# 2024-10-24 00:00:00+00:00  ... -0.199997  0.379997  1.569992 -0.900009
# 2024-10-25 00:00:00+00:00  ... -0.755001 -0.129997 -2.669998  1.450012
#
# Ticker                     TRYUSD=X       WFC         X        ^DJI  \
# Date
# 2019-10-25 00:00:00+00:00       NaN       NaN       NaN         NaN
# 2019-10-28 00:00:00+00:00 -0.000177  0.080002  0.600000  132.660156
# 2019-10-29 00:00:00+00:00  0.001306  0.519997 -0.090000  -19.259766
# 2019-10-30 00:00:00+00:00 -0.000671 -0.139999 -0.210000  115.228516
# 2019-10-31 00:00:00+00:00  0.001522 -0.399998 -0.500000 -140.458984
# ...                             ...       ...       ...         ...
# 2024-10-21 00:00:00+00:00 -0.000072 -0.340004  1.099998 -344.308594
# 2024-10-22 00:00:00+00:00  0.000026  0.790001  0.000000   -6.710938
# 2024-10-23 00:00:00+00:00 -0.000006 -0.250000  0.590000 -409.941406
# 2024-10-24 00:00:00+00:00 -0.000013  0.870003 -0.009998 -140.589844
# 2024-10-25 00:00:00+00:00 -0.000004 -0.940102 -0.735001 -262.320312
#
# Ticker                         ^GSPC       ^IXIC
# Date
# 2019-10-25 00:00:00+00:00        NaN         NaN
# 2019-10-28 00:00:00+00:00  16.869873   82.870117
# 2019-10-29 00:00:00+00:00  -2.530029  -49.140625
# 2019-10-30 00:00:00+00:00   9.880127   27.130859
# 2019-10-31 00:00:00+00:00  -9.209961  -11.620117
# ...                              ...         ...
# 2024-10-21 00:00:00+00:00 -10.689941   50.458984
# 2024-10-22 00:00:00+00:00  -2.779785   39.759766
# 2024-10-23 00:00:00+00:00 -53.780273 -303.119141
# 2024-10-24 00:00:00+00:00  12.439941  138.839844
# 2024-10-25 00:00:00+00:00  -2.719727  100.789062
#
# [1306 rows x 21 columns]

# %% [markdown]
# ## Apply Granger Causality test

# %%
ticker = ['ALV','ASEKY','BAC','CADUSD=X','CHFUSD=X','CL=F','F','FDX','GBPUSD=X','GBPUSD=X','GM','JCI','JPM','TM',
         'TRYUSD=X','WFC','X','^DJI','^GSPC','^IXIC','ALI=F']

GC_stock = []
optimal_lag = []

for t in ticker:
    df1 = df[['DNZOY', t]].copy()
    test_result = grangercausalitytests(df1.dropna(), maxlag=10)
    p_values = [round(test_result[i+1][0]['ssr_ftest'][1],4) for i in range(10)]
    min_p_value = np.min(p_values)
    if min_p_value < 0.05:
        GC_stock.append(t)
        optimal_lag.append(1 + np.argmin(p_values))
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.2335  , p=0.0042  , df_denom=1207, df_num=1
# ssr based chi2 test:   chi2=8.2539  , p=0.0041  , df=1
# likelihood ratio test: chi2=8.2259  , p=0.0041  , df=1
# parameter F test:         F=8.2335  , p=0.0042  , df_denom=1207, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=6.2947  , p=0.0019  , df_denom=1204, df_num=2
# ssr based chi2 test:   chi2=12.6416 , p=0.0018  , df=2
# likelihood ratio test: chi2=12.5760 , p=0.0019  , df=2
# parameter F test:         F=6.2947  , p=0.0019  , df_denom=1204, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.2724  , p=0.0052  , df_denom=1201, df_num=3
# ssr based chi2 test:   chi2=12.8920 , p=0.0049  , df=3
# likelihood ratio test: chi2=12.8236 , p=0.0050  , df=3
# parameter F test:         F=4.2724  , p=0.0052  , df_denom=1201, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.3280  , p=0.0101  , df_denom=1198, df_num=4
# ssr based chi2 test:   chi2=13.4121 , p=0.0094  , df=4
# likelihood ratio test: chi2=13.3381 , p=0.0097  , df=4
# parameter F test:         F=3.3280  , p=0.0101  , df_denom=1198, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.0845  , p=0.0090  , df_denom=1195, df_num=5
# ssr based chi2 test:   chi2=15.5645 , p=0.0082  , df=5
# likelihood ratio test: chi2=15.4650 , p=0.0085  , df=5
# parameter F test:         F=3.0845  , p=0.0090  , df_denom=1195, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.6940  , p=0.0133  , df_denom=1192, df_num=6
# ssr based chi2 test:   chi2=16.3403 , p=0.0120  , df=6
# likelihood ratio test: chi2=16.2305 , p=0.0126  , df=6
# parameter F test:         F=2.6940  , p=0.0133  , df_denom=1192, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.3117  , p=0.0242  , df_denom=1189, df_num=7
# ssr based chi2 test:   chi2=16.3859 , p=0.0218  , df=7
# likelihood ratio test: chi2=16.2754 , p=0.0227  , df=7
# parameter F test:         F=2.3117  , p=0.0242  , df_denom=1189, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.1271  , p=0.0308  , df_denom=1186, df_num=8
# ssr based chi2 test:   chi2=17.2605 , p=0.0275  , df=8
# likelihood ratio test: chi2=17.1379 , p=0.0287  , df=8
# parameter F test:         F=2.1271  , p=0.0308  , df_denom=1186, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.5817  , p=0.0060  , df_denom=1183, df_num=9
# ssr based chi2 test:   chi2=23.6081 , p=0.0050  , df=9
# likelihood ratio test: chi2=23.3793 , p=0.0054  , df=9
# parameter F test:         F=2.5817  , p=0.0060  , df_denom=1183, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.4376  , p=0.0071  , df_denom=1180, df_num=10
# ssr based chi2 test:   chi2=24.8094 , p=0.0057  , df=10
# likelihood ratio test: chi2=24.5566 , p=0.0063  , df=10
# parameter F test:         F=2.4376  , p=0.0071  , df_denom=1180, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4559  , p=0.4997  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.4571  , p=0.4990  , df=1
# likelihood ratio test: chi2=0.4570  , p=0.4990  , df=1
# parameter F test:         F=0.4559  , p=0.4997  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2262  , p=0.7976  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=0.4542  , p=0.7968  , df=2
# likelihood ratio test: chi2=0.4541  , p=0.7969  , df=2
# parameter F test:         F=0.2262  , p=0.7976  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1912  , p=0.9024  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=0.5771  , p=0.9017  , df=3
# likelihood ratio test: chi2=0.5769  , p=0.9017  , df=3
# parameter F test:         F=0.1912  , p=0.9024  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3789  , p=0.8238  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=1.5270  , p=0.8219  , df=4
# likelihood ratio test: chi2=1.5260  , p=0.8220  , df=4
# parameter F test:         F=0.3789  , p=0.8238  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9716  , p=0.4339  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=4.9027  , p=0.4279  , df=5
# likelihood ratio test: chi2=4.8927  , p=0.4291  , df=5
# parameter F test:         F=0.9716  , p=0.4339  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7859  , p=0.5810  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=4.7669  , p=0.5740  , df=6
# likelihood ratio test: chi2=4.7575  , p=0.5753  , df=6
# parameter F test:         F=0.7859  , p=0.5810  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.7669  , p=0.6152  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=5.4361  , p=0.6069  , df=7
# likelihood ratio test: chi2=5.4239  , p=0.6084  , df=7
# parameter F test:         F=0.7669  , p=0.6152  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6620  , p=0.7254  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=5.3717  , p=0.7172  , df=8
# likelihood ratio test: chi2=5.3598  , p=0.7185  , df=8
# parameter F test:         F=0.6620  , p=0.7254  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6411  , p=0.7624  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=5.8625  , p=0.7536  , df=9
# likelihood ratio test: chi2=5.8482  , p=0.7550  , df=9
# parameter F test:         F=0.6411  , p=0.7624  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.6145  , p=0.8025  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=6.2548  , p=0.7934  , df=10
# likelihood ratio test: chi2=6.2386  , p=0.7948  , df=10
# parameter F test:         F=0.6145  , p=0.8025  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.5744  , p=0.0589  , df_denom=1207, df_num=1
# ssr based chi2 test:   chi2=3.5833  , p=0.0584  , df=1
# likelihood ratio test: chi2=3.5780  , p=0.0586  , df=1
# parameter F test:         F=3.5744  , p=0.0589  , df_denom=1207, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.2502  , p=0.1058  , df_denom=1204, df_num=2
# ssr based chi2 test:   chi2=4.5191  , p=0.1044  , df=2
# likelihood ratio test: chi2=4.5107  , p=0.1048  , df=2
# parameter F test:         F=2.2502  , p=0.1058  , df_denom=1204, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.5915  , p=0.1897  , df_denom=1201, df_num=3
# ssr based chi2 test:   chi2=4.8024  , p=0.1868  , df=3
# likelihood ratio test: chi2=4.7929  , p=0.1876  , df=3
# parameter F test:         F=1.5915  , p=0.1897  , df_denom=1201, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3836  , p=0.2374  , df_denom=1198, df_num=4
# ssr based chi2 test:   chi2=5.5762  , p=0.2331  , df=4
# likelihood ratio test: chi2=5.5633  , p=0.2342  , df=4
# parameter F test:         F=1.3836  , p=0.2374  , df_denom=1198, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.8631  , p=0.0980  , df_denom=1195, df_num=5
# ssr based chi2 test:   chi2=9.4015  , p=0.0941  , df=5
# likelihood ratio test: chi2=9.3650  , p=0.0954  , df=5
# parameter F test:         F=1.8631  , p=0.0980  , df_denom=1195, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.8536  , p=0.0857  , df_denom=1192, df_num=6
# ssr based chi2 test:   chi2=11.2429 , p=0.0812  , df=6
# likelihood ratio test: chi2=11.1908 , p=0.0827  , df=6
# parameter F test:         F=1.8536  , p=0.0857  , df_denom=1192, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.5399  , p=0.1498  , df_denom=1189, df_num=7
# ssr based chi2 test:   chi2=10.9152 , p=0.1424  , df=7
# likelihood ratio test: chi2=10.8660 , p=0.1446  , df=7
# parameter F test:         F=1.5399  , p=0.1498  , df_denom=1189, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3978  , p=0.1929  , df_denom=1186, df_num=8
# ssr based chi2 test:   chi2=11.3429 , p=0.1830  , df=8
# likelihood ratio test: chi2=11.2897 , p=0.1858  , df=8
# parameter F test:         F=1.3978  , p=0.1929  , df_denom=1186, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.3100  , p=0.2268  , df_denom=1183, df_num=9
# ssr based chi2 test:   chi2=11.9795 , p=0.2145  , df=9
# likelihood ratio test: chi2=11.9202 , p=0.2178  , df=9
# parameter F test:         F=1.3100  , p=0.2268  , df_denom=1183, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1694  , p=0.3074  , df_denom=1180, df_num=10
# ssr based chi2 test:   chi2=11.9016 , p=0.2917  , df=10
# likelihood ratio test: chi2=11.8430 , p=0.2957  , df=10
# parameter F test:         F=1.1694  , p=0.3074  , df_denom=1180, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.5553  , p=0.1102  , df_denom=1205, df_num=1
# ssr based chi2 test:   chi2=2.5617  , p=0.1095  , df=1
# likelihood ratio test: chi2=2.5590  , p=0.1097  , df=1
# parameter F test:         F=2.5553  , p=0.1102  , df_denom=1205, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.7312  , p=0.0655  , df_denom=1202, df_num=2
# ssr based chi2 test:   chi2=5.4851  , p=0.0644  , df=2
# likelihood ratio test: chi2=5.4727  , p=0.0648  , df=2
# parameter F test:         F=2.7312  , p=0.0655  , df_denom=1202, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.0893  , p=0.0999  , df_denom=1199, df_num=3
# ssr based chi2 test:   chi2=6.3045  , p=0.0977  , df=3
# likelihood ratio test: chi2=6.2880  , p=0.0984  , df=3
# parameter F test:         F=2.0893  , p=0.0999  , df_denom=1199, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.1034  , p=0.0783  , df_denom=1196, df_num=4
# ssr based chi2 test:   chi2=8.4769  , p=0.0756  , df=4
# likelihood ratio test: chi2=8.4472  , p=0.0765  , df=4
# parameter F test:         F=2.1034  , p=0.0783  , df_denom=1196, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.6343  , p=0.1479  , df_denom=1193, df_num=5
# ssr based chi2 test:   chi2=8.2471  , p=0.1431  , df=5
# likelihood ratio test: chi2=8.2190  , p=0.1446  , df=5
# parameter F test:         F=1.6343  , p=0.1479  , df_denom=1193, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4713  , p=0.1845  , df_denom=1190, df_num=6
# ssr based chi2 test:   chi2=8.9243  , p=0.1779  , df=6
# likelihood ratio test: chi2=8.8914  , p=0.1798  , df=6
# parameter F test:         F=1.4713  , p=0.1845  , df_denom=1190, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1703  , p=0.3169  , df_denom=1187, df_num=7
# ssr based chi2 test:   chi2=8.2960  , p=0.3072  , df=7
# likelihood ratio test: chi2=8.2675  , p=0.3096  , df=7
# parameter F test:         F=1.1703  , p=0.3169  , df_denom=1187, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1338  , p=0.3373  , df_denom=1184, df_num=8
# ssr based chi2 test:   chi2=9.2010  , p=0.3256  , df=8
# likelihood ratio test: chi2=9.1659  , p=0.3285  , df=8
# parameter F test:         F=1.1338  , p=0.3373  , df_denom=1184, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9789  , p=0.4557  , df_denom=1181, df_num=9
# ssr based chi2 test:   chi2=8.9515  , p=0.4418  , df=9
# likelihood ratio test: chi2=8.9183  , p=0.4449  , df=9
# parameter F test:         F=0.9789  , p=0.4557  , df_denom=1181, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9426  , p=0.4927  , df_denom=1178, df_num=10
# ssr based chi2 test:   chi2=9.5945  , p=0.4768  , df=10
# likelihood ratio test: chi2=9.5563  , p=0.4802  , df=10
# parameter F test:         F=0.9426  , p=0.4927  , df_denom=1178, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1514  , p=0.6973  , df_denom=1205, df_num=1
# ssr based chi2 test:   chi2=0.1518  , p=0.6968  , df=1
# likelihood ratio test: chi2=0.1518  , p=0.6969  , df=1
# parameter F test:         F=0.1514  , p=0.6973  , df_denom=1205, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5489  , p=0.2129  , df_denom=1202, df_num=2
# ssr based chi2 test:   chi2=3.1107  , p=0.2111  , df=2
# likelihood ratio test: chi2=3.1067  , p=0.2115  , df=2
# parameter F test:         F=1.5489  , p=0.2129  , df_denom=1202, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3088  , p=0.2701  , df_denom=1199, df_num=3
# ssr based chi2 test:   chi2=3.9493  , p=0.2670  , df=3
# likelihood ratio test: chi2=3.9428  , p=0.2677  , df=3
# parameter F test:         F=1.3088  , p=0.2701  , df_denom=1199, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.4850  , p=0.2044  , df_denom=1196, df_num=4
# ssr based chi2 test:   chi2=5.9848  , p=0.2003  , df=4
# likelihood ratio test: chi2=5.9700  , p=0.2014  , df=4
# parameter F test:         F=1.4850  , p=0.2044  , df_denom=1196, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2483  , p=0.2842  , df_denom=1193, df_num=5
# ssr based chi2 test:   chi2=6.2991  , p=0.2782  , df=5
# likelihood ratio test: chi2=6.2827  , p=0.2797  , df=5
# parameter F test:         F=1.2483  , p=0.2842  , df_denom=1193, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0110  , p=0.4164  , df_denom=1190, df_num=6
# ssr based chi2 test:   chi2=6.1321  , p=0.4086  , df=6
# likelihood ratio test: chi2=6.1165  , p=0.4103  , df=6
# parameter F test:         F=1.0110  , p=0.4164  , df_denom=1190, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8975  , p=0.5076  , df_denom=1187, df_num=7
# ssr based chi2 test:   chi2=6.3619  , p=0.4982  , df=7
# likelihood ratio test: chi2=6.3452  , p=0.5001  , df=7
# parameter F test:         F=0.8975  , p=0.5076  , df_denom=1187, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8345  , p=0.5721  , df_denom=1184, df_num=8
# ssr based chi2 test:   chi2=6.7721  , p=0.5614  , df=8
# likelihood ratio test: chi2=6.7531  , p=0.5635  , df=8
# parameter F test:         F=0.8345  , p=0.5721  , df_denom=1184, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7904  , p=0.6253  , df_denom=1181, df_num=9
# ssr based chi2 test:   chi2=7.2280  , p=0.6134  , df=9
# likelihood ratio test: chi2=7.2063  , p=0.6156  , df=9
# parameter F test:         F=0.7904  , p=0.6253  , df_denom=1181, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.7787  , p=0.6496  , df_denom=1178, df_num=10
# ssr based chi2 test:   chi2=7.9256  , p=0.6361  , df=10
# likelihood ratio test: chi2=7.8995  , p=0.6387  , df=10
# parameter F test:         F=0.7787  , p=0.6496  , df_denom=1178, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0038  , p=0.9509  , df_denom=1207, df_num=1
# ssr based chi2 test:   chi2=0.0038  , p=0.9508  , df=1
# likelihood ratio test: chi2=0.0038  , p=0.9508  , df=1
# parameter F test:         F=0.0038  , p=0.9509  , df_denom=1207, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1114  , p=0.8946  , df_denom=1204, df_num=2
# ssr based chi2 test:   chi2=0.2237  , p=0.8942  , df=2
# likelihood ratio test: chi2=0.2237  , p=0.8942  , df=2
# parameter F test:         F=0.1114  , p=0.8946  , df_denom=1204, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7743  , p=0.5084  , df_denom=1201, df_num=3
# ssr based chi2 test:   chi2=2.3364  , p=0.5056  , df=3
# likelihood ratio test: chi2=2.3341  , p=0.5060  , df=3
# parameter F test:         F=0.7743  , p=0.5084  , df_denom=1201, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8069  , p=0.5207  , df_denom=1198, df_num=4
# ssr based chi2 test:   chi2=3.2520  , p=0.5166  , df=4
# likelihood ratio test: chi2=3.2476  , p=0.5173  , df=4
# parameter F test:         F=0.8069  , p=0.5207  , df_denom=1198, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6461  , p=0.6646  , df_denom=1195, df_num=5
# ssr based chi2 test:   chi2=3.2601  , p=0.6600  , df=5
# likelihood ratio test: chi2=3.2557  , p=0.6606  , df=5
# parameter F test:         F=0.6461  , p=0.6646  , df_denom=1195, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6731  , p=0.6714  , df_denom=1192, df_num=6
# ssr based chi2 test:   chi2=4.0828  , p=0.6655  , df=6
# likelihood ratio test: chi2=4.0759  , p=0.6664  , df=6
# parameter F test:         F=0.6731  , p=0.6714  , df_denom=1192, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5580  , p=0.7903  , df_denom=1189, df_num=7
# ssr based chi2 test:   chi2=3.9553  , p=0.7849  , df=7
# likelihood ratio test: chi2=3.9488  , p=0.7857  , df=7
# parameter F test:         F=0.5580  , p=0.7903  , df_denom=1189, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8502  , p=0.5584  , df_denom=1186, df_num=8
# ssr based chi2 test:   chi2=6.8991  , p=0.5476  , df=8
# likelihood ratio test: chi2=6.8794  , p=0.5497  , df=8
# parameter F test:         F=0.8502  , p=0.5584  , df_denom=1186, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9112  , p=0.5144  , df_denom=1183, df_num=9
# ssr based chi2 test:   chi2=8.3327  , p=0.5010  , df=9
# likelihood ratio test: chi2=8.3039  , p=0.5038  , df=9
# parameter F test:         F=0.9112  , p=0.5144  , df_denom=1183, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9230  , p=0.5108  , df_denom=1180, df_num=10
# ssr based chi2 test:   chi2=9.3946  , p=0.4951  , df=10
# likelihood ratio test: chi2=9.3580  , p=0.4985  , df=10
# parameter F test:         F=0.9230  , p=0.5108  , df_denom=1180, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.8242  , p=0.0160  , df_denom=1207, df_num=1
# ssr based chi2 test:   chi2=5.8387  , p=0.0157  , df=1
# likelihood ratio test: chi2=5.8246  , p=0.0158  , df=1
# parameter F test:         F=5.8242  , p=0.0160  , df_denom=1207, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.7473  , p=0.0239  , df_denom=1204, df_num=2
# ssr based chi2 test:   chi2=7.5258  , p=0.0232  , df=2
# likelihood ratio test: chi2=7.5025  , p=0.0235  , df=2
# parameter F test:         F=3.7473  , p=0.0239  , df_denom=1204, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.6784  , p=0.0458  , df_denom=1201, df_num=3
# ssr based chi2 test:   chi2=8.0821  , p=0.0443  , df=3
# likelihood ratio test: chi2=8.0552  , p=0.0449  , df=3
# parameter F test:         F=2.6784  , p=0.0458  , df_denom=1201, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.2115  , p=0.0657  , df_denom=1198, df_num=4
# ssr based chi2 test:   chi2=8.9125  , p=0.0633  , df=4
# likelihood ratio test: chi2=8.8797  , p=0.0642  , df=4
# parameter F test:         F=2.2115  , p=0.0657  , df_denom=1198, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.3503  , p=0.0052  , df_denom=1195, df_num=5
# ssr based chi2 test:   chi2=16.9056 , p=0.0047  , df=5
# likelihood ratio test: chi2=16.7882 , p=0.0049  , df=5
# parameter F test:         F=3.3503  , p=0.0052  , df_denom=1195, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.8645  , p=0.0089  , df_denom=1192, df_num=6
# ssr based chi2 test:   chi2=17.3743 , p=0.0080  , df=6
# likelihood ratio test: chi2=17.2502 , p=0.0084  , df=6
# parameter F test:         F=2.8645  , p=0.0089  , df_denom=1192, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.4280  , p=0.0180  , df_denom=1189, df_num=7
# ssr based chi2 test:   chi2=17.2102 , p=0.0161  , df=7
# likelihood ratio test: chi2=17.0884 , p=0.0168  , df=7
# parameter F test:         F=2.4280  , p=0.0180  , df_denom=1189, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.4570  , p=0.0122  , df_denom=1186, df_num=8
# ssr based chi2 test:   chi2=19.9374 , p=0.0106  , df=8
# likelihood ratio test: chi2=19.7740 , p=0.0112  , df=8
# parameter F test:         F=2.4570  , p=0.0122  , df_denom=1186, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.4434  , p=0.0094  , df_denom=1183, df_num=9
# ssr based chi2 test:   chi2=22.3438 , p=0.0079  , df=9
# likelihood ratio test: chi2=22.1387 , p=0.0084  , df=9
# parameter F test:         F=2.4434  , p=0.0094  , df_denom=1183, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.2102  , p=0.0152  , df_denom=1180, df_num=10
# ssr based chi2 test:   chi2=22.4956 , p=0.0128  , df=10
# likelihood ratio test: chi2=22.2875 , p=0.0137  , df=10
# parameter F test:         F=2.2102  , p=0.0152  , df_denom=1180, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0034  , p=0.9535  , df_denom=1207, df_num=1
# ssr based chi2 test:   chi2=0.0034  , p=0.9535  , df=1
# likelihood ratio test: chi2=0.0034  , p=0.9535  , df=1
# parameter F test:         F=0.0034  , p=0.9535  , df_denom=1207, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5513  , p=0.5763  , df_denom=1204, df_num=2
# ssr based chi2 test:   chi2=1.1073  , p=0.5749  , df=2
# likelihood ratio test: chi2=1.1068  , p=0.5750  , df=2
# parameter F test:         F=0.5513  , p=0.5763  , df_denom=1204, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4559  , p=0.7132  , df_denom=1201, df_num=3
# ssr based chi2 test:   chi2=1.3757  , p=0.7113  , df=3
# likelihood ratio test: chi2=1.3749  , p=0.7114  , df=3
# parameter F test:         F=0.4559  , p=0.7132  , df_denom=1201, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3797  , p=0.8232  , df_denom=1198, df_num=4
# ssr based chi2 test:   chi2=1.5304  , p=0.8212  , df=4
# likelihood ratio test: chi2=1.5294  , p=0.8214  , df=4
# parameter F test:         F=0.3797  , p=0.8232  , df_denom=1198, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4434  , p=0.8183  , df_denom=1195, df_num=5
# ssr based chi2 test:   chi2=2.2373  , p=0.8154  , df=5
# likelihood ratio test: chi2=2.2352  , p=0.8157  , df=5
# parameter F test:         F=0.4434  , p=0.8183  , df_denom=1195, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3606  , p=0.9039  , df_denom=1192, df_num=6
# ssr based chi2 test:   chi2=2.1874  , p=0.9017  , df=6
# likelihood ratio test: chi2=2.1854  , p=0.9019  , df=6
# parameter F test:         F=0.3606  , p=0.9039  , df_denom=1192, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4660  , p=0.8595  , df_denom=1189, df_num=7
# ssr based chi2 test:   chi2=3.3032  , p=0.8556  , df=7
# likelihood ratio test: chi2=3.2987  , p=0.8561  , df=7
# parameter F test:         F=0.4660  , p=0.8595  , df_denom=1189, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5879  , p=0.7885  , df_denom=1186, df_num=8
# ssr based chi2 test:   chi2=4.7710  , p=0.7817  , df=8
# likelihood ratio test: chi2=4.7616  , p=0.7827  , df=8
# parameter F test:         F=0.5879  , p=0.7885  , df_denom=1186, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7237  , p=0.6875  , df_denom=1183, df_num=9
# ssr based chi2 test:   chi2=6.6178  , p=0.6768  , df=9
# likelihood ratio test: chi2=6.5996  , p=0.6787  , df=9
# parameter F test:         F=0.7237  , p=0.6875  , df_denom=1183, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9735  , p=0.4647  , df_denom=1180, df_num=10
# ssr based chi2 test:   chi2=9.9078  , p=0.4486  , df=10
# likelihood ratio test: chi2=9.8671  , p=0.4522  , df=10
# parameter F test:         F=0.9735  , p=0.4647  , df_denom=1180, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2269  , p=0.6339  , df_denom=1205, df_num=1
# ssr based chi2 test:   chi2=0.2275  , p=0.6334  , df=1
# likelihood ratio test: chi2=0.2274  , p=0.6334  , df=1
# parameter F test:         F=0.2269  , p=0.6339  , df_denom=1205, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2257  , p=0.7980  , df_denom=1202, df_num=2
# ssr based chi2 test:   chi2=0.4533  , p=0.7972  , df=2
# likelihood ratio test: chi2=0.4532  , p=0.7972  , df=2
# parameter F test:         F=0.2257  , p=0.7980  , df_denom=1202, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1893  , p=0.9037  , df_denom=1199, df_num=3
# ssr based chi2 test:   chi2=0.5711  , p=0.9030  , df=3
# likelihood ratio test: chi2=0.5710  , p=0.9030  , df=3
# parameter F test:         F=0.1893  , p=0.9037  , df_denom=1199, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2404  , p=0.9155  , df_denom=1196, df_num=4
# ssr based chi2 test:   chi2=0.9687  , p=0.9145  , df=4
# likelihood ratio test: chi2=0.9684  , p=0.9146  , df=4
# parameter F test:         F=0.2404  , p=0.9155  , df_denom=1196, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.2583  , p=0.9357  , df_denom=1193, df_num=5
# ssr based chi2 test:   chi2=1.3034  , p=0.9346  , df=5
# likelihood ratio test: chi2=1.3027  , p=0.9346  , df=5
# parameter F test:         F=0.2583  , p=0.9357  , df_denom=1193, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6709  , p=0.6732  , df_denom=1190, df_num=6
# ssr based chi2 test:   chi2=4.0696  , p=0.6673  , df=6
# likelihood ratio test: chi2=4.0628  , p=0.6682  , df=6
# parameter F test:         F=0.6709  , p=0.6732  , df_denom=1190, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5457  , p=0.8000  , df_denom=1187, df_num=7
# ssr based chi2 test:   chi2=3.8684  , p=0.7948  , df=7
# likelihood ratio test: chi2=3.8622  , p=0.7955  , df=7
# parameter F test:         F=0.5457  , p=0.8000  , df_denom=1187, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5562  , p=0.8142  , df_denom=1184, df_num=8
# ssr based chi2 test:   chi2=4.5133  , p=0.8081  , df=8
# likelihood ratio test: chi2=4.5048  , p=0.8090  , df=8
# parameter F test:         F=0.5562  , p=0.8142  , df_denom=1184, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.4449  , p=0.9108  , df_denom=1181, df_num=9
# ssr based chi2 test:   chi2=4.0689  , p=0.9068  , df=9
# likelihood ratio test: chi2=4.0620  , p=0.9073  , df=9
# parameter F test:         F=0.4449  , p=0.9108  , df_denom=1181, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.4883  , p=0.8985  , df_denom=1178, df_num=10
# ssr based chi2 test:   chi2=4.9698  , p=0.8932  , df=10
# likelihood ratio test: chi2=4.9596  , p=0.8939  , df=10
# parameter F test:         F=0.4883  , p=0.8985  , df_denom=1178, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2269  , p=0.6339  , df_denom=1205, df_num=1
# ssr based chi2 test:   chi2=0.2275  , p=0.6334  , df=1
# likelihood ratio test: chi2=0.2274  , p=0.6334  , df=1
# parameter F test:         F=0.2269  , p=0.6339  , df_denom=1205, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2257  , p=0.7980  , df_denom=1202, df_num=2
# ssr based chi2 test:   chi2=0.4533  , p=0.7972  , df=2
# likelihood ratio test: chi2=0.4532  , p=0.7972  , df=2
# parameter F test:         F=0.2257  , p=0.7980  , df_denom=1202, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1893  , p=0.9037  , df_denom=1199, df_num=3
# ssr based chi2 test:   chi2=0.5711  , p=0.9030  , df=3
# likelihood ratio test: chi2=0.5710  , p=0.9030  , df=3
# parameter F test:         F=0.1893  , p=0.9037  , df_denom=1199, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2404  , p=0.9155  , df_denom=1196, df_num=4
# ssr based chi2 test:   chi2=0.9687  , p=0.9145  , df=4
# likelihood ratio test: chi2=0.9684  , p=0.9146  , df=4
# parameter F test:         F=0.2404  , p=0.9155  , df_denom=1196, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.2583  , p=0.9357  , df_denom=1193, df_num=5
# ssr based chi2 test:   chi2=1.3034  , p=0.9346  , df=5
# likelihood ratio test: chi2=1.3027  , p=0.9346  , df=5
# parameter F test:         F=0.2583  , p=0.9357  , df_denom=1193, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6709  , p=0.6732  , df_denom=1190, df_num=6
# ssr based chi2 test:   chi2=4.0696  , p=0.6673  , df=6
# likelihood ratio test: chi2=4.0628  , p=0.6682  , df=6
# parameter F test:         F=0.6709  , p=0.6732  , df_denom=1190, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5457  , p=0.8000  , df_denom=1187, df_num=7
# ssr based chi2 test:   chi2=3.8684  , p=0.7948  , df=7
# likelihood ratio test: chi2=3.8622  , p=0.7955  , df=7
# parameter F test:         F=0.5457  , p=0.8000  , df_denom=1187, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5562  , p=0.8142  , df_denom=1184, df_num=8
# ssr based chi2 test:   chi2=4.5133  , p=0.8081  , df=8
# likelihood ratio test: chi2=4.5048  , p=0.8090  , df=8
# parameter F test:         F=0.5562  , p=0.8142  , df_denom=1184, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.4449  , p=0.9108  , df_denom=1181, df_num=9
# ssr based chi2 test:   chi2=4.0689  , p=0.9068  , df=9
# likelihood ratio test: chi2=4.0620  , p=0.9073  , df=9
# parameter F test:         F=0.4449  , p=0.9108  , df_denom=1181, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.4883  , p=0.8985  , df_denom=1178, df_num=10
# ssr based chi2 test:   chi2=4.9698  , p=0.8932  , df=10
# likelihood ratio test: chi2=4.9596  , p=0.8939  , df=10
# parameter F test:         F=0.4883  , p=0.8985  , df_denom=1178, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=9.3304  , p=0.0023  , df_denom=1207, df_num=1
# ssr based chi2 test:   chi2=9.3536  , p=0.0022  , df=1
# likelihood ratio test: chi2=9.3176  , p=0.0023  , df=1
# parameter F test:         F=9.3304  , p=0.0023  , df_denom=1207, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.6971  , p=0.0034  , df_denom=1204, df_num=2
# ssr based chi2 test:   chi2=11.4415 , p=0.0033  , df=2
# likelihood ratio test: chi2=11.3877 , p=0.0034  , df=2
# parameter F test:         F=5.6971  , p=0.0034  , df_denom=1204, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.8730  , p=0.0090  , df_denom=1201, df_num=3
# ssr based chi2 test:   chi2=11.6868 , p=0.0085  , df=3
# likelihood ratio test: chi2=11.6307 , p=0.0088  , df=3
# parameter F test:         F=3.8730  , p=0.0090  , df_denom=1201, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.6702  , p=0.0056  , df_denom=1198, df_num=4
# ssr based chi2 test:   chi2=14.7909 , p=0.0052  , df=4
# likelihood ratio test: chi2=14.7010 , p=0.0054  , df=4
# parameter F test:         F=3.6702  , p=0.0056  , df_denom=1198, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.5780  , p=0.0032  , df_denom=1195, df_num=5
# ssr based chi2 test:   chi2=18.0549 , p=0.0029  , df=5
# likelihood ratio test: chi2=17.9211 , p=0.0030  , df=5
# parameter F test:         F=3.5780  , p=0.0032  , df_denom=1195, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.0778  , p=0.0054  , df_denom=1192, df_num=6
# ssr based chi2 test:   chi2=18.6682 , p=0.0048  , df=6
# likelihood ratio test: chi2=18.5250 , p=0.0050  , df=6
# parameter F test:         F=3.0778  , p=0.0054  , df_denom=1192, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.7876  , p=0.0070  , df_denom=1189, df_num=7
# ssr based chi2 test:   chi2=19.7594 , p=0.0061  , df=7
# likelihood ratio test: chi2=19.5990 , p=0.0065  , df=7
# parameter F test:         F=2.7876  , p=0.0070  , df_denom=1189, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.1069  , p=0.0018  , df_denom=1186, df_num=8
# ssr based chi2 test:   chi2=25.2113 , p=0.0014  , df=8
# likelihood ratio test: chi2=24.9508 , p=0.0016  , df=8
# parameter F test:         F=3.1069  , p=0.0018  , df_denom=1186, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.1587  , p=0.0009  , df_denom=1183, df_num=9
# ssr based chi2 test:   chi2=28.8851 , p=0.0007  , df=9
# likelihood ratio test: chi2=28.5435 , p=0.0008  , df=9
# parameter F test:         F=3.1587  , p=0.0009  , df_denom=1183, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.8949  , p=0.0014  , df_denom=1180, df_num=10
# ssr based chi2 test:   chi2=29.4639 , p=0.0010  , df=10
# likelihood ratio test: chi2=29.1083 , p=0.0012  , df=10
# parameter F test:         F=2.8949  , p=0.0014  , df_denom=1180, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.7771  , p=0.0959  , df_denom=1207, df_num=1
# ssr based chi2 test:   chi2=2.7840  , p=0.0952  , df=1
# likelihood ratio test: chi2=2.7808  , p=0.0954  , df=1
# parameter F test:         F=2.7771  , p=0.0959  , df_denom=1207, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5007  , p=0.2234  , df_denom=1204, df_num=2
# ssr based chi2 test:   chi2=3.0139  , p=0.2216  , df=2
# likelihood ratio test: chi2=3.0101  , p=0.2220  , df=2
# parameter F test:         F=1.5007  , p=0.2234  , df_denom=1204, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6844  , p=0.1685  , df_denom=1201, df_num=3
# ssr based chi2 test:   chi2=5.0828  , p=0.1658  , df=3
# likelihood ratio test: chi2=5.0721  , p=0.1666  , df=3
# parameter F test:         F=1.6844  , p=0.1685  , df_denom=1201, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2818  , p=0.2752  , df_denom=1198, df_num=4
# ssr based chi2 test:   chi2=5.1657  , p=0.2707  , df=4
# likelihood ratio test: chi2=5.1547  , p=0.2718  , df=4
# parameter F test:         F=1.2818  , p=0.2752  , df_denom=1198, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.5367  , p=0.1755  , df_denom=1195, df_num=5
# ssr based chi2 test:   chi2=7.7540  , p=0.1703  , df=5
# likelihood ratio test: chi2=7.7292  , p=0.1718  , df=5
# parameter F test:         F=1.5367  , p=0.1755  , df_denom=1195, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3005  , p=0.2539  , df_denom=1192, df_num=6
# ssr based chi2 test:   chi2=7.8879  , p=0.2464  , df=6
# likelihood ratio test: chi2=7.8622  , p=0.2484  , df=6
# parameter F test:         F=1.3005  , p=0.2539  , df_denom=1192, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1767  , p=0.3131  , df_denom=1189, df_num=7
# ssr based chi2 test:   chi2=8.3409  , p=0.3035  , df=7
# likelihood ratio test: chi2=8.3122  , p=0.3059  , df=7
# parameter F test:         F=1.1767  , p=0.3131  , df_denom=1189, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.0918  , p=0.3661  , df_denom=1186, df_num=8
# ssr based chi2 test:   chi2=8.8595  , p=0.3543  , df=8
# likelihood ratio test: chi2=8.8270  , p=0.3571  , df=8
# parameter F test:         F=1.0918  , p=0.3661  , df_denom=1186, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.7660  , p=0.0704  , df_denom=1183, df_num=9
# ssr based chi2 test:   chi2=16.1494 , p=0.0638  , df=9
# likelihood ratio test: chi2=16.0419 , p=0.0660  , df=9
# parameter F test:         F=1.7660  , p=0.0704  , df_denom=1183, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.7227  , p=0.0709  , df_denom=1180, df_num=10
# ssr based chi2 test:   chi2=17.5331 , p=0.0634  , df=10
# likelihood ratio test: chi2=17.4063 , p=0.0658  , df=10
# parameter F test:         F=1.7227  , p=0.0709  , df_denom=1180, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.5740  , p=0.0589  , df_denom=1207, df_num=1
# ssr based chi2 test:   chi2=3.5829  , p=0.0584  , df=1
# likelihood ratio test: chi2=3.5776  , p=0.0586  , df=1
# parameter F test:         F=3.5740  , p=0.0589  , df_denom=1207, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.6534  , p=0.0708  , df_denom=1204, df_num=2
# ssr based chi2 test:   chi2=5.3289  , p=0.0696  , df=2
# likelihood ratio test: chi2=5.3172  , p=0.0700  , df=2
# parameter F test:         F=2.6534  , p=0.0708  , df_denom=1204, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.8323  , p=0.1394  , df_denom=1201, df_num=3
# ssr based chi2 test:   chi2=5.5289  , p=0.1369  , df=3
# likelihood ratio test: chi2=5.5163  , p=0.1377  , df=3
# parameter F test:         F=1.8323  , p=0.1394  , df_denom=1201, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.5836  , p=0.1763  , df_denom=1198, df_num=4
# ssr based chi2 test:   chi2=6.3818  , p=0.1724  , df=4
# likelihood ratio test: chi2=6.3650  , p=0.1735  , df=4
# parameter F test:         F=1.5836  , p=0.1763  , df_denom=1198, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.8507  , p=0.1003  , df_denom=1195, df_num=5
# ssr based chi2 test:   chi2=9.3385  , p=0.0963  , df=5
# likelihood ratio test: chi2=9.3025  , p=0.0976  , df=5
# parameter F test:         F=1.8507  , p=0.1003  , df_denom=1195, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.9101  , p=0.0761  , df_denom=1192, df_num=6
# ssr based chi2 test:   chi2=11.5858 , p=0.0719  , df=6
# likelihood ratio test: chi2=11.5305 , p=0.0733  , df=6
# parameter F test:         F=1.9101  , p=0.0761  , df_denom=1192, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.8352  , p=0.0770  , df_denom=1189, df_num=7
# ssr based chi2 test:   chi2=13.0085 , p=0.0719  , df=7
# likelihood ratio test: chi2=12.9387 , p=0.0736  , df=7
# parameter F test:         F=1.8352  , p=0.0770  , df_denom=1189, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.6720  , p=0.1008  , df_denom=1186, df_num=8
# ssr based chi2 test:   chi2=13.5675 , p=0.0938  , df=8
# likelihood ratio test: chi2=13.4916 , p=0.0960  , df=8
# parameter F test:         F=1.6720  , p=0.1008  , df_denom=1186, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.5199  , p=0.1357  , df_denom=1183, df_num=9
# ssr based chi2 test:   chi2=13.8988 , p=0.1260  , df=9
# likelihood ratio test: chi2=13.8190 , p=0.1289  , df=9
# parameter F test:         F=1.5199  , p=0.1357  , df_denom=1183, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3165  , p=0.2162  , df_denom=1180, df_num=10
# ssr based chi2 test:   chi2=13.3990 , p=0.2022  , df=10
# likelihood ratio test: chi2=13.3248 , p=0.2061  , df=10
# parameter F test:         F=1.3165  , p=0.2162  , df_denom=1180, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=15.8065 , p=0.0001  , df_denom=1207, df_num=1
# ssr based chi2 test:   chi2=15.8458 , p=0.0001  , df=1
# likelihood ratio test: chi2=15.7430 , p=0.0001  , df=1
# parameter F test:         F=15.8065 , p=0.0001  , df_denom=1207, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.8897  , p=0.0004  , df_denom=1204, df_num=2
# ssr based chi2 test:   chi2=15.8449 , p=0.0004  , df=2
# likelihood ratio test: chi2=15.7420 , p=0.0004  , df=2
# parameter F test:         F=7.8897  , p=0.0004  , df_denom=1204, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.1714  , p=0.0015  , df_denom=1201, df_num=3
# ssr based chi2 test:   chi2=15.6047 , p=0.0014  , df=3
# likelihood ratio test: chi2=15.5048 , p=0.0014  , df=3
# parameter F test:         F=5.1714  , p=0.0015  , df_denom=1201, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.3293  , p=0.0018  , df_denom=1198, df_num=4
# ssr based chi2 test:   chi2=17.4472 , p=0.0016  , df=4
# likelihood ratio test: chi2=17.3223 , p=0.0017  , df=4
# parameter F test:         F=4.3293  , p=0.0018  , df_denom=1198, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=4.3331  , p=0.0007  , df_denom=1195, df_num=5
# ssr based chi2 test:   chi2=21.8650 , p=0.0006  , df=5
# likelihood ratio test: chi2=21.6692 , p=0.0006  , df=5
# parameter F test:         F=4.3331  , p=0.0007  , df_denom=1195, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.8046  , p=0.0009  , df_denom=1192, df_num=6
# ssr based chi2 test:   chi2=23.0764 , p=0.0008  , df=6
# likelihood ratio test: chi2=22.8582 , p=0.0008  , df=6
# parameter F test:         F=3.8046  , p=0.0009  , df_denom=1192, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=3.2873  , p=0.0018  , df_denom=1189, df_num=7
# ssr based chi2 test:   chi2=23.3012 , p=0.0015  , df=7
# likelihood ratio test: chi2=23.0786 , p=0.0017  , df=7
# parameter F test:         F=3.2873  , p=0.0018  , df_denom=1189, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.1862  , p=0.0014  , df_denom=1186, df_num=8
# ssr based chi2 test:   chi2=25.8550 , p=0.0011  , df=8
# likelihood ratio test: chi2=25.5811 , p=0.0012  , df=8
# parameter F test:         F=3.1862  , p=0.0014  , df_denom=1186, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.9195  , p=0.0020  , df_denom=1183, df_num=9
# ssr based chi2 test:   chi2=26.6978 , p=0.0016  , df=9
# likelihood ratio test: chi2=26.4056 , p=0.0018  , df=9
# parameter F test:         F=2.9195  , p=0.0020  , df_denom=1183, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.5512  , p=0.0048  , df_denom=1180, df_num=10
# ssr based chi2 test:   chi2=25.9663 , p=0.0038  , df=10
# likelihood ratio test: chi2=25.6896 , p=0.0042  , df=10
# parameter F test:         F=2.5512  , p=0.0048  , df_denom=1180, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.5948  , p=0.2069  , df_denom=1205, df_num=1
# ssr based chi2 test:   chi2=1.5988  , p=0.2061  , df=1
# likelihood ratio test: chi2=1.5977  , p=0.2062  , df=1
# parameter F test:         F=1.5948  , p=0.2069  , df_denom=1205, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8332  , p=0.4349  , df_denom=1202, df_num=2
# ssr based chi2 test:   chi2=1.6734  , p=0.4331  , df=2
# likelihood ratio test: chi2=1.6723  , p=0.4334  , df=2
# parameter F test:         F=0.8332  , p=0.4349  , df_denom=1202, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0482  , p=0.3703  , df_denom=1199, df_num=3
# ssr based chi2 test:   chi2=3.1630  , p=0.3672  , df=3
# likelihood ratio test: chi2=3.1589  , p=0.3678  , df=3
# parameter F test:         F=1.0482  , p=0.3703  , df_denom=1199, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.2580  , p=0.0114  , df_denom=1196, df_num=4
# ssr based chi2 test:   chi2=13.1302 , p=0.0107  , df=4
# likelihood ratio test: chi2=13.0592 , p=0.0110  , df=4
# parameter F test:         F=3.2580  , p=0.0114  , df_denom=1196, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.6359  , p=0.0222  , df_denom=1193, df_num=5
# ssr based chi2 test:   chi2=13.3009 , p=0.0207  , df=5
# likelihood ratio test: chi2=13.2280 , p=0.0213  , df=5
# parameter F test:         F=2.6359  , p=0.0222  , df_denom=1193, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.2487  , p=0.0366  , df_denom=1190, df_num=6
# ssr based chi2 test:   chi2=13.6396 , p=0.0339  , df=6
# likelihood ratio test: chi2=13.5629 , p=0.0349  , df=6
# parameter F test:         F=2.2487  , p=0.0366  , df_denom=1190, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.0649  , p=0.0446  , df_denom=1187, df_num=7
# ssr based chi2 test:   chi2=14.6369 , p=0.0409  , df=7
# likelihood ratio test: chi2=14.5485 , p=0.0422  , df=7
# parameter F test:         F=2.0649  , p=0.0446  , df_denom=1187, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.7908  , p=0.0748  , df_denom=1184, df_num=8
# ssr based chi2 test:   chi2=14.5318 , p=0.0689  , df=8
# likelihood ratio test: chi2=14.4445 , p=0.0709  , df=8
# parameter F test:         F=1.7908  , p=0.0748  , df_denom=1184, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.6585  , p=0.0944  , df_denom=1181, df_num=9
# ssr based chi2 test:   chi2=15.1666 , p=0.0865  , df=9
# likelihood ratio test: chi2=15.0716 , p=0.0890  , df=9
# parameter F test:         F=1.6585  , p=0.0944  , df_denom=1181, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.5334  , p=0.1220  , df_denom=1178, df_num=10
# ssr based chi2 test:   chi2=15.6069 , p=0.1115  , df=10
# likelihood ratio test: chi2=15.5062 , p=0.1147  , df=10
# parameter F test:         F=1.5334  , p=0.1220  , df_denom=1178, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.8908  , p=0.0488  , df_denom=1207, df_num=1
# ssr based chi2 test:   chi2=3.9005  , p=0.0483  , df=1
# likelihood ratio test: chi2=3.8942  , p=0.0485  , df=1
# parameter F test:         F=3.8908  , p=0.0488  , df_denom=1207, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.9551  , p=0.1420  , df_denom=1204, df_num=2
# ssr based chi2 test:   chi2=3.9264  , p=0.1404  , df=2
# likelihood ratio test: chi2=3.9201  , p=0.1409  , df=2
# parameter F test:         F=1.9551  , p=0.1420  , df_denom=1204, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4276  , p=0.2331  , df_denom=1201, df_num=3
# ssr based chi2 test:   chi2=4.3076  , p=0.2301  , df=3
# likelihood ratio test: chi2=4.3000  , p=0.2308  , df=3
# parameter F test:         F=1.4276  , p=0.2331  , df_denom=1201, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1113  , p=0.3497  , df_denom=1198, df_num=4
# ssr based chi2 test:   chi2=4.4784  , p=0.3451  , df=4
# likelihood ratio test: chi2=4.4701  , p=0.3461  , df=4
# parameter F test:         F=1.1113  , p=0.3497  , df_denom=1198, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2610  , p=0.2784  , df_denom=1195, df_num=5
# ssr based chi2 test:   chi2=6.3632  , p=0.2725  , df=5
# likelihood ratio test: chi2=6.3465  , p=0.2739  , df=5
# parameter F test:         F=1.2610  , p=0.2784  , df_denom=1195, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.1341  , p=0.3401  , df_denom=1192, df_num=6
# ssr based chi2 test:   chi2=6.8786  , p=0.3322  , df=6
# likelihood ratio test: chi2=6.8590  , p=0.3341  , df=6
# parameter F test:         F=1.1341  , p=0.3401  , df_denom=1192, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.9642  , p=0.4559  , df_denom=1189, df_num=7
# ssr based chi2 test:   chi2=6.8349  , p=0.4463  , df=7
# likelihood ratio test: chi2=6.8156  , p=0.4483  , df=7
# parameter F test:         F=0.9642  , p=0.4559  , df_denom=1189, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.9058  , p=0.5107  , df_denom=1186, df_num=8
# ssr based chi2 test:   chi2=7.3503  , p=0.4994  , df=8
# likelihood ratio test: chi2=7.3279  , p=0.5017  , df=8
# parameter F test:         F=0.9058  , p=0.5107  , df_denom=1186, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.8230  , p=0.5950  , df_denom=1183, df_num=9
# ssr based chi2 test:   chi2=7.5260  , p=0.5825  , df=9
# likelihood ratio test: chi2=7.5025  , p=0.5849  , df=9
# parameter F test:         F=0.8230  , p=0.5950  , df_denom=1183, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8629  , p=0.5678  , df_denom=1180, df_num=10
# ssr based chi2 test:   chi2=8.7828  , p=0.5528  , df=10
# likelihood ratio test: chi2=8.7509  , p=0.5559  , df=10
# parameter F test:         F=0.8629  , p=0.5678  , df_denom=1180, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.2934  , p=0.1302  , df_denom=1207, df_num=1
# ssr based chi2 test:   chi2=2.2991  , p=0.1295  , df=1
# likelihood ratio test: chi2=2.2969  , p=0.1296  , df=1
# parameter F test:         F=2.2934  , p=0.1302  , df_denom=1207, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.5390  , p=0.0293  , df_denom=1204, df_num=2
# ssr based chi2 test:   chi2=7.1075  , p=0.0286  , df=2
# likelihood ratio test: chi2=7.0867  , p=0.0289  , df=2
# parameter F test:         F=3.5390  , p=0.0293  , df_denom=1204, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.3650  , p=0.0695  , df_denom=1201, df_num=3
# ssr based chi2 test:   chi2=7.1362  , p=0.0677  , df=3
# likelihood ratio test: chi2=7.1152  , p=0.0683  , df=3
# parameter F test:         F=2.3650  , p=0.0695  , df_denom=1201, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.9820  , p=0.0950  , df_denom=1198, df_num=4
# ssr based chi2 test:   chi2=7.9874  , p=0.0920  , df=4
# likelihood ratio test: chi2=7.9611  , p=0.0930  , df=4
# parameter F test:         F=1.9820  , p=0.0950  , df_denom=1198, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.6144  , p=0.1532  , df_denom=1195, df_num=5
# ssr based chi2 test:   chi2=8.1461  , p=0.1484  , df=5
# likelihood ratio test: chi2=8.1187  , p=0.1498  , df=5
# parameter F test:         F=1.6144  , p=0.1532  , df_denom=1195, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3889  , p=0.2157  , df_denom=1192, df_num=6
# ssr based chi2 test:   chi2=8.4241  , p=0.2087  , df=6
# likelihood ratio test: chi2=8.3948  , p=0.2106  , df=6
# parameter F test:         F=1.3889  , p=0.2157  , df_denom=1192, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.3473  , p=0.2243  , df_denom=1189, df_num=7
# ssr based chi2 test:   chi2=9.5501  , p=0.2155  , df=7
# likelihood ratio test: chi2=9.5124  , p=0.2179  , df=7
# parameter F test:         F=1.3473  , p=0.2243  , df_denom=1189, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2037  , p=0.2931  , df_denom=1186, df_num=8
# ssr based chi2 test:   chi2=9.7679  , p=0.2817  , df=8
# likelihood ratio test: chi2=9.7284  , p=0.2846  , df=8
# parameter F test:         F=1.2037  , p=0.2931  , df_denom=1186, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.1901  , p=0.2973  , df_denom=1183, df_num=9
# ssr based chi2 test:   chi2=10.8825 , p=0.2838  , df=9
# likelihood ratio test: chi2=10.8336 , p=0.2873  , df=9
# parameter F test:         F=1.1901  , p=0.2973  , df_denom=1183, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3611  , p=0.1931  , df_denom=1180, df_num=10
# ssr based chi2 test:   chi2=13.8529 , p=0.1798  , df=10
# likelihood ratio test: chi2=13.7737 , p=0.1836  , df=10
# parameter F test:         F=1.3611  , p=0.1931  , df_denom=1180, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4521  , p=0.5015  , df_denom=1207, df_num=1
# ssr based chi2 test:   chi2=0.4532  , p=0.5008  , df=1
# likelihood ratio test: chi2=0.4532  , p=0.5008  , df=1
# parameter F test:         F=0.4521  , p=0.5015  , df_denom=1207, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8339  , p=0.4346  , df_denom=1204, df_num=2
# ssr based chi2 test:   chi2=1.6747  , p=0.4329  , df=2
# likelihood ratio test: chi2=1.6735  , p=0.4331  , df=2
# parameter F test:         F=0.8339  , p=0.4346  , df_denom=1204, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7787  , p=0.5059  , df_denom=1201, df_num=3
# ssr based chi2 test:   chi2=2.3497  , p=0.5031  , df=3
# likelihood ratio test: chi2=2.3474  , p=0.5035  , df=3
# parameter F test:         F=0.7787  , p=0.5059  , df_denom=1201, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7209  , p=0.5777  , df_denom=1198, df_num=4
# ssr based chi2 test:   chi2=2.9051  , p=0.5738  , df=4
# likelihood ratio test: chi2=2.9016  , p=0.5744  , df=4
# parameter F test:         F=0.7209  , p=0.5777  , df_denom=1198, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7872  , p=0.5589  , df_denom=1195, df_num=5
# ssr based chi2 test:   chi2=3.9722  , p=0.5534  , df=5
# likelihood ratio test: chi2=3.9656  , p=0.5544  , df=5
# parameter F test:         F=0.7872  , p=0.5589  , df_denom=1195, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6667  , p=0.6767  , df_denom=1192, df_num=6
# ssr based chi2 test:   chi2=4.0438  , p=0.6708  , df=6
# likelihood ratio test: chi2=4.0370  , p=0.6717  , df=6
# parameter F test:         F=0.6667  , p=0.6767  , df_denom=1192, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6680  , p=0.6993  , df_denom=1189, df_num=7
# ssr based chi2 test:   chi2=4.7352  , p=0.6922  , df=7
# likelihood ratio test: chi2=4.7259  , p=0.6934  , df=7
# parameter F test:         F=0.6680  , p=0.6993  , df_denom=1189, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6588  , p=0.7281  , df_denom=1186, df_num=8
# ssr based chi2 test:   chi2=5.3462  , p=0.7200  , df=8
# likelihood ratio test: chi2=5.3344  , p=0.7213  , df=8
# parameter F test:         F=0.6588  , p=0.7281  , df_denom=1186, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0055  , p=0.4334  , df_denom=1183, df_num=9
# ssr based chi2 test:   chi2=9.1947  , p=0.4195  , df=9
# likelihood ratio test: chi2=9.1598  , p=0.4227  , df=9
# parameter F test:         F=1.0055  , p=0.4334  , df_denom=1183, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8742  , p=0.5570  , df_denom=1180, df_num=10
# ssr based chi2 test:   chi2=8.8974  , p=0.5419  , df=10
# likelihood ratio test: chi2=8.8646  , p=0.5450  , df=10
# parameter F test:         F=0.8742  , p=0.5570  , df_denom=1180, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.9091  , p=0.1673  , df_denom=1207, df_num=1
# ssr based chi2 test:   chi2=1.9138  , p=0.1665  , df=1
# likelihood ratio test: chi2=1.9123  , p=0.1667  , df=1
# parameter F test:         F=1.9091  , p=0.1673  , df_denom=1207, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.4772  , p=0.2287  , df_denom=1204, df_num=2
# ssr based chi2 test:   chi2=2.9666  , p=0.2269  , df=2
# likelihood ratio test: chi2=2.9630  , p=0.2273  , df=2
# parameter F test:         F=1.4772  , p=0.2287  , df_denom=1204, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0202  , p=0.3828  , df_denom=1201, df_num=3
# ssr based chi2 test:   chi2=3.0786  , p=0.3797  , df=3
# likelihood ratio test: chi2=3.0746  , p=0.3803  , df=3
# parameter F test:         F=1.0202  , p=0.3828  , df_denom=1201, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7591  , p=0.5520  , df_denom=1198, df_num=4
# ssr based chi2 test:   chi2=3.0591  , p=0.5480  , df=4
# likelihood ratio test: chi2=3.0553  , p=0.5486  , df=4
# parameter F test:         F=0.7591  , p=0.5520  , df_denom=1198, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6422  , p=0.6676  , df_denom=1195, df_num=5
# ssr based chi2 test:   chi2=3.2404  , p=0.6630  , df=5
# likelihood ratio test: chi2=3.2361  , p=0.6636  , df=5
# parameter F test:         F=0.6422  , p=0.6676  , df_denom=1195, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5706  , p=0.7540  , df_denom=1192, df_num=6
# ssr based chi2 test:   chi2=3.4607  , p=0.7492  , df=6
# likelihood ratio test: chi2=3.4557  , p=0.7498  , df=6
# parameter F test:         F=0.5706  , p=0.7540  , df_denom=1192, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.0130  , p=0.4201  , df_denom=1189, df_num=7
# ssr based chi2 test:   chi2=7.1804  , p=0.4103  , df=7
# likelihood ratio test: chi2=7.1591  , p=0.4125  , df=7
# parameter F test:         F=1.0130  , p=0.4201  , df_denom=1189, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.9849  , p=0.4460  , df_denom=1186, df_num=8
# ssr based chi2 test:   chi2=7.9917  , p=0.4343  , df=8
# likelihood ratio test: chi2=7.9653  , p=0.4369  , df=8
# parameter F test:         F=0.9849  , p=0.4460  , df_denom=1186, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.5204  , p=0.1355  , df_denom=1183, df_num=9
# ssr based chi2 test:   chi2=13.9029 , p=0.1258  , df=9
# likelihood ratio test: chi2=13.8231 , p=0.1288  , df=9
# parameter F test:         F=1.5204  , p=0.1355  , df_denom=1183, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3156  , p=0.2166  , df_denom=1180, df_num=10
# ssr based chi2 test:   chi2=13.3906 , p=0.2026  , df=10
# likelihood ratio test: chi2=13.3165 , p=0.2065  , df=10
# parameter F test:         F=1.3156  , p=0.2166  , df_denom=1180, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.8044  , p=0.1794  , df_denom=1207, df_num=1
# ssr based chi2 test:   chi2=1.8089  , p=0.1786  , df=1
# likelihood ratio test: chi2=1.8075  , p=0.1788  , df=1
# parameter F test:         F=1.8044  , p=0.1794  , df_denom=1207, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3366  , p=0.2631  , df_denom=1204, df_num=2
# ssr based chi2 test:   chi2=2.6844  , p=0.2613  , df=2
# likelihood ratio test: chi2=2.6814  , p=0.2617  , df=2
# parameter F test:         F=1.3366  , p=0.2631  , df_denom=1204, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0120  , p=0.3865  , df_denom=1201, df_num=3
# ssr based chi2 test:   chi2=3.0537  , p=0.3834  , df=3
# likelihood ratio test: chi2=3.0499  , p=0.3840  , df=3
# parameter F test:         F=1.0120  , p=0.3865  , df_denom=1201, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7419  , p=0.5635  , df_denom=1198, df_num=4
# ssr based chi2 test:   chi2=2.9899  , p=0.5595  , df=4
# likelihood ratio test: chi2=2.9862  , p=0.5601  , df=4
# parameter F test:         F=0.7419  , p=0.5635  , df_denom=1198, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5812  , p=0.7145  , df_denom=1195, df_num=5
# ssr based chi2 test:   chi2=2.9327  , p=0.7104  , df=5
# likelihood ratio test: chi2=2.9292  , p=0.7109  , df=5
# parameter F test:         F=0.5812  , p=0.7145  , df_denom=1195, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5548  , p=0.7665  , df_denom=1192, df_num=6
# ssr based chi2 test:   chi2=3.3651  , p=0.7618  , df=6
# likelihood ratio test: chi2=3.3604  , p=0.7624  , df=6
# parameter F test:         F=0.5548  , p=0.7665  , df_denom=1192, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2008  , p=0.2992  , df_denom=1189, df_num=7
# ssr based chi2 test:   chi2=8.5118  , p=0.2896  , df=7
# likelihood ratio test: chi2=8.4819  , p=0.2920  , df=7
# parameter F test:         F=1.2008  , p=0.2992  , df_denom=1189, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1774  , p=0.3092  , df_denom=1186, df_num=8
# ssr based chi2 test:   chi2=9.5545  , p=0.2977  , df=8
# likelihood ratio test: chi2=9.5168  , p=0.3006  , df=8
# parameter F test:         F=1.1774  , p=0.3092  , df_denom=1186, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.5369  , p=0.1299  , df_denom=1183, df_num=9
# ssr based chi2 test:   chi2=14.0540 , p=0.1204  , df=9
# likelihood ratio test: chi2=13.9725 , p=0.1233  , df=9
# parameter F test:         F=1.5369  , p=0.1299  , df_denom=1183, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3248  , p=0.2117  , df_denom=1180, df_num=10
# ssr based chi2 test:   chi2=13.4839 , p=0.1979  , df=10
# likelihood ratio test: chi2=13.4087 , p=0.2017  , df=10
# parameter F test:         F=1.3248  , p=0.2117  , df_denom=1180, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.9593  , p=0.0148  , df_denom=1207, df_num=1
# ssr based chi2 test:   chi2=5.9741  , p=0.0145  , df=1
# likelihood ratio test: chi2=5.9594  , p=0.0146  , df=1
# parameter F test:         F=5.9593  , p=0.0148  , df_denom=1207, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.4778  , p=0.0312  , df_denom=1204, df_num=2
# ssr based chi2 test:   chi2=6.9845  , p=0.0304  , df=2
# likelihood ratio test: chi2=6.9644  , p=0.0307  , df=2
# parameter F test:         F=3.4778  , p=0.0312  , df_denom=1204, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.4225  , p=0.0644  , df_denom=1201, df_num=3
# ssr based chi2 test:   chi2=7.3098  , p=0.0627  , df=3
# likelihood ratio test: chi2=7.2878  , p=0.0633  , df=3
# parameter F test:         F=2.4225  , p=0.0644  , df_denom=1201, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.7916  , p=0.1281  , df_denom=1198, df_num=4
# ssr based chi2 test:   chi2=7.2201  , p=0.1247  , df=4
# likelihood ratio test: chi2=7.1986  , p=0.1258  , df=4
# parameter F test:         F=1.7916  , p=0.1281  , df_denom=1198, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.4385  , p=0.2076  , df_denom=1195, df_num=5
# ssr based chi2 test:   chi2=7.2588  , p=0.2021  , df=5
# likelihood ratio test: chi2=7.2370  , p=0.2036  , df=5
# parameter F test:         F=1.4385  , p=0.2076  , df_denom=1195, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3832  , p=0.2180  , df_denom=1192, df_num=6
# ssr based chi2 test:   chi2=8.3897  , p=0.2109  , df=6
# likelihood ratio test: chi2=8.3606  , p=0.2129  , df=6
# parameter F test:         F=1.3832  , p=0.2180  , df_denom=1192, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4271  , p=0.1903  , df_denom=1189, df_num=7
# ssr based chi2 test:   chi2=10.1158 , p=0.1821  , df=7
# likelihood ratio test: chi2=10.0735 , p=0.1844  , df=7
# parameter F test:         F=1.4271  , p=0.1903  , df_denom=1189, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2546  , p=0.2636  , df_denom=1186, df_num=8
# ssr based chi2 test:   chi2=10.1811 , p=0.2525  , df=8
# likelihood ratio test: chi2=10.1382 , p=0.2555  , df=8
# parameter F test:         F=1.2546  , p=0.2636  , df_denom=1186, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0672  , p=0.3843  , df_denom=1183, df_num=9
# ssr based chi2 test:   chi2=9.7593  , p=0.3703  , df=9
# likelihood ratio test: chi2=9.7199  , p=0.3736  , df=9
# parameter F test:         F=1.0672  , p=0.3843  , df_denom=1183, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.0518  , p=0.3972  , df_denom=1180, df_num=10
# ssr based chi2 test:   chi2=10.7054 , p=0.3809  , df=10
# likelihood ratio test: chi2=10.6580 , p=0.3848  , df=10
# parameter F test:         F=1.0518  , p=0.3972  , df_denom=1180, df_num=10

# %%
GC_stock
# Out:
# ['ALV', 'F', 'GM', 'TM', 'TRYUSD=X', 'WFC', 'X', 'ALI=F']

# %%
optimal_lag
# Out:
# [np.int64(2),
#  np.int64(5),
#  np.int64(9),
#  np.int64(1),
#  np.int64(4),
#  np.int64(1),
#  np.int64(2),
#  np.int64(1)]

# %% [markdown]
# From this table, we found that the followings causality:
# - Tesla causes Meta, Ford, Palladium
# - Apple causes Microsoft, NVIDIA, Amazon, Meta, Gold, Palladium
# - Google causes Microsoft, Amazon, Meta, Oil, Ford, Palladium
# - Microsoft causes Apple, Google, Amazon, Meta, Gold, Ford, Palladium
# - NVIDIA causes Google, Microsoft, Amazon, Meta, Gold
# - Amazon causes Tesla, TGold, Ford, Palladium
# - Meta causes Amazon, TSMC, Ford, Palladium
# - TSMC causes Apple, Gold, Ford, Palladium
# - Gold causes Oil, Palladium
# - Oil causes Google, Microsoft, Gold, Palladium
# - Ford causes Tesla, NVIDIA, TSMC, Gold, Oil, Palladium
# - Palladium causes Tesla

# %% [markdown]
# ## Definition

# %%
ticker = ['ALV','ASEKY','BAC','CADUSD=X','CHFUSD=X','CL=F','F','FDX','GBPUSD=X','GBPUSD=X','GM','JCI','JPM','TM',
         'TRYUSD=X','WFC','X','^DJI','^GSPC','^IXIC','ALI=F']

GC_stock = []
optimal_lag = []

def gc_test(df):

for t in ticker:
    df1 = df[['DNZOY', t]].copy()
    test_result = grangercausalitytests(df1.dropna(), maxlag=10)
    p_values = [round(test_result[i+1][0]['ssr_ftest'][1],4) for i in range(10)]
    min_p_value = np.min(p_values)
    if min_p_value < 0.05:
        GC_stock.append(t)
        optimal_lag.append(1 + np.argmin(p_values))
