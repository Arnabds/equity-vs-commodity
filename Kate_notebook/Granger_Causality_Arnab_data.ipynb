# %% [markdown]
# ## Granger Causality Test

# %% [markdown]
# Companies that Granger Causes Apple’s close differencing will be implemented in VAR.

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from statsmodels.tsa.stattools import grangercausalitytests

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
#warnings.filterwarnings("ignore", category=ValueError)
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=ValueError)

# %% [markdown]
# ## Import stock data from Yahoo Finance

# %%
tickers = ['DNZOY','ALV','ASEKY','BAC','CADUSD=X','CHFUSD=X','CL=F','F','FDX','GBPUSD=X','GBPUSD=X','GM','JCI','JPM','TM',
         'TRYUSD=X','WFC','X','^DJI','^GSPC','^IXIC','ALI=F']

data = yf.download(tickers, period="5y")
df = data['Close'].diff().copy()
# Out:
# [*********************100%***********************]  21 of 21 completed

# %%
df
# Out:
# Ticker                     ALI=F       ALV  ASEKY       BAC  CADUSD=X  \
# Date
# 2019-12-02 00:00:00+00:00    NaN       NaN    NaN       NaN       NaN
# 2019-12-03 00:00:00+00:00 -24.25       NaN    NaN       NaN       NaN
# 2019-12-04 00:00:00+00:00 -11.00  0.279999    0.0  0.310001  0.000628
# 2019-12-05 00:00:00+00:00  -6.75  0.949997    0.0 -0.060001  0.005657
# 2019-12-06 00:00:00+00:00   5.75  0.920006    0.0  0.579998  0.000961
# ...                          ...       ...    ...       ...       ...
# 2024-11-27 00:00:00+00:00   1.25 -0.690002    0.0  0.020000  0.002286
# 2024-11-28 00:00:00+00:00 -30.50       NaN    NaN       NaN  0.001360
# 2024-11-29 00:00:00+00:00  36.00       NaN    NaN       NaN  0.000972
# 2024-12-02 00:00:00+00:00    NaN  0.860001    NaN -0.469997 -0.000275
# 2024-12-03 00:00:00+00:00    NaN       NaN    NaN       NaN -0.001864
#
# Ticker                     CHFUSD=X      CL=F     DNZOY         F       FDX  \
# Date
# 2019-12-02 00:00:00+00:00       NaN       NaN       NaN       NaN       NaN
# 2019-12-03 00:00:00+00:00       NaN  0.139999       NaN       NaN       NaN
# 2019-12-04 00:00:00+00:00  0.004630  2.330002  0.180000  0.059999  2.729996
# 2019-12-05 00:00:00+00:00 -0.001384  0.000000  0.049999 -0.020000  0.070007
# 2019-12-06 00:00:00+00:00  0.001281  0.770000  0.120001  0.090000  2.669998
# ...                             ...       ...       ...       ...       ...
# 2024-11-27 00:00:00+00:00  0.003212 -0.049995 -0.410000  0.000000  0.410004
# 2024-11-28 00:00:00+00:00  0.005462  0.159996       NaN       NaN       NaN
# 2024-11-29 00:00:00+00:00 -0.000437 -0.879997       NaN       NaN       NaN
# 2024-12-02 00:00:00+00:00  0.000402       NaN  0.130000 -0.150001 -5.980011
# 2024-12-03 00:00:00+00:00 -0.007081       NaN       NaN       NaN       NaN
#
# Ticker                     ...        GM       JCI       JPM        TM  \
# Date                       ...
# 2019-12-02 00:00:00+00:00  ...       NaN       NaN       NaN       NaN
# 2019-12-03 00:00:00+00:00  ...       NaN       NaN       NaN       NaN
# 2019-12-04 00:00:00+00:00  ...  0.270000  0.340000  2.559998  2.650009
# 2019-12-05 00:00:00+00:00  ... -0.489998 -0.380001  0.720001 -0.550003
# 2019-12-06 00:00:00+00:00  ...  0.230000  0.340000  1.979996 -0.059998
# ...                        ...       ...       ...       ...       ...
# 2024-11-27 00:00:00+00:00  ...  0.709999 -0.040001 -0.180008 -2.800003
# 2024-11-28 00:00:00+00:00  ...       NaN       NaN       NaN       NaN
# 2024-11-29 00:00:00+00:00  ...       NaN       NaN       NaN       NaN
# 2024-12-02 00:00:00+00:00  ... -0.549999 -0.190002 -3.470001  5.179993
# 2024-12-03 00:00:00+00:00  ...       NaN       NaN       NaN       NaN
#
# Ticker                     TRYUSD=X       WFC     X        ^DJI      ^GSPC  \
# Date
# 2019-12-02 00:00:00+00:00       NaN       NaN   NaN         NaN        NaN
# 2019-12-03 00:00:00+00:00       NaN       NaN   NaN         NaN        NaN
# 2019-12-04 00:00:00+00:00 -0.000069  0.660000  0.20  146.968750  19.560059
# 2019-12-05 00:00:00+00:00 -0.000096 -0.010002 -0.01   28.009766   4.669922
# 2019-12-06 00:00:00+00:00  0.000011  1.139999  0.61  337.271484  28.479980
# ...                             ...       ...   ...         ...        ...
# 2024-11-27 00:00:00+00:00 -0.000047 -0.139999  0.82 -138.250000 -22.889648
# 2024-11-28 00:00:00+00:00  0.000014       NaN   NaN         NaN        NaN
# 2024-11-29 00:00:00+00:00 -0.000010       NaN   NaN         NaN        NaN
# 2024-12-02 00:00:00+00:00 -0.000037 -0.889999  0.18 -128.648438  14.770020
# 2024-12-03 00:00:00+00:00 -0.000042       NaN   NaN         NaN        NaN
#
# Ticker                          ^IXIC
# Date
# 2019-12-02 00:00:00+00:00         NaN
# 2019-12-03 00:00:00+00:00         NaN
# 2019-12-04 00:00:00+00:00   46.030273
# 2019-12-05 00:00:00+00:00    4.030273
# 2019-12-06 00:00:00+00:00   85.830078
# ...                               ...
# 2024-11-27 00:00:00+00:00 -113.820312
# 2024-11-28 00:00:00+00:00         NaN
# 2024-11-29 00:00:00+00:00         NaN
# 2024-12-02 00:00:00+00:00  185.777344
# 2024-12-03 00:00:00+00:00         NaN
#
# [1307 rows x 21 columns]

# %% [markdown]
# ## Apply Granger Causality test

# %%
ticker = ['ALV','ASEKY','BAC','CADUSD=X','CHFUSD=X','CL=F','F','FDX','GBPUSD=X','GBPUSD=X','GM','JCI','JPM','TM',
         'TRYUSD=X','WFC','X','^DJI','^GSPC','^IXIC','ALI=F']

GC_stock = []
optimal_lag = []

for t in ticker:
    df1 = df[['DNZOY', t]].copy()
    test_result = grangercausalitytests(df1.dropna(), maxlag=10)
    p_values = [round(test_result[i+1][0]['ssr_ftest'][1],4) for i in range(10)]
    min_p_value = np.min(p_values)
    if min_p_value < 0.05:
        GC_stock.append(t)
        optimal_lag.append(1 + np.argmin(p_values))
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.5546  , p=0.0106  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=6.5709  , p=0.0104  , df=1
# likelihood ratio test: chi2=6.5531  , p=0.0105  , df=1
# parameter F test:         F=6.5546  , p=0.0106  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.3995  , p=0.0046  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=10.8440 , p=0.0044  , df=2
# likelihood ratio test: chi2=10.7956 , p=0.0045  , df=2
# parameter F test:         F=5.3995  , p=0.0046  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.6058  , p=0.0130  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=10.8806 , p=0.0124  , df=3
# likelihood ratio test: chi2=10.8319 , p=0.0127  , df=3
# parameter F test:         F=3.6058  , p=0.0130  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.8281  , p=0.0237  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=11.3976 , p=0.0224  , df=4
# likelihood ratio test: chi2=11.3441 , p=0.0230  , df=4
# parameter F test:         F=2.8281  , p=0.0237  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.6304  , p=0.0225  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=13.2731 , p=0.0209  , df=5
# likelihood ratio test: chi2=13.2006 , p=0.0216  , df=5
# parameter F test:         F=2.6304  , p=0.0225  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.3674  , p=0.0281  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=14.3596 , p=0.0259  , df=6
# likelihood ratio test: chi2=14.2746 , p=0.0267  , df=6
# parameter F test:         F=2.3674  , p=0.0281  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.0945  , p=0.0415  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=14.8464 , p=0.0380  , df=7
# likelihood ratio test: chi2=14.7556 , p=0.0393  , df=7
# parameter F test:         F=2.0945  , p=0.0415  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.8601  , p=0.0626  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=15.0945 , p=0.0573  , df=8
# likelihood ratio test: chi2=15.0005 , p=0.0591  , df=8
# parameter F test:         F=1.8601  , p=0.0626  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.3403  , p=0.0129  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=21.4011 , p=0.0110  , df=9
# likelihood ratio test: chi2=21.2127 , p=0.0117  , df=9
# parameter F test:         F=2.3403  , p=0.0129  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.2211  , p=0.0147  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=22.6064 , p=0.0123  , df=10
# likelihood ratio test: chi2=22.3961 , p=0.0132  , df=10
# parameter F test:         F=2.2211  , p=0.0147  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.0325  , p=0.3098  , df_denom=1205, df_num=1
# ssr based chi2 test:   chi2=1.0350  , p=0.3090  , df=1
# likelihood ratio test: chi2=1.0346  , p=0.3091  , df=1
# parameter F test:         F=1.0325  , p=0.3098  , df_denom=1205, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5229  , p=0.5929  , df_denom=1202, df_num=2
# ssr based chi2 test:   chi2=1.0501  , p=0.5915  , df=2
# likelihood ratio test: chi2=1.0497  , p=0.5917  , df=2
# parameter F test:         F=0.5229  , p=0.5929  , df_denom=1202, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4683  , p=0.7044  , df_denom=1199, df_num=3
# ssr based chi2 test:   chi2=1.4131  , p=0.7025  , df=3
# likelihood ratio test: chi2=1.4123  , p=0.7027  , df=3
# parameter F test:         F=0.4683  , p=0.7044  , df_denom=1199, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5900  , p=0.6699  , df_denom=1196, df_num=4
# ssr based chi2 test:   chi2=2.3778  , p=0.6666  , df=4
# likelihood ratio test: chi2=2.3754  , p=0.6671  , df=4
# parameter F test:         F=0.5900  , p=0.6699  , df_denom=1196, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2438  , p=0.2862  , df_denom=1193, df_num=5
# ssr based chi2 test:   chi2=6.2766  , p=0.2802  , df=5
# likelihood ratio test: chi2=6.2603  , p=0.2817  , df=5
# parameter F test:         F=1.2438  , p=0.2862  , df_denom=1193, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0067  , p=0.4193  , df_denom=1190, df_num=6
# ssr based chi2 test:   chi2=6.1063  , p=0.4114  , df=6
# likelihood ratio test: chi2=6.0909  , p=0.4131  , df=6
# parameter F test:         F=1.0067  , p=0.4193  , df_denom=1190, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8673  , p=0.5318  , df_denom=1187, df_num=7
# ssr based chi2 test:   chi2=6.1478  , p=0.5226  , df=7
# likelihood ratio test: chi2=6.1321  , p=0.5244  , df=7
# parameter F test:         F=0.8673  , p=0.5318  , df_denom=1187, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7192  , p=0.6747  , df_denom=1184, df_num=8
# ssr based chi2 test:   chi2=5.8363  , p=0.6656  , df=8
# likelihood ratio test: chi2=5.8221  , p=0.6671  , df=8
# parameter F test:         F=0.7192  , p=0.6747  , df_denom=1184, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6940  , p=0.7149  , df_denom=1181, df_num=9
# ssr based chi2 test:   chi2=6.3466  , p=0.7048  , df=9
# likelihood ratio test: chi2=6.3299  , p=0.7065  , df=9
# parameter F test:         F=0.6940  , p=0.7149  , df_denom=1181, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.6320  , p=0.7873  , df_denom=1178, df_num=10
# ssr based chi2 test:   chi2=6.4328  , p=0.7777  , df=10
# likelihood ratio test: chi2=6.4156  , p=0.7792  , df=10
# parameter F test:         F=0.6320  , p=0.7873  , df_denom=1178, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.5151  , p=0.0338  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=4.5264  , p=0.0334  , df=1
# likelihood ratio test: chi2=4.5179  , p=0.0335  , df=1
# parameter F test:         F=4.5151  , p=0.0338  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.4124  , p=0.0900  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=4.8448  , p=0.0887  , df=2
# likelihood ratio test: chi2=4.8351  , p=0.0891  , df=2
# parameter F test:         F=2.4124  , p=0.0900  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.7199  , p=0.1611  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=5.1897  , p=0.1584  , df=3
# likelihood ratio test: chi2=5.1786  , p=0.1592  , df=3
# parameter F test:         F=1.7199  , p=0.1611  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.4664  , p=0.2101  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=5.9098  , p=0.2060  , df=4
# likelihood ratio test: chi2=5.8954  , p=0.2071  , df=4
# parameter F test:         F=1.4664  , p=0.2101  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.6672  , p=0.1396  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=8.4128  , p=0.1349  , df=5
# likelihood ratio test: chi2=8.3836  , p=0.1363  , df=5
# parameter F test:         F=1.6672  , p=0.1396  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.7347  , p=0.1095  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=10.5219 , p=0.1043  , df=6
# likelihood ratio test: chi2=10.4762 , p=0.1060  , df=6
# parameter F test:         F=1.7347  , p=0.1095  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4917  , p=0.1661  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=10.5740 , p=0.1583  , df=7
# likelihood ratio test: chi2=10.5278 , p=0.1606  , df=7
# parameter F test:         F=1.4917  , p=0.1661  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3440  , p=0.2174  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=10.9065 , p=0.2071  , df=8
# likelihood ratio test: chi2=10.8574 , p=0.2099  , df=8
# parameter F test:         F=1.3440  , p=0.2174  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2527  , p=0.2587  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=11.4552 , p=0.2458  , df=9
# likelihood ratio test: chi2=11.4009 , p=0.2492  , df=9
# parameter F test:         F=1.2527  , p=0.2587  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1275  , p=0.3377  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=11.4754 , p=0.3217  , df=10
# likelihood ratio test: chi2=11.4209 , p=0.3257  , df=10
# parameter F test:         F=1.1275  , p=0.3377  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.5967  , p=0.0581  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=3.6056  , p=0.0576  , df=1
# likelihood ratio test: chi2=3.6002  , p=0.0578  , df=1
# parameter F test:         F=3.5967  , p=0.0581  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.4251  , p=0.0329  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=6.8786  , p=0.0321  , df=2
# likelihood ratio test: chi2=6.8591  , p=0.0324  , df=2
# parameter F test:         F=3.4251  , p=0.0329  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.5335  , p=0.0555  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=7.6447  , p=0.0540  , df=3
# likelihood ratio test: chi2=7.6206  , p=0.0545  , df=3
# parameter F test:         F=2.5335  , p=0.0555  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.4324  , p=0.0458  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=9.8026  , p=0.0439  , df=4
# likelihood ratio test: chi2=9.7630  , p=0.0446  , df=4
# parameter F test:         F=2.4324  , p=0.0458  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.9050  , p=0.0907  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=9.6129  , p=0.0870  , df=5
# likelihood ratio test: chi2=9.5748  , p=0.0882  , df=5
# parameter F test:         F=1.9050  , p=0.0907  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.6634  , p=0.1265  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=10.0895 , p=0.1209  , df=6
# likelihood ratio test: chi2=10.0475 , p=0.1227  , df=6
# parameter F test:         F=1.6634  , p=0.1265  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.3756  , p=0.2117  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=9.7506  , p=0.2032  , df=7
# likelihood ratio test: chi2=9.7113  , p=0.2055  , df=7
# parameter F test:         F=1.3756  , p=0.2117  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3202  , p=0.2291  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=10.7131 , p=0.2185  , df=8
# likelihood ratio test: chi2=10.6656 , p=0.2214  , df=8
# parameter F test:         F=1.3202  , p=0.2291  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.1432  , p=0.3287  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=10.4538 , p=0.3150  , df=9
# likelihood ratio test: chi2=10.4086 , p=0.3184  , df=9
# parameter F test:         F=1.1432  , p=0.3287  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.0782  , p=0.3758  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=10.9738 , p=0.3596  , df=10
# likelihood ratio test: chi2=10.9239 , p=0.3635  , df=10
# parameter F test:         F=1.0782  , p=0.3758  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3656  , p=0.5455  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.3665  , p=0.5449  , df=1
# likelihood ratio test: chi2=0.3665  , p=0.5449  , df=1
# parameter F test:         F=0.3656  , p=0.5455  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.4176  , p=0.2427  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=2.8471  , p=0.2409  , df=2
# likelihood ratio test: chi2=2.8437  , p=0.2413  , df=2
# parameter F test:         F=1.4176  , p=0.2427  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1764  , p=0.3175  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=3.5496  , p=0.3144  , df=3
# likelihood ratio test: chi2=3.5444  , p=0.3150  , df=3
# parameter F test:         F=1.1764  , p=0.3175  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2138  , p=0.3031  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=4.8918  , p=0.2986  , df=4
# likelihood ratio test: chi2=4.8819  , p=0.2996  , df=4
# parameter F test:         F=1.2138  , p=0.3031  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0830  , p=0.3680  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=5.4647  , p=0.3618  , df=5
# likelihood ratio test: chi2=5.4523  , p=0.3632  , df=5
# parameter F test:         F=1.0830  , p=0.3680  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8690  , p=0.5170  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=5.2712  , p=0.5095  , df=6
# likelihood ratio test: chi2=5.2597  , p=0.5110  , df=6
# parameter F test:         F=0.8690  , p=0.5170  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8003  , p=0.5871  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=5.6726  , p=0.5785  , df=7
# likelihood ratio test: chi2=5.6593  , p=0.5800  , df=7
# parameter F test:         F=0.8003  , p=0.5871  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7583  , p=0.6399  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=6.1531  , p=0.6301  , df=8
# likelihood ratio test: chi2=6.1374  , p=0.6318  , df=8
# parameter F test:         F=0.7583  , p=0.6399  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7227  , p=0.6884  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=6.6092  , p=0.6777  , df=9
# likelihood ratio test: chi2=6.5911  , p=0.6796  , df=9
# parameter F test:         F=0.7227  , p=0.6884  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.7336  , p=0.6932  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=7.4671  , p=0.6807  , df=10
# likelihood ratio test: chi2=7.4440  , p=0.6830  , df=10
# parameter F test:         F=0.7336  , p=0.6932  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0011  , p=0.9731  , df_denom=1205, df_num=1
# ssr based chi2 test:   chi2=0.0011  , p=0.9731  , df=1
# likelihood ratio test: chi2=0.0011  , p=0.9731  , df=1
# parameter F test:         F=0.0011  , p=0.9731  , df_denom=1205, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1336  , p=0.8749  , df_denom=1202, df_num=2
# ssr based chi2 test:   chi2=0.2684  , p=0.8744  , df=2
# likelihood ratio test: chi2=0.2683  , p=0.8744  , df=2
# parameter F test:         F=0.1336  , p=0.8749  , df_denom=1202, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6716  , p=0.5695  , df_denom=1199, df_num=3
# ssr based chi2 test:   chi2=2.0265  , p=0.5669  , df=3
# likelihood ratio test: chi2=2.0248  , p=0.5673  , df=3
# parameter F test:         F=0.6716  , p=0.5695  , df_denom=1199, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7346  , p=0.5684  , df_denom=1196, df_num=4
# ssr based chi2 test:   chi2=2.9604  , p=0.5645  , df=4
# likelihood ratio test: chi2=2.9567  , p=0.5651  , df=4
# parameter F test:         F=0.7346  , p=0.5684  , df_denom=1196, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5780  , p=0.7169  , df_denom=1193, df_num=5
# ssr based chi2 test:   chi2=2.9169  , p=0.7128  , df=5
# likelihood ratio test: chi2=2.9133  , p=0.7133  , df=5
# parameter F test:         F=0.5780  , p=0.7169  , df_denom=1193, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5958  , p=0.7339  , df_denom=1190, df_num=6
# ssr based chi2 test:   chi2=3.6141  , p=0.7287  , df=6
# likelihood ratio test: chi2=3.6087  , p=0.7295  , df=6
# parameter F test:         F=0.5958  , p=0.7339  , df_denom=1190, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4932  , p=0.8400  , df_denom=1187, df_num=7
# ssr based chi2 test:   chi2=3.4964  , p=0.8356  , df=7
# likelihood ratio test: chi2=3.4913  , p=0.8361  , df=7
# parameter F test:         F=0.4932  , p=0.8400  , df_denom=1187, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8565  , p=0.5529  , df_denom=1184, df_num=8
# ssr based chi2 test:   chi2=6.9508  , p=0.5420  , df=8
# likelihood ratio test: chi2=6.9307  , p=0.5441  , df=8
# parameter F test:         F=0.8565  , p=0.5529  , df_denom=1184, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9096  , p=0.5159  , df_denom=1181, df_num=9
# ssr based chi2 test:   chi2=8.3183  , p=0.5024  , df=9
# likelihood ratio test: chi2=8.2896  , p=0.5052  , df=9
# parameter F test:         F=0.9096  , p=0.5159  , df_denom=1181, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8985  , p=0.5338  , df_denom=1178, df_num=10
# ssr based chi2 test:   chi2=9.1456  , p=0.5183  , df=10
# likelihood ratio test: chi2=9.1109  , p=0.5216  , df=10
# parameter F test:         F=0.8985  , p=0.5338  , df_denom=1178, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.1572  , p=0.0132  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=6.1725  , p=0.0130  , df=1
# likelihood ratio test: chi2=6.1568  , p=0.0131  , df=1
# parameter F test:         F=6.1572  , p=0.0132  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.6550  , p=0.0261  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=7.3403  , p=0.0255  , df=2
# likelihood ratio test: chi2=7.3181  , p=0.0258  , df=2
# parameter F test:         F=3.6550  , p=0.0261  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.6102  , p=0.0501  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=7.8764  , p=0.0486  , df=3
# likelihood ratio test: chi2=7.8508  , p=0.0492  , df=3
# parameter F test:         F=2.6102  , p=0.0501  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.1286  , p=0.0751  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=8.5786  , p=0.0725  , df=4
# likelihood ratio test: chi2=8.5482  , p=0.0734  , df=4
# parameter F test:         F=2.1286  , p=0.0751  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.9201  , p=0.0126  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=14.7351 , p=0.0116  , df=5
# likelihood ratio test: chi2=14.6458 , p=0.0120  , df=5
# parameter F test:         F=2.9201  , p=0.0126  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.4846  , p=0.0215  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=15.0704 , p=0.0197  , df=6
# likelihood ratio test: chi2=14.9769 , p=0.0204  , df=6
# parameter F test:         F=2.4846  , p=0.0215  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.1650  , p=0.0349  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=15.3461 , p=0.0318  , df=7
# likelihood ratio test: chi2=15.2490 , p=0.0329  , df=7
# parameter F test:         F=2.1650  , p=0.0349  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.0999  , p=0.0331  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=17.0403 , p=0.0297  , df=8
# likelihood ratio test: chi2=16.9206 , p=0.0309  , df=8
# parameter F test:         F=2.0999  , p=0.0331  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.0828  , p=0.0283  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=19.0466 , p=0.0248  , df=9
# likelihood ratio test: chi2=18.8971 , p=0.0261  , df=9
# parameter F test:         F=2.0828  , p=0.0283  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.8962  , p=0.0419  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=19.3000 , p=0.0366  , df=10
# likelihood ratio test: chi2=19.1465 , p=0.0384  , df=10
# parameter F test:         F=1.8962  , p=0.0419  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0002  , p=0.9897  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.0002  , p=0.9897  , df=1
# likelihood ratio test: chi2=0.0002  , p=0.9897  , df=1
# parameter F test:         F=0.0002  , p=0.9897  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4369  , p=0.6462  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=0.8774  , p=0.6449  , df=2
# likelihood ratio test: chi2=0.8771  , p=0.6450  , df=2
# parameter F test:         F=0.4369  , p=0.6462  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4121  , p=0.7444  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=1.2434  , p=0.7426  , df=3
# likelihood ratio test: chi2=1.2428  , p=0.7428  , df=3
# parameter F test:         F=0.4121  , p=0.7444  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3529  , p=0.8421  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=1.4221  , p=0.8403  , df=4
# likelihood ratio test: chi2=1.4212  , p=0.8405  , df=4
# parameter F test:         F=0.3529  , p=0.8421  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.3949  , p=0.8526  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=1.9926  , p=0.8502  , df=5
# likelihood ratio test: chi2=1.9909  , p=0.8504  , df=5
# parameter F test:         F=0.3949  , p=0.8526  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3212  , p=0.9261  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=1.9485  , p=0.9244  , df=6
# likelihood ratio test: chi2=1.9469  , p=0.9245  , df=6
# parameter F test:         F=0.3212  , p=0.9261  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4539  , p=0.8679  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=3.2172  , p=0.8642  , df=7
# likelihood ratio test: chi2=3.2129  , p=0.8646  , df=7
# parameter F test:         F=0.4539  , p=0.8679  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5159  , p=0.8452  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=4.1865  , p=0.8399  , df=8
# likelihood ratio test: chi2=4.1792  , p=0.8406  , df=8
# parameter F test:         F=0.5159  , p=0.8452  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6310  , p=0.7713  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=5.7700  , p=0.7627  , df=9
# likelihood ratio test: chi2=5.7562  , p=0.7640  , df=9
# parameter F test:         F=0.6310  , p=0.7713  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9045  , p=0.5282  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=9.2064  , p=0.5126  , df=10
# likelihood ratio test: chi2=9.1713  , p=0.5159  , df=10
# parameter F test:         F=0.9045  , p=0.5282  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7014  , p=0.4025  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.7032  , p=0.4017  , df=1
# likelihood ratio test: chi2=0.7030  , p=0.4018  , df=1
# parameter F test:         F=0.7014  , p=0.4025  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5032  , p=0.6047  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=1.0106  , p=0.6033  , df=2
# likelihood ratio test: chi2=1.0102  , p=0.6034  , df=2
# parameter F test:         F=0.5032  , p=0.6047  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3810  , p=0.7667  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=1.1497  , p=0.7651  , df=3
# likelihood ratio test: chi2=1.1491  , p=0.7652  , df=3
# parameter F test:         F=0.3810  , p=0.7667  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3789  , p=0.8238  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=1.5270  , p=0.8218  , df=4
# likelihood ratio test: chi2=1.5261  , p=0.8220  , df=4
# parameter F test:         F=0.3789  , p=0.8238  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4068  , p=0.8443  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=2.0528  , p=0.8418  , df=5
# likelihood ratio test: chi2=2.0510  , p=0.8420  , df=5
# parameter F test:         F=0.4068  , p=0.8443  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7897  , p=0.5780  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=4.7901  , p=0.5710  , df=6
# likelihood ratio test: chi2=4.7806  , p=0.5722  , df=6
# parameter F test:         F=0.7897  , p=0.5780  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6301  , p=0.7313  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=4.4667  , p=0.7247  , df=7
# likelihood ratio test: chi2=4.4585  , p=0.7257  , df=7
# parameter F test:         F=0.6301  , p=0.7313  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6390  , p=0.7453  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=5.1855  , p=0.7376  , df=8
# likelihood ratio test: chi2=5.1744  , p=0.7388  , df=8
# parameter F test:         F=0.6390  , p=0.7453  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5305  , p=0.8531  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=4.8514  , p=0.8471  , df=9
# likelihood ratio test: chi2=4.8416  , p=0.8479  , df=9
# parameter F test:         F=0.5305  , p=0.8531  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.5566  , p=0.8499  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=5.6648  , p=0.8426  , df=10
# likelihood ratio test: chi2=5.6515  , p=0.8436  , df=10
# parameter F test:         F=0.5566  , p=0.8499  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7014  , p=0.4025  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.7032  , p=0.4017  , df=1
# likelihood ratio test: chi2=0.7030  , p=0.4018  , df=1
# parameter F test:         F=0.7014  , p=0.4025  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5032  , p=0.6047  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=1.0106  , p=0.6033  , df=2
# likelihood ratio test: chi2=1.0102  , p=0.6034  , df=2
# parameter F test:         F=0.5032  , p=0.6047  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3810  , p=0.7667  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=1.1497  , p=0.7651  , df=3
# likelihood ratio test: chi2=1.1491  , p=0.7652  , df=3
# parameter F test:         F=0.3810  , p=0.7667  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3789  , p=0.8238  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=1.5270  , p=0.8218  , df=4
# likelihood ratio test: chi2=1.5261  , p=0.8220  , df=4
# parameter F test:         F=0.3789  , p=0.8238  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4068  , p=0.8443  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=2.0528  , p=0.8418  , df=5
# likelihood ratio test: chi2=2.0510  , p=0.8420  , df=5
# parameter F test:         F=0.4068  , p=0.8443  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7897  , p=0.5780  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=4.7901  , p=0.5710  , df=6
# likelihood ratio test: chi2=4.7806  , p=0.5722  , df=6
# parameter F test:         F=0.7897  , p=0.5780  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6301  , p=0.7313  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=4.4667  , p=0.7247  , df=7
# likelihood ratio test: chi2=4.4585  , p=0.7257  , df=7
# parameter F test:         F=0.6301  , p=0.7313  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6390  , p=0.7453  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=5.1855  , p=0.7376  , df=8
# likelihood ratio test: chi2=5.1744  , p=0.7388  , df=8
# parameter F test:         F=0.6390  , p=0.7453  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5305  , p=0.8531  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=4.8514  , p=0.8471  , df=9
# likelihood ratio test: chi2=4.8416  , p=0.8479  , df=9
# parameter F test:         F=0.5305  , p=0.8531  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.5566  , p=0.8499  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=5.6648  , p=0.8426  , df=10
# likelihood ratio test: chi2=5.6515  , p=0.8436  , df=10
# parameter F test:         F=0.5566  , p=0.8499  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=10.1779 , p=0.0015  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=10.2032 , p=0.0014  , df=1
# likelihood ratio test: chi2=10.1604 , p=0.0014  , df=1
# parameter F test:         F=10.1779 , p=0.0015  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.6651  , p=0.0036  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=11.3773 , p=0.0034  , df=2
# likelihood ratio test: chi2=11.3241 , p=0.0035  , df=2
# parameter F test:         F=5.6651  , p=0.0036  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.8242  , p=0.0096  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=11.5397 , p=0.0091  , df=3
# likelihood ratio test: chi2=11.4848 , p=0.0094  , df=3
# parameter F test:         F=3.8242  , p=0.0096  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.4987  , p=0.0075  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=14.1000 , p=0.0070  , df=4
# likelihood ratio test: chi2=14.0182 , p=0.0072  , df=4
# parameter F test:         F=3.4987  , p=0.0075  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.2492  , p=0.0064  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=16.3956 , p=0.0058  , df=5
# likelihood ratio test: chi2=16.2851 , p=0.0061  , df=5
# parameter F test:         F=3.2492  , p=0.0064  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.7412  , p=0.0119  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=16.6265 , p=0.0108  , df=6
# likelihood ratio test: chi2=16.5128 , p=0.0113  , df=6
# parameter F test:         F=2.7412  , p=0.0119  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.4956  , p=0.0151  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=17.6899 , p=0.0135  , df=7
# likelihood ratio test: chi2=17.5611 , p=0.0141  , df=7
# parameter F test:         F=2.4956  , p=0.0151  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.6721  , p=0.0065  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=21.6834 , p=0.0055  , df=8
# likelihood ratio test: chi2=21.4902 , p=0.0060  , df=8
# parameter F test:         F=2.6721  , p=0.0065  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.6929  , p=0.0042  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=24.6253 , p=0.0034  , df=9
# likelihood ratio test: chi2=24.3762 , p=0.0037  , df=9
# parameter F test:         F=2.6929  , p=0.0042  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.4714  , p=0.0063  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=25.1546 , p=0.0051  , df=10
# likelihood ratio test: chi2=24.8946 , p=0.0055  , df=10
# parameter F test:         F=2.4714  , p=0.0063  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.0391  , p=0.0447  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=4.0492  , p=0.0442  , df=1
# likelihood ratio test: chi2=4.0424  , p=0.0444  , df=1
# parameter F test:         F=4.0391  , p=0.0447  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.0311  , p=0.1316  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=4.0791  , p=0.1301  , df=2
# likelihood ratio test: chi2=4.0723  , p=0.1305  , df=2
# parameter F test:         F=2.0311  , p=0.1316  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.2009  , p=0.0863  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=6.6412  , p=0.0843  , df=3
# likelihood ratio test: chi2=6.6230  , p=0.0849  , df=3
# parameter F test:         F=2.2009  , p=0.0863  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.6597  , p=0.1570  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=6.6888  , p=0.1533  , df=4
# likelihood ratio test: chi2=6.6703  , p=0.1544  , df=4
# parameter F test:         F=1.6597  , p=0.1570  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.5656  , p=0.1669  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=7.9003  , p=0.1618  , df=5
# likelihood ratio test: chi2=7.8745  , p=0.1633  , df=5
# parameter F test:         F=1.5656  , p=0.1669  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3450  , p=0.2340  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=8.1583  , p=0.2267  , df=6
# likelihood ratio test: chi2=8.1308  , p=0.2287  , df=6
# parameter F test:         F=1.3450  , p=0.2340  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2393  , p=0.2778  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=8.7848  , p=0.2685  , df=7
# likelihood ratio test: chi2=8.7529  , p=0.2709  , df=7
# parameter F test:         F=1.2393  , p=0.2778  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2158  , p=0.2859  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=9.8660  , p=0.2746  , df=8
# likelihood ratio test: chi2=9.8258  , p=0.2775  , df=8
# parameter F test:         F=1.2158  , p=0.2859  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.7896  , p=0.0659  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=16.3655 , p=0.0596  , df=9
# likelihood ratio test: chi2=16.2550 , p=0.0617  , df=9
# parameter F test:         F=1.7896  , p=0.0659  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.7416  , p=0.0670  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=17.7263 , p=0.0598  , df=10
# likelihood ratio test: chi2=17.5967 , p=0.0622  , df=10
# parameter F test:         F=1.7416  , p=0.0670  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.9142  , p=0.0152  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=5.9289  , p=0.0149  , df=1
# likelihood ratio test: chi2=5.9145  , p=0.0150  , df=1
# parameter F test:         F=5.9142  , p=0.0152  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.2609  , p=0.0387  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=6.5490  , p=0.0378  , df=2
# likelihood ratio test: chi2=6.5313  , p=0.0382  , df=2
# parameter F test:         F=3.2609  , p=0.0387  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.2228  , p=0.0838  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=6.7074  , p=0.0818  , df=3
# likelihood ratio test: chi2=6.6888  , p=0.0825  , df=3
# parameter F test:         F=2.2228  , p=0.0838  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8122  , p=0.1241  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=7.3032  , p=0.1207  , df=4
# likelihood ratio test: chi2=7.2812  , p=0.1218  , df=4
# parameter F test:         F=1.8122  , p=0.1241  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.6167  , p=0.1526  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=8.1580  , p=0.1477  , df=5
# likelihood ratio test: chi2=8.1305  , p=0.1492  , df=5
# parameter F test:         F=1.6167  , p=0.1526  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.7605  , p=0.1039  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=10.6785 , p=0.0988  , df=6
# likelihood ratio test: chi2=10.6314 , p=0.1005  , df=6
# parameter F test:         F=1.7605  , p=0.1039  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.7488  , p=0.0940  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=12.3962 , p=0.0883  , df=7
# likelihood ratio test: chi2=12.3328 , p=0.0901  , df=7
# parameter F test:         F=1.7488  , p=0.0940  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.5790  , p=0.1265  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=12.8129 , p=0.1184  , df=8
# likelihood ratio test: chi2=12.7451 , p=0.1209  , df=8
# parameter F test:         F=1.5790  , p=0.1265  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.4543  , p=0.1601  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=13.2991 , p=0.1495  , df=9
# likelihood ratio test: chi2=13.2260 , p=0.1526  , df=9
# parameter F test:         F=1.4543  , p=0.1601  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2826  , p=0.2351  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=13.0540 , p=0.2207  , df=10
# likelihood ratio test: chi2=12.9835 , p=0.2246  , df=10
# parameter F test:         F=1.2826  , p=0.2351  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=14.3835 , p=0.0002  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=14.4192 , p=0.0001  , df=1
# likelihood ratio test: chi2=14.3339 , p=0.0002  , df=1
# parameter F test:         F=14.3835 , p=0.0002  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.1610  , p=0.0008  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=14.3814 , p=0.0008  , df=2
# likelihood ratio test: chi2=14.2965 , p=0.0008  , df=2
# parameter F test:         F=7.1610  , p=0.0008  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.7333  , p=0.0027  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=14.2829 , p=0.0025  , df=3
# likelihood ratio test: chi2=14.1990 , p=0.0026  , df=3
# parameter F test:         F=4.7333  , p=0.0027  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.0048  , p=0.0031  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=16.1396 , p=0.0028  , df=4
# likelihood ratio test: chi2=16.0326 , p=0.0030  , df=4
# parameter F test:         F=4.0048  , p=0.0031  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=4.1049  , p=0.0011  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=20.7136 , p=0.0009  , df=5
# likelihood ratio test: chi2=20.5376 , p=0.0010  , df=5
# parameter F test:         F=4.1049  , p=0.0011  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.6302  , p=0.0014  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=22.0192 , p=0.0012  , df=6
# likelihood ratio test: chi2=21.8203 , p=0.0013  , df=6
# parameter F test:         F=3.6302  , p=0.0014  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=3.1418  , p=0.0027  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=22.2705 , p=0.0023  , df=7
# likelihood ratio test: chi2=22.0669 , p=0.0025  , df=7
# parameter F test:         F=3.1418  , p=0.0027  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.9878  , p=0.0025  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=24.2450 , p=0.0021  , df=8
# likelihood ratio test: chi2=24.0037 , p=0.0023  , df=8
# parameter F test:         F=2.9878  , p=0.0025  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.7247  , p=0.0038  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=24.9166 , p=0.0031  , df=9
# likelihood ratio test: chi2=24.6617 , p=0.0034  , df=9
# parameter F test:         F=2.7247  , p=0.0038  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.3972  , p=0.0081  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=24.3989 , p=0.0066  , df=10
# likelihood ratio test: chi2=24.1542 , p=0.0072  , df=10
# parameter F test:         F=2.3972  , p=0.0081  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.5350  , p=0.2156  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=1.5388  , p=0.2148  , df=1
# likelihood ratio test: chi2=1.5378  , p=0.2149  , df=1
# parameter F test:         F=1.5350  , p=0.2156  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7921  , p=0.4531  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=1.5908  , p=0.4514  , df=2
# likelihood ratio test: chi2=1.5897  , p=0.4516  , df=2
# parameter F test:         F=0.7921  , p=0.4531  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0441  , p=0.3721  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=3.1505  , p=0.3690  , df=3
# likelihood ratio test: chi2=3.1464  , p=0.3696  , df=3
# parameter F test:         F=1.0441  , p=0.3721  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.1341  , p=0.0141  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=12.6305 , p=0.0132  , df=4
# likelihood ratio test: chi2=12.5648 , p=0.0136  , df=4
# parameter F test:         F=3.1341  , p=0.0141  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.5442  , p=0.0267  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=12.8384 , p=0.0249  , df=5
# likelihood ratio test: chi2=12.7705 , p=0.0256  , df=5
# parameter F test:         F=2.5442  , p=0.0267  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.1783  , p=0.0427  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=13.2128 , p=0.0398  , df=6
# likelihood ratio test: chi2=13.1408 , p=0.0409  , df=6
# parameter F test:         F=2.1783  , p=0.0427  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.0044  , p=0.0516  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=14.2082 , p=0.0476  , df=7
# likelihood ratio test: chi2=14.1249 , p=0.0490  , df=7
# parameter F test:         F=2.0044  , p=0.0516  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.7424  , p=0.0846  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=14.1395 , p=0.0782  , df=8
# likelihood ratio test: chi2=14.0570 , p=0.0803  , df=8
# parameter F test:         F=1.7424  , p=0.0846  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.6199  , p=0.1046  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=14.8137 , p=0.0962  , df=9
# likelihood ratio test: chi2=14.7231 , p=0.0988  , df=9
# parameter F test:         F=1.6199  , p=0.1046  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.4909  , p=0.1370  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=15.1742 , p=0.1258  , df=10
# likelihood ratio test: chi2=15.0790 , p=0.1292  , df=10
# parameter F test:         F=1.4909  , p=0.1370  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.6579  , p=0.0175  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=5.6720  , p=0.0172  , df=1
# likelihood ratio test: chi2=5.6587  , p=0.0174  , df=1
# parameter F test:         F=5.6579  , p=0.0175  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.9663  , p=0.0519  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=5.9572  , p=0.0509  , df=2
# likelihood ratio test: chi2=5.9426  , p=0.0512  , df=2
# parameter F test:         F=2.9663  , p=0.0519  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.0963  , p=0.0990  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=6.3257  , p=0.0968  , df=3
# likelihood ratio test: chi2=6.3092  , p=0.0975  , df=3
# parameter F test:         F=2.0963  , p=0.0990  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.6180  , p=0.1673  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=6.5206  , p=0.1635  , df=4
# likelihood ratio test: chi2=6.5031  , p=0.1646  , df=4
# parameter F test:         F=1.6180  , p=0.1673  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.4062  , p=0.2192  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=7.0957  , p=0.2136  , df=5
# likelihood ratio test: chi2=7.0749  , p=0.2151  , df=5
# parameter F test:         F=1.4062  , p=0.2192  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3228  , p=0.2438  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=8.0233  , p=0.2364  , df=6
# likelihood ratio test: chi2=7.9967  , p=0.2383  , df=6
# parameter F test:         F=1.3228  , p=0.2438  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1368  , p=0.3372  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=8.0583  , p=0.3275  , df=7
# likelihood ratio test: chi2=8.0315  , p=0.3298  , df=7
# parameter F test:         F=1.1368  , p=0.3372  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.0430  , p=0.4014  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=8.4637  , p=0.3895  , df=8
# likelihood ratio test: chi2=8.4340  , p=0.3923  , df=8
# parameter F test:         F=1.0430  , p=0.4014  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9462  , p=0.4836  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=8.6530  , p=0.4699  , df=9
# likelihood ratio test: chi2=8.6220  , p=0.4729  , df=9
# parameter F test:         F=0.9462  , p=0.4836  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9555  , p=0.4809  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=9.7254  , p=0.4649  , df=10
# likelihood ratio test: chi2=9.6862  , p=0.4684  , df=10
# parameter F test:         F=0.9555  , p=0.4809  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.7361  , p=0.0984  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=2.7429  , p=0.0977  , df=1
# likelihood ratio test: chi2=2.7398  , p=0.0979  , df=1
# parameter F test:         F=2.7361  , p=0.0984  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.8795  , p=0.0209  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=7.7912  , p=0.0203  , df=2
# likelihood ratio test: chi2=7.7662  , p=0.0206  , df=2
# parameter F test:         F=3.8795  , p=0.0209  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.6177  , p=0.0496  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=7.8989  , p=0.0481  , df=3
# likelihood ratio test: chi2=7.8732  , p=0.0487  , df=3
# parameter F test:         F=2.6177  , p=0.0496  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.2411  , p=0.0627  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=9.0320  , p=0.0603  , df=4
# likelihood ratio test: chi2=8.9983  , p=0.0611  , df=4
# parameter F test:         F=2.2411  , p=0.0627  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.8144  , p=0.1071  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=9.1557  , p=0.1030  , df=5
# likelihood ratio test: chi2=9.1211  , p=0.1043  , df=5
# parameter F test:         F=1.8144  , p=0.1071  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5299  , p=0.1648  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=9.2795  , p=0.1585  , df=6
# likelihood ratio test: chi2=9.2439  , p=0.1603  , df=6
# parameter F test:         F=1.5299  , p=0.1648  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.3856  , p=0.2074  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=9.8218  , p=0.1989  , df=7
# likelihood ratio test: chi2=9.7819  , p=0.2013  , df=7
# parameter F test:         F=1.3856  , p=0.2074  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2421  , p=0.2707  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=10.0795 , p=0.2595  , df=8
# likelihood ratio test: chi2=10.0374 , p=0.2624  , df=8
# parameter F test:         F=1.2421  , p=0.2707  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2569  , p=0.2563  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=11.4936 , p=0.2434  , df=9
# likelihood ratio test: chi2=11.4390 , p=0.2468  , df=9
# parameter F test:         F=1.2569  , p=0.2563  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.4063  , p=0.1718  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=14.3131 , p=0.1592  , df=10
# likelihood ratio test: chi2=14.2284 , p=0.1628  , df=10
# parameter F test:         F=1.4063  , p=0.1718  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1924  , p=0.6610  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.1929  , p=0.6605  , df=1
# likelihood ratio test: chi2=0.1929  , p=0.6605  , df=1
# parameter F test:         F=0.1924  , p=0.6610  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4141  , p=0.6611  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=0.8316  , p=0.6598  , df=2
# likelihood ratio test: chi2=0.8313  , p=0.6599  , df=2
# parameter F test:         F=0.4141  , p=0.6611  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6095  , p=0.6089  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=1.8390  , p=0.6065  , df=3
# likelihood ratio test: chi2=1.8376  , p=0.6068  , df=3
# parameter F test:         F=0.6095  , p=0.6089  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6218  , p=0.6470  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=2.5061  , p=0.6435  , df=4
# likelihood ratio test: chi2=2.5035  , p=0.6440  , df=4
# parameter F test:         F=0.6218  , p=0.6470  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5589  , p=0.7316  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=2.8200  , p=0.7277  , df=5
# likelihood ratio test: chi2=2.8167  , p=0.7282  , df=5
# parameter F test:         F=0.5589  , p=0.7316  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4807  , p=0.8231  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=2.9156  , p=0.8194  , df=6
# likelihood ratio test: chi2=2.9121  , p=0.8198  , df=6
# parameter F test:         F=0.4807  , p=0.8231  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5468  , p=0.7992  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=3.8757  , p=0.7940  , df=7
# likelihood ratio test: chi2=3.8694  , p=0.7947  , df=7
# parameter F test:         F=0.5468  , p=0.7992  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5356  , p=0.8303  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=4.3462  , p=0.8246  , df=8
# likelihood ratio test: chi2=4.3384  , p=0.8254  , df=8
# parameter F test:         F=0.5356  , p=0.8303  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.8758  , p=0.5464  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=8.0089  , p=0.5332  , df=9
# likelihood ratio test: chi2=7.9824  , p=0.5359  , df=9
# parameter F test:         F=0.8758  , p=0.5464  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.7793  , p=0.6490  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=7.9314  , p=0.6355  , df=10
# likelihood ratio test: chi2=7.9053  , p=0.6381  , df=10
# parameter F test:         F=0.7793  , p=0.6490  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.5180  , p=0.2182  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=1.5217  , p=0.2174  , df=1
# likelihood ratio test: chi2=1.5208  , p=0.2175  , df=1
# parameter F test:         F=1.5180  , p=0.2182  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1606  , p=0.3137  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=2.3308  , p=0.3118  , df=2
# likelihood ratio test: chi2=2.3285  , p=0.3122  , df=2
# parameter F test:         F=1.1606  , p=0.3137  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8582  , p=0.4623  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=2.5895  , p=0.4593  , df=3
# likelihood ratio test: chi2=2.5867  , p=0.4598  , df=3
# parameter F test:         F=0.8582  , p=0.4623  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6557  , p=0.6229  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=2.6425  , p=0.6193  , df=4
# likelihood ratio test: chi2=2.6396  , p=0.6198  , df=4
# parameter F test:         F=0.6557  , p=0.6229  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5109  , p=0.7682  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=2.5782  , p=0.7647  , df=5
# likelihood ratio test: chi2=2.5755  , p=0.7651  , df=5
# parameter F test:         F=0.5109  , p=0.7682  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4590  , p=0.8389  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=2.7838  , p=0.8355  , df=6
# likelihood ratio test: chi2=2.7806  , p=0.8358  , df=6
# parameter F test:         F=0.4590  , p=0.8389  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.9568  , p=0.4615  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=6.7824  , p=0.4519  , df=7
# likelihood ratio test: chi2=6.7634  , p=0.4539  , df=7
# parameter F test:         F=0.9568  , p=0.4615  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8929  , p=0.5216  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=7.2460  , p=0.5103  , df=8
# likelihood ratio test: chi2=7.2242  , p=0.5126  , df=8
# parameter F test:         F=0.8929  , p=0.5216  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.4669  , p=0.1552  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=13.4146 , p=0.1447  , df=9
# likelihood ratio test: chi2=13.3402 , p=0.1478  , df=9
# parameter F test:         F=1.4669  , p=0.1552  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2834  , p=0.2346  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=13.0631 , p=0.2202  , df=10
# likelihood ratio test: chi2=12.9925 , p=0.2241  , df=10
# parameter F test:         F=1.2834  , p=0.2346  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4767  , p=0.2245  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=1.4804  , p=0.2237  , df=1
# likelihood ratio test: chi2=1.4795  , p=0.2239  , df=1
# parameter F test:         F=1.4767  , p=0.2245  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1331  , p=0.3224  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=2.2757  , p=0.3205  , df=2
# likelihood ratio test: chi2=2.2736  , p=0.3209  , df=2
# parameter F test:         F=1.1331  , p=0.3224  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8053  , p=0.4910  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=2.4299  , p=0.4881  , df=3
# likelihood ratio test: chi2=2.4275  , p=0.4885  , df=3
# parameter F test:         F=0.8053  , p=0.4910  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5851  , p=0.6735  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=2.3582  , p=0.6702  , df=4
# likelihood ratio test: chi2=2.3559  , p=0.6706  , df=4
# parameter F test:         F=0.5851  , p=0.6735  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5262  , p=0.7566  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=2.6552  , p=0.7530  , df=5
# likelihood ratio test: chi2=2.6522  , p=0.7534  , df=5
# parameter F test:         F=0.5262  , p=0.7566  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5020  , p=0.8072  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=3.0449  , p=0.8032  , df=6
# likelihood ratio test: chi2=3.0410  , p=0.8037  , df=6
# parameter F test:         F=0.5020  , p=0.8072  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2540  , p=0.2701  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=8.8886  , p=0.2608  , df=7
# likelihood ratio test: chi2=8.8559  , p=0.2632  , df=7
# parameter F test:         F=1.2540  , p=0.2701  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1740  , p=0.3114  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=9.5269  , p=0.2998  , df=8
# likelihood ratio test: chi2=9.4893  , p=0.3027  , df=8
# parameter F test:         F=1.1740  , p=0.3114  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.5940  , p=0.1120  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=14.5768 , p=0.1032  , df=9
# likelihood ratio test: chi2=14.4891 , p=0.1060  , df=9
# parameter F test:         F=1.5940  , p=0.1120  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3858  , p=0.1812  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=14.1047 , p=0.1683  , df=10
# likelihood ratio test: chi2=14.0224 , p=0.1720  , df=10
# parameter F test:         F=1.3858  , p=0.1812  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.3820  , p=0.0117  , df_denom=1205, df_num=1
# ssr based chi2 test:   chi2=6.3979  , p=0.0114  , df=1
# likelihood ratio test: chi2=6.3810  , p=0.0115  , df=1
# parameter F test:         F=6.3820  , p=0.0117  , df_denom=1205, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.5707  , p=0.0284  , df_denom=1202, df_num=2
# ssr based chi2 test:   chi2=7.1711  , p=0.0277  , df=2
# likelihood ratio test: chi2=7.1499  , p=0.0280  , df=2
# parameter F test:         F=3.5707  , p=0.0284  , df_denom=1202, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.4505  , p=0.0620  , df_denom=1199, df_num=3
# ssr based chi2 test:   chi2=7.3943  , p=0.0603  , df=3
# likelihood ratio test: chi2=7.3717  , p=0.0609  , df=3
# parameter F test:         F=2.4505  , p=0.0620  , df_denom=1199, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8095  , p=0.1246  , df_denom=1196, df_num=4
# ssr based chi2 test:   chi2=7.2926  , p=0.1212  , df=4
# likelihood ratio test: chi2=7.2706  , p=0.1223  , df=4
# parameter F test:         F=1.8095  , p=0.1246  , df_denom=1196, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.4383  , p=0.2077  , df_denom=1193, df_num=5
# ssr based chi2 test:   chi2=7.2578  , p=0.2022  , df=5
# likelihood ratio test: chi2=7.2360  , p=0.2037  , df=5
# parameter F test:         F=1.4383  , p=0.2077  , df_denom=1193, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4992  , p=0.1749  , df_denom=1190, df_num=6
# ssr based chi2 test:   chi2=9.0934  , p=0.1684  , df=6
# likelihood ratio test: chi2=9.0592  , p=0.1703  , df=6
# parameter F test:         F=1.4992  , p=0.1749  , df_denom=1190, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4670  , p=0.1750  , df_denom=1187, df_num=7
# ssr based chi2 test:   chi2=10.3988 , p=0.1671  , df=7
# likelihood ratio test: chi2=10.3540 , p=0.1694  , df=7
# parameter F test:         F=1.4670  , p=0.1750  , df_denom=1187, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2606  , p=0.2603  , df_denom=1184, df_num=8
# ssr based chi2 test:   chi2=10.2298 , p=0.2493  , df=8
# likelihood ratio test: chi2=10.1865 , p=0.2522  , df=8
# parameter F test:         F=1.2606  , p=0.2603  , df_denom=1184, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0869  , p=0.3694  , df_denom=1181, df_num=9
# ssr based chi2 test:   chi2=9.9392  , p=0.3554  , df=9
# likelihood ratio test: chi2=9.8982  , p=0.3588  , df=9
# parameter F test:         F=1.0869  , p=0.3694  , df_denom=1181, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.0664  , p=0.3853  , df_denom=1178, df_num=10
# ssr based chi2 test:   chi2=10.8541 , p=0.3690  , df=10
# likelihood ratio test: chi2=10.8053 , p=0.3729  , df=10
# parameter F test:         F=1.0664  , p=0.3853  , df_denom=1178, df_num=10

# %%
GC_stock
# Out:
# ['ALV',
#  'BAC',
#  'CADUSD=X',
#  'F',
#  'GM',
#  'JCI',
#  'JPM',
#  'TM',
#  'TRYUSD=X',
#  'WFC',
#  'X',
#  'ALI=F']

# %%
optimal_lag
# Out:
# [np.int64(2),
#  np.int64(1),
#  np.int64(2),
#  np.int64(5),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(4),
#  np.int64(1),
#  np.int64(2),
#  np.int64(1)]

# %% [markdown]
# From this table, we found that the followings causality:
# - Tesla causes Meta, Ford, Palladium
# - Apple causes Microsoft, NVIDIA, Amazon, Meta, Gold, Palladium
# - Google causes Microsoft, Amazon, Meta, Oil, Ford, Palladium
# - Microsoft causes Apple, Google, Amazon, Meta, Gold, Ford, Palladium
# - NVIDIA causes Google, Microsoft, Amazon, Meta, Gold
# - Amazon causes Tesla, TGold, Ford, Palladium
# - Meta causes Amazon, TSMC, Ford, Palladium
# - TSMC causes Apple, Gold, Ford, Palladium
# - Gold causes Oil, Palladium
# - Oil causes Google, Microsoft, Gold, Palladium
# - Ford causes Tesla, NVIDIA, TSMC, Gold, Oil, Palladium
# - Palladium causes Tesla

# %% [markdown]
# ## Definition

# %%
ticker = ['ALV','ASEKY','BAC','CADUSD=X','CHFUSD=X','CL=F','F','FDX','GBPUSD=X','GBPUSD=X','GM','JCI','JPM','TM',
         'TRYUSD=X','WFC','X','^DJI','^GSPC','^IXIC','ALI=F']

GC_stock = []
optimal_lag = []

#def gc_test(df):

for t in ticker:
    df1 = df[['DNZOY', t]].copy()
    test_result = grangercausalitytests(df1.dropna(), maxlag=10)
    p_values = [round(test_result[i+1][0]['ssr_ftest'][1],4) for i in range(10)]
    min_p_value = np.min(p_values)
    if min_p_value < 0.05:
        GC_stock.append(t)
        optimal_lag.append(1 + np.argmin(p_values))
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.5546  , p=0.0106  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=6.5709  , p=0.0104  , df=1
# likelihood ratio test: chi2=6.5531  , p=0.0105  , df=1
# parameter F test:         F=6.5546  , p=0.0106  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.3995  , p=0.0046  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=10.8440 , p=0.0044  , df=2
# likelihood ratio test: chi2=10.7956 , p=0.0045  , df=2
# parameter F test:         F=5.3995  , p=0.0046  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.6058  , p=0.0130  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=10.8806 , p=0.0124  , df=3
# likelihood ratio test: chi2=10.8319 , p=0.0127  , df=3
# parameter F test:         F=3.6058  , p=0.0130  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.8281  , p=0.0237  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=11.3976 , p=0.0224  , df=4
# likelihood ratio test: chi2=11.3441 , p=0.0230  , df=4
# parameter F test:         F=2.8281  , p=0.0237  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.6304  , p=0.0225  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=13.2731 , p=0.0209  , df=5
# likelihood ratio test: chi2=13.2006 , p=0.0216  , df=5
# parameter F test:         F=2.6304  , p=0.0225  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.3674  , p=0.0281  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=14.3596 , p=0.0259  , df=6
# likelihood ratio test: chi2=14.2746 , p=0.0267  , df=6
# parameter F test:         F=2.3674  , p=0.0281  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.0945  , p=0.0415  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=14.8464 , p=0.0380  , df=7
# likelihood ratio test: chi2=14.7556 , p=0.0393  , df=7
# parameter F test:         F=2.0945  , p=0.0415  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.8601  , p=0.0626  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=15.0945 , p=0.0573  , df=8
# likelihood ratio test: chi2=15.0005 , p=0.0591  , df=8
# parameter F test:         F=1.8601  , p=0.0626  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.3403  , p=0.0129  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=21.4011 , p=0.0110  , df=9
# likelihood ratio test: chi2=21.2127 , p=0.0117  , df=9
# parameter F test:         F=2.3403  , p=0.0129  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.2211  , p=0.0147  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=22.6064 , p=0.0123  , df=10
# likelihood ratio test: chi2=22.3961 , p=0.0132  , df=10
# parameter F test:         F=2.2211  , p=0.0147  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.0325  , p=0.3098  , df_denom=1205, df_num=1
# ssr based chi2 test:   chi2=1.0350  , p=0.3090  , df=1
# likelihood ratio test: chi2=1.0346  , p=0.3091  , df=1
# parameter F test:         F=1.0325  , p=0.3098  , df_denom=1205, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5229  , p=0.5929  , df_denom=1202, df_num=2
# ssr based chi2 test:   chi2=1.0501  , p=0.5915  , df=2
# likelihood ratio test: chi2=1.0497  , p=0.5917  , df=2
# parameter F test:         F=0.5229  , p=0.5929  , df_denom=1202, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4683  , p=0.7044  , df_denom=1199, df_num=3
# ssr based chi2 test:   chi2=1.4131  , p=0.7025  , df=3
# likelihood ratio test: chi2=1.4123  , p=0.7027  , df=3
# parameter F test:         F=0.4683  , p=0.7044  , df_denom=1199, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5900  , p=0.6699  , df_denom=1196, df_num=4
# ssr based chi2 test:   chi2=2.3778  , p=0.6666  , df=4
# likelihood ratio test: chi2=2.3754  , p=0.6671  , df=4
# parameter F test:         F=0.5900  , p=0.6699  , df_denom=1196, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2438  , p=0.2862  , df_denom=1193, df_num=5
# ssr based chi2 test:   chi2=6.2766  , p=0.2802  , df=5
# likelihood ratio test: chi2=6.2603  , p=0.2817  , df=5
# parameter F test:         F=1.2438  , p=0.2862  , df_denom=1193, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0067  , p=0.4193  , df_denom=1190, df_num=6
# ssr based chi2 test:   chi2=6.1063  , p=0.4114  , df=6
# likelihood ratio test: chi2=6.0909  , p=0.4131  , df=6
# parameter F test:         F=1.0067  , p=0.4193  , df_denom=1190, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8673  , p=0.5318  , df_denom=1187, df_num=7
# ssr based chi2 test:   chi2=6.1478  , p=0.5226  , df=7
# likelihood ratio test: chi2=6.1321  , p=0.5244  , df=7
# parameter F test:         F=0.8673  , p=0.5318  , df_denom=1187, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7192  , p=0.6747  , df_denom=1184, df_num=8
# ssr based chi2 test:   chi2=5.8363  , p=0.6656  , df=8
# likelihood ratio test: chi2=5.8221  , p=0.6671  , df=8
# parameter F test:         F=0.7192  , p=0.6747  , df_denom=1184, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6940  , p=0.7149  , df_denom=1181, df_num=9
# ssr based chi2 test:   chi2=6.3466  , p=0.7048  , df=9
# likelihood ratio test: chi2=6.3299  , p=0.7065  , df=9
# parameter F test:         F=0.6940  , p=0.7149  , df_denom=1181, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.6320  , p=0.7873  , df_denom=1178, df_num=10
# ssr based chi2 test:   chi2=6.4328  , p=0.7777  , df=10
# likelihood ratio test: chi2=6.4156  , p=0.7792  , df=10
# parameter F test:         F=0.6320  , p=0.7873  , df_denom=1178, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.5151  , p=0.0338  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=4.5264  , p=0.0334  , df=1
# likelihood ratio test: chi2=4.5179  , p=0.0335  , df=1
# parameter F test:         F=4.5151  , p=0.0338  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.4124  , p=0.0900  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=4.8448  , p=0.0887  , df=2
# likelihood ratio test: chi2=4.8351  , p=0.0891  , df=2
# parameter F test:         F=2.4124  , p=0.0900  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.7199  , p=0.1611  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=5.1897  , p=0.1584  , df=3
# likelihood ratio test: chi2=5.1786  , p=0.1592  , df=3
# parameter F test:         F=1.7199  , p=0.1611  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.4664  , p=0.2101  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=5.9098  , p=0.2060  , df=4
# likelihood ratio test: chi2=5.8954  , p=0.2071  , df=4
# parameter F test:         F=1.4664  , p=0.2101  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.6672  , p=0.1396  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=8.4128  , p=0.1349  , df=5
# likelihood ratio test: chi2=8.3836  , p=0.1363  , df=5
# parameter F test:         F=1.6672  , p=0.1396  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.7347  , p=0.1095  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=10.5219 , p=0.1043  , df=6
# likelihood ratio test: chi2=10.4762 , p=0.1060  , df=6
# parameter F test:         F=1.7347  , p=0.1095  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4917  , p=0.1661  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=10.5740 , p=0.1583  , df=7
# likelihood ratio test: chi2=10.5278 , p=0.1606  , df=7
# parameter F test:         F=1.4917  , p=0.1661  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3440  , p=0.2174  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=10.9065 , p=0.2071  , df=8
# likelihood ratio test: chi2=10.8574 , p=0.2099  , df=8
# parameter F test:         F=1.3440  , p=0.2174  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2527  , p=0.2587  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=11.4552 , p=0.2458  , df=9
# likelihood ratio test: chi2=11.4009 , p=0.2492  , df=9
# parameter F test:         F=1.2527  , p=0.2587  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1275  , p=0.3377  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=11.4754 , p=0.3217  , df=10
# likelihood ratio test: chi2=11.4209 , p=0.3257  , df=10
# parameter F test:         F=1.1275  , p=0.3377  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.5967  , p=0.0581  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=3.6056  , p=0.0576  , df=1
# likelihood ratio test: chi2=3.6002  , p=0.0578  , df=1
# parameter F test:         F=3.5967  , p=0.0581  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.4251  , p=0.0329  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=6.8786  , p=0.0321  , df=2
# likelihood ratio test: chi2=6.8591  , p=0.0324  , df=2
# parameter F test:         F=3.4251  , p=0.0329  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.5335  , p=0.0555  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=7.6447  , p=0.0540  , df=3
# likelihood ratio test: chi2=7.6206  , p=0.0545  , df=3
# parameter F test:         F=2.5335  , p=0.0555  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.4324  , p=0.0458  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=9.8026  , p=0.0439  , df=4
# likelihood ratio test: chi2=9.7630  , p=0.0446  , df=4
# parameter F test:         F=2.4324  , p=0.0458  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.9050  , p=0.0907  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=9.6129  , p=0.0870  , df=5
# likelihood ratio test: chi2=9.5748  , p=0.0882  , df=5
# parameter F test:         F=1.9050  , p=0.0907  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.6634  , p=0.1265  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=10.0895 , p=0.1209  , df=6
# likelihood ratio test: chi2=10.0475 , p=0.1227  , df=6
# parameter F test:         F=1.6634  , p=0.1265  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.3756  , p=0.2117  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=9.7506  , p=0.2032  , df=7
# likelihood ratio test: chi2=9.7113  , p=0.2055  , df=7
# parameter F test:         F=1.3756  , p=0.2117  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3202  , p=0.2291  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=10.7131 , p=0.2185  , df=8
# likelihood ratio test: chi2=10.6656 , p=0.2214  , df=8
# parameter F test:         F=1.3202  , p=0.2291  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.1432  , p=0.3287  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=10.4538 , p=0.3150  , df=9
# likelihood ratio test: chi2=10.4086 , p=0.3184  , df=9
# parameter F test:         F=1.1432  , p=0.3287  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.0782  , p=0.3758  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=10.9738 , p=0.3596  , df=10
# likelihood ratio test: chi2=10.9239 , p=0.3635  , df=10
# parameter F test:         F=1.0782  , p=0.3758  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3656  , p=0.5455  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.3665  , p=0.5449  , df=1
# likelihood ratio test: chi2=0.3665  , p=0.5449  , df=1
# parameter F test:         F=0.3656  , p=0.5455  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.4176  , p=0.2427  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=2.8471  , p=0.2409  , df=2
# likelihood ratio test: chi2=2.8437  , p=0.2413  , df=2
# parameter F test:         F=1.4176  , p=0.2427  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1764  , p=0.3175  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=3.5496  , p=0.3144  , df=3
# likelihood ratio test: chi2=3.5444  , p=0.3150  , df=3
# parameter F test:         F=1.1764  , p=0.3175  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2138  , p=0.3031  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=4.8918  , p=0.2986  , df=4
# likelihood ratio test: chi2=4.8819  , p=0.2996  , df=4
# parameter F test:         F=1.2138  , p=0.3031  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.0830  , p=0.3680  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=5.4647  , p=0.3618  , df=5
# likelihood ratio test: chi2=5.4523  , p=0.3632  , df=5
# parameter F test:         F=1.0830  , p=0.3680  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8690  , p=0.5170  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=5.2712  , p=0.5095  , df=6
# likelihood ratio test: chi2=5.2597  , p=0.5110  , df=6
# parameter F test:         F=0.8690  , p=0.5170  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8003  , p=0.5871  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=5.6726  , p=0.5785  , df=7
# likelihood ratio test: chi2=5.6593  , p=0.5800  , df=7
# parameter F test:         F=0.8003  , p=0.5871  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.7583  , p=0.6399  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=6.1531  , p=0.6301  , df=8
# likelihood ratio test: chi2=6.1374  , p=0.6318  , df=8
# parameter F test:         F=0.7583  , p=0.6399  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7227  , p=0.6884  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=6.6092  , p=0.6777  , df=9
# likelihood ratio test: chi2=6.5911  , p=0.6796  , df=9
# parameter F test:         F=0.7227  , p=0.6884  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.7336  , p=0.6932  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=7.4671  , p=0.6807  , df=10
# likelihood ratio test: chi2=7.4440  , p=0.6830  , df=10
# parameter F test:         F=0.7336  , p=0.6932  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0011  , p=0.9731  , df_denom=1205, df_num=1
# ssr based chi2 test:   chi2=0.0011  , p=0.9731  , df=1
# likelihood ratio test: chi2=0.0011  , p=0.9731  , df=1
# parameter F test:         F=0.0011  , p=0.9731  , df_denom=1205, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1336  , p=0.8749  , df_denom=1202, df_num=2
# ssr based chi2 test:   chi2=0.2684  , p=0.8744  , df=2
# likelihood ratio test: chi2=0.2683  , p=0.8744  , df=2
# parameter F test:         F=0.1336  , p=0.8749  , df_denom=1202, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6716  , p=0.5695  , df_denom=1199, df_num=3
# ssr based chi2 test:   chi2=2.0265  , p=0.5669  , df=3
# likelihood ratio test: chi2=2.0248  , p=0.5673  , df=3
# parameter F test:         F=0.6716  , p=0.5695  , df_denom=1199, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7346  , p=0.5684  , df_denom=1196, df_num=4
# ssr based chi2 test:   chi2=2.9604  , p=0.5645  , df=4
# likelihood ratio test: chi2=2.9567  , p=0.5651  , df=4
# parameter F test:         F=0.7346  , p=0.5684  , df_denom=1196, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5780  , p=0.7169  , df_denom=1193, df_num=5
# ssr based chi2 test:   chi2=2.9169  , p=0.7128  , df=5
# likelihood ratio test: chi2=2.9133  , p=0.7133  , df=5
# parameter F test:         F=0.5780  , p=0.7169  , df_denom=1193, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5958  , p=0.7339  , df_denom=1190, df_num=6
# ssr based chi2 test:   chi2=3.6141  , p=0.7287  , df=6
# likelihood ratio test: chi2=3.6087  , p=0.7295  , df=6
# parameter F test:         F=0.5958  , p=0.7339  , df_denom=1190, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4932  , p=0.8400  , df_denom=1187, df_num=7
# ssr based chi2 test:   chi2=3.4964  , p=0.8356  , df=7
# likelihood ratio test: chi2=3.4913  , p=0.8361  , df=7
# parameter F test:         F=0.4932  , p=0.8400  , df_denom=1187, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8565  , p=0.5529  , df_denom=1184, df_num=8
# ssr based chi2 test:   chi2=6.9508  , p=0.5420  , df=8
# likelihood ratio test: chi2=6.9307  , p=0.5441  , df=8
# parameter F test:         F=0.8565  , p=0.5529  , df_denom=1184, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9096  , p=0.5159  , df_denom=1181, df_num=9
# ssr based chi2 test:   chi2=8.3183  , p=0.5024  , df=9
# likelihood ratio test: chi2=8.2896  , p=0.5052  , df=9
# parameter F test:         F=0.9096  , p=0.5159  , df_denom=1181, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8985  , p=0.5338  , df_denom=1178, df_num=10
# ssr based chi2 test:   chi2=9.1456  , p=0.5183  , df=10
# likelihood ratio test: chi2=9.1109  , p=0.5216  , df=10
# parameter F test:         F=0.8985  , p=0.5338  , df_denom=1178, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.1572  , p=0.0132  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=6.1725  , p=0.0130  , df=1
# likelihood ratio test: chi2=6.1568  , p=0.0131  , df=1
# parameter F test:         F=6.1572  , p=0.0132  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.6550  , p=0.0261  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=7.3403  , p=0.0255  , df=2
# likelihood ratio test: chi2=7.3181  , p=0.0258  , df=2
# parameter F test:         F=3.6550  , p=0.0261  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.6102  , p=0.0501  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=7.8764  , p=0.0486  , df=3
# likelihood ratio test: chi2=7.8508  , p=0.0492  , df=3
# parameter F test:         F=2.6102  , p=0.0501  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.1286  , p=0.0751  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=8.5786  , p=0.0725  , df=4
# likelihood ratio test: chi2=8.5482  , p=0.0734  , df=4
# parameter F test:         F=2.1286  , p=0.0751  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.9201  , p=0.0126  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=14.7351 , p=0.0116  , df=5
# likelihood ratio test: chi2=14.6458 , p=0.0120  , df=5
# parameter F test:         F=2.9201  , p=0.0126  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.4846  , p=0.0215  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=15.0704 , p=0.0197  , df=6
# likelihood ratio test: chi2=14.9769 , p=0.0204  , df=6
# parameter F test:         F=2.4846  , p=0.0215  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.1650  , p=0.0349  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=15.3461 , p=0.0318  , df=7
# likelihood ratio test: chi2=15.2490 , p=0.0329  , df=7
# parameter F test:         F=2.1650  , p=0.0349  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.0999  , p=0.0331  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=17.0403 , p=0.0297  , df=8
# likelihood ratio test: chi2=16.9206 , p=0.0309  , df=8
# parameter F test:         F=2.0999  , p=0.0331  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.0828  , p=0.0283  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=19.0466 , p=0.0248  , df=9
# likelihood ratio test: chi2=18.8971 , p=0.0261  , df=9
# parameter F test:         F=2.0828  , p=0.0283  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.8962  , p=0.0419  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=19.3000 , p=0.0366  , df=10
# likelihood ratio test: chi2=19.1465 , p=0.0384  , df=10
# parameter F test:         F=1.8962  , p=0.0419  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0002  , p=0.9897  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.0002  , p=0.9897  , df=1
# likelihood ratio test: chi2=0.0002  , p=0.9897  , df=1
# parameter F test:         F=0.0002  , p=0.9897  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4369  , p=0.6462  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=0.8774  , p=0.6449  , df=2
# likelihood ratio test: chi2=0.8771  , p=0.6450  , df=2
# parameter F test:         F=0.4369  , p=0.6462  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4121  , p=0.7444  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=1.2434  , p=0.7426  , df=3
# likelihood ratio test: chi2=1.2428  , p=0.7428  , df=3
# parameter F test:         F=0.4121  , p=0.7444  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3529  , p=0.8421  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=1.4221  , p=0.8403  , df=4
# likelihood ratio test: chi2=1.4212  , p=0.8405  , df=4
# parameter F test:         F=0.3529  , p=0.8421  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.3949  , p=0.8526  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=1.9926  , p=0.8502  , df=5
# likelihood ratio test: chi2=1.9909  , p=0.8504  , df=5
# parameter F test:         F=0.3949  , p=0.8526  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3212  , p=0.9261  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=1.9485  , p=0.9244  , df=6
# likelihood ratio test: chi2=1.9469  , p=0.9245  , df=6
# parameter F test:         F=0.3212  , p=0.9261  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4539  , p=0.8679  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=3.2172  , p=0.8642  , df=7
# likelihood ratio test: chi2=3.2129  , p=0.8646  , df=7
# parameter F test:         F=0.4539  , p=0.8679  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5159  , p=0.8452  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=4.1865  , p=0.8399  , df=8
# likelihood ratio test: chi2=4.1792  , p=0.8406  , df=8
# parameter F test:         F=0.5159  , p=0.8452  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6310  , p=0.7713  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=5.7700  , p=0.7627  , df=9
# likelihood ratio test: chi2=5.7562  , p=0.7640  , df=9
# parameter F test:         F=0.6310  , p=0.7713  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9045  , p=0.5282  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=9.2064  , p=0.5126  , df=10
# likelihood ratio test: chi2=9.1713  , p=0.5159  , df=10
# parameter F test:         F=0.9045  , p=0.5282  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7014  , p=0.4025  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.7032  , p=0.4017  , df=1
# likelihood ratio test: chi2=0.7030  , p=0.4018  , df=1
# parameter F test:         F=0.7014  , p=0.4025  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5032  , p=0.6047  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=1.0106  , p=0.6033  , df=2
# likelihood ratio test: chi2=1.0102  , p=0.6034  , df=2
# parameter F test:         F=0.5032  , p=0.6047  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3810  , p=0.7667  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=1.1497  , p=0.7651  , df=3
# likelihood ratio test: chi2=1.1491  , p=0.7652  , df=3
# parameter F test:         F=0.3810  , p=0.7667  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3789  , p=0.8238  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=1.5270  , p=0.8218  , df=4
# likelihood ratio test: chi2=1.5261  , p=0.8220  , df=4
# parameter F test:         F=0.3789  , p=0.8238  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4068  , p=0.8443  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=2.0528  , p=0.8418  , df=5
# likelihood ratio test: chi2=2.0510  , p=0.8420  , df=5
# parameter F test:         F=0.4068  , p=0.8443  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7897  , p=0.5780  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=4.7901  , p=0.5710  , df=6
# likelihood ratio test: chi2=4.7806  , p=0.5722  , df=6
# parameter F test:         F=0.7897  , p=0.5780  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6301  , p=0.7313  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=4.4667  , p=0.7247  , df=7
# likelihood ratio test: chi2=4.4585  , p=0.7257  , df=7
# parameter F test:         F=0.6301  , p=0.7313  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6390  , p=0.7453  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=5.1855  , p=0.7376  , df=8
# likelihood ratio test: chi2=5.1744  , p=0.7388  , df=8
# parameter F test:         F=0.6390  , p=0.7453  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5305  , p=0.8531  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=4.8514  , p=0.8471  , df=9
# likelihood ratio test: chi2=4.8416  , p=0.8479  , df=9
# parameter F test:         F=0.5305  , p=0.8531  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.5566  , p=0.8499  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=5.6648  , p=0.8426  , df=10
# likelihood ratio test: chi2=5.6515  , p=0.8436  , df=10
# parameter F test:         F=0.5566  , p=0.8499  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.7014  , p=0.4025  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.7032  , p=0.4017  , df=1
# likelihood ratio test: chi2=0.7030  , p=0.4018  , df=1
# parameter F test:         F=0.7014  , p=0.4025  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5032  , p=0.6047  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=1.0106  , p=0.6033  , df=2
# likelihood ratio test: chi2=1.0102  , p=0.6034  , df=2
# parameter F test:         F=0.5032  , p=0.6047  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3810  , p=0.7667  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=1.1497  , p=0.7651  , df=3
# likelihood ratio test: chi2=1.1491  , p=0.7652  , df=3
# parameter F test:         F=0.3810  , p=0.7667  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3789  , p=0.8238  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=1.5270  , p=0.8218  , df=4
# likelihood ratio test: chi2=1.5261  , p=0.8220  , df=4
# parameter F test:         F=0.3789  , p=0.8238  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4068  , p=0.8443  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=2.0528  , p=0.8418  , df=5
# likelihood ratio test: chi2=2.0510  , p=0.8420  , df=5
# parameter F test:         F=0.4068  , p=0.8443  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7897  , p=0.5780  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=4.7901  , p=0.5710  , df=6
# likelihood ratio test: chi2=4.7806  , p=0.5722  , df=6
# parameter F test:         F=0.7897  , p=0.5780  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6301  , p=0.7313  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=4.4667  , p=0.7247  , df=7
# likelihood ratio test: chi2=4.4585  , p=0.7257  , df=7
# parameter F test:         F=0.6301  , p=0.7313  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6390  , p=0.7453  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=5.1855  , p=0.7376  , df=8
# likelihood ratio test: chi2=5.1744  , p=0.7388  , df=8
# parameter F test:         F=0.6390  , p=0.7453  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.5305  , p=0.8531  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=4.8514  , p=0.8471  , df=9
# likelihood ratio test: chi2=4.8416  , p=0.8479  , df=9
# parameter F test:         F=0.5305  , p=0.8531  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.5566  , p=0.8499  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=5.6648  , p=0.8426  , df=10
# likelihood ratio test: chi2=5.6515  , p=0.8436  , df=10
# parameter F test:         F=0.5566  , p=0.8499  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=10.1779 , p=0.0015  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=10.2032 , p=0.0014  , df=1
# likelihood ratio test: chi2=10.1604 , p=0.0014  , df=1
# parameter F test:         F=10.1779 , p=0.0015  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.6651  , p=0.0036  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=11.3773 , p=0.0034  , df=2
# likelihood ratio test: chi2=11.3241 , p=0.0035  , df=2
# parameter F test:         F=5.6651  , p=0.0036  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.8242  , p=0.0096  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=11.5397 , p=0.0091  , df=3
# likelihood ratio test: chi2=11.4848 , p=0.0094  , df=3
# parameter F test:         F=3.8242  , p=0.0096  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.4987  , p=0.0075  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=14.1000 , p=0.0070  , df=4
# likelihood ratio test: chi2=14.0182 , p=0.0072  , df=4
# parameter F test:         F=3.4987  , p=0.0075  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.2492  , p=0.0064  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=16.3956 , p=0.0058  , df=5
# likelihood ratio test: chi2=16.2851 , p=0.0061  , df=5
# parameter F test:         F=3.2492  , p=0.0064  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.7412  , p=0.0119  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=16.6265 , p=0.0108  , df=6
# likelihood ratio test: chi2=16.5128 , p=0.0113  , df=6
# parameter F test:         F=2.7412  , p=0.0119  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.4956  , p=0.0151  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=17.6899 , p=0.0135  , df=7
# likelihood ratio test: chi2=17.5611 , p=0.0141  , df=7
# parameter F test:         F=2.4956  , p=0.0151  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.6721  , p=0.0065  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=21.6834 , p=0.0055  , df=8
# likelihood ratio test: chi2=21.4902 , p=0.0060  , df=8
# parameter F test:         F=2.6721  , p=0.0065  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.6929  , p=0.0042  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=24.6253 , p=0.0034  , df=9
# likelihood ratio test: chi2=24.3762 , p=0.0037  , df=9
# parameter F test:         F=2.6929  , p=0.0042  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.4714  , p=0.0063  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=25.1546 , p=0.0051  , df=10
# likelihood ratio test: chi2=24.8946 , p=0.0055  , df=10
# parameter F test:         F=2.4714  , p=0.0063  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.0391  , p=0.0447  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=4.0492  , p=0.0442  , df=1
# likelihood ratio test: chi2=4.0424  , p=0.0444  , df=1
# parameter F test:         F=4.0391  , p=0.0447  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.0311  , p=0.1316  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=4.0791  , p=0.1301  , df=2
# likelihood ratio test: chi2=4.0723  , p=0.1305  , df=2
# parameter F test:         F=2.0311  , p=0.1316  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.2009  , p=0.0863  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=6.6412  , p=0.0843  , df=3
# likelihood ratio test: chi2=6.6230  , p=0.0849  , df=3
# parameter F test:         F=2.2009  , p=0.0863  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.6597  , p=0.1570  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=6.6888  , p=0.1533  , df=4
# likelihood ratio test: chi2=6.6703  , p=0.1544  , df=4
# parameter F test:         F=1.6597  , p=0.1570  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.5656  , p=0.1669  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=7.9003  , p=0.1618  , df=5
# likelihood ratio test: chi2=7.8745  , p=0.1633  , df=5
# parameter F test:         F=1.5656  , p=0.1669  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3450  , p=0.2340  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=8.1583  , p=0.2267  , df=6
# likelihood ratio test: chi2=8.1308  , p=0.2287  , df=6
# parameter F test:         F=1.3450  , p=0.2340  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2393  , p=0.2778  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=8.7848  , p=0.2685  , df=7
# likelihood ratio test: chi2=8.7529  , p=0.2709  , df=7
# parameter F test:         F=1.2393  , p=0.2778  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2158  , p=0.2859  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=9.8660  , p=0.2746  , df=8
# likelihood ratio test: chi2=9.8258  , p=0.2775  , df=8
# parameter F test:         F=1.2158  , p=0.2859  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.7896  , p=0.0659  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=16.3655 , p=0.0596  , df=9
# likelihood ratio test: chi2=16.2550 , p=0.0617  , df=9
# parameter F test:         F=1.7896  , p=0.0659  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.7416  , p=0.0670  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=17.7263 , p=0.0598  , df=10
# likelihood ratio test: chi2=17.5967 , p=0.0622  , df=10
# parameter F test:         F=1.7416  , p=0.0670  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.9142  , p=0.0152  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=5.9289  , p=0.0149  , df=1
# likelihood ratio test: chi2=5.9145  , p=0.0150  , df=1
# parameter F test:         F=5.9142  , p=0.0152  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.2609  , p=0.0387  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=6.5490  , p=0.0378  , df=2
# likelihood ratio test: chi2=6.5313  , p=0.0382  , df=2
# parameter F test:         F=3.2609  , p=0.0387  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.2228  , p=0.0838  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=6.7074  , p=0.0818  , df=3
# likelihood ratio test: chi2=6.6888  , p=0.0825  , df=3
# parameter F test:         F=2.2228  , p=0.0838  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8122  , p=0.1241  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=7.3032  , p=0.1207  , df=4
# likelihood ratio test: chi2=7.2812  , p=0.1218  , df=4
# parameter F test:         F=1.8122  , p=0.1241  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.6167  , p=0.1526  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=8.1580  , p=0.1477  , df=5
# likelihood ratio test: chi2=8.1305  , p=0.1492  , df=5
# parameter F test:         F=1.6167  , p=0.1526  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.7605  , p=0.1039  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=10.6785 , p=0.0988  , df=6
# likelihood ratio test: chi2=10.6314 , p=0.1005  , df=6
# parameter F test:         F=1.7605  , p=0.1039  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.7488  , p=0.0940  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=12.3962 , p=0.0883  , df=7
# likelihood ratio test: chi2=12.3328 , p=0.0901  , df=7
# parameter F test:         F=1.7488  , p=0.0940  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.5790  , p=0.1265  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=12.8129 , p=0.1184  , df=8
# likelihood ratio test: chi2=12.7451 , p=0.1209  , df=8
# parameter F test:         F=1.5790  , p=0.1265  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.4543  , p=0.1601  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=13.2991 , p=0.1495  , df=9
# likelihood ratio test: chi2=13.2260 , p=0.1526  , df=9
# parameter F test:         F=1.4543  , p=0.1601  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2826  , p=0.2351  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=13.0540 , p=0.2207  , df=10
# likelihood ratio test: chi2=12.9835 , p=0.2246  , df=10
# parameter F test:         F=1.2826  , p=0.2351  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=14.3835 , p=0.0002  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=14.4192 , p=0.0001  , df=1
# likelihood ratio test: chi2=14.3339 , p=0.0002  , df=1
# parameter F test:         F=14.3835 , p=0.0002  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.1610  , p=0.0008  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=14.3814 , p=0.0008  , df=2
# likelihood ratio test: chi2=14.2965 , p=0.0008  , df=2
# parameter F test:         F=7.1610  , p=0.0008  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.7333  , p=0.0027  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=14.2829 , p=0.0025  , df=3
# likelihood ratio test: chi2=14.1990 , p=0.0026  , df=3
# parameter F test:         F=4.7333  , p=0.0027  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.0048  , p=0.0031  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=16.1396 , p=0.0028  , df=4
# likelihood ratio test: chi2=16.0326 , p=0.0030  , df=4
# parameter F test:         F=4.0048  , p=0.0031  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=4.1049  , p=0.0011  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=20.7136 , p=0.0009  , df=5
# likelihood ratio test: chi2=20.5376 , p=0.0010  , df=5
# parameter F test:         F=4.1049  , p=0.0011  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.6302  , p=0.0014  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=22.0192 , p=0.0012  , df=6
# likelihood ratio test: chi2=21.8203 , p=0.0013  , df=6
# parameter F test:         F=3.6302  , p=0.0014  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=3.1418  , p=0.0027  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=22.2705 , p=0.0023  , df=7
# likelihood ratio test: chi2=22.0669 , p=0.0025  , df=7
# parameter F test:         F=3.1418  , p=0.0027  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.9878  , p=0.0025  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=24.2450 , p=0.0021  , df=8
# likelihood ratio test: chi2=24.0037 , p=0.0023  , df=8
# parameter F test:         F=2.9878  , p=0.0025  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.7247  , p=0.0038  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=24.9166 , p=0.0031  , df=9
# likelihood ratio test: chi2=24.6617 , p=0.0034  , df=9
# parameter F test:         F=2.7247  , p=0.0038  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.3972  , p=0.0081  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=24.3989 , p=0.0066  , df=10
# likelihood ratio test: chi2=24.1542 , p=0.0072  , df=10
# parameter F test:         F=2.3972  , p=0.0081  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.5350  , p=0.2156  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=1.5388  , p=0.2148  , df=1
# likelihood ratio test: chi2=1.5378  , p=0.2149  , df=1
# parameter F test:         F=1.5350  , p=0.2156  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7921  , p=0.4531  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=1.5908  , p=0.4514  , df=2
# likelihood ratio test: chi2=1.5897  , p=0.4516  , df=2
# parameter F test:         F=0.7921  , p=0.4531  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0441  , p=0.3721  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=3.1505  , p=0.3690  , df=3
# likelihood ratio test: chi2=3.1464  , p=0.3696  , df=3
# parameter F test:         F=1.0441  , p=0.3721  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.1341  , p=0.0141  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=12.6305 , p=0.0132  , df=4
# likelihood ratio test: chi2=12.5648 , p=0.0136  , df=4
# parameter F test:         F=3.1341  , p=0.0141  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.5442  , p=0.0267  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=12.8384 , p=0.0249  , df=5
# likelihood ratio test: chi2=12.7705 , p=0.0256  , df=5
# parameter F test:         F=2.5442  , p=0.0267  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.1783  , p=0.0427  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=13.2128 , p=0.0398  , df=6
# likelihood ratio test: chi2=13.1408 , p=0.0409  , df=6
# parameter F test:         F=2.1783  , p=0.0427  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.0044  , p=0.0516  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=14.2082 , p=0.0476  , df=7
# likelihood ratio test: chi2=14.1249 , p=0.0490  , df=7
# parameter F test:         F=2.0044  , p=0.0516  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.7424  , p=0.0846  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=14.1395 , p=0.0782  , df=8
# likelihood ratio test: chi2=14.0570 , p=0.0803  , df=8
# parameter F test:         F=1.7424  , p=0.0846  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.6199  , p=0.1046  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=14.8137 , p=0.0962  , df=9
# likelihood ratio test: chi2=14.7231 , p=0.0988  , df=9
# parameter F test:         F=1.6199  , p=0.1046  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.4909  , p=0.1370  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=15.1742 , p=0.1258  , df=10
# likelihood ratio test: chi2=15.0790 , p=0.1292  , df=10
# parameter F test:         F=1.4909  , p=0.1370  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.6579  , p=0.0175  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=5.6720  , p=0.0172  , df=1
# likelihood ratio test: chi2=5.6587  , p=0.0174  , df=1
# parameter F test:         F=5.6579  , p=0.0175  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.9663  , p=0.0519  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=5.9572  , p=0.0509  , df=2
# likelihood ratio test: chi2=5.9426  , p=0.0512  , df=2
# parameter F test:         F=2.9663  , p=0.0519  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.0963  , p=0.0990  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=6.3257  , p=0.0968  , df=3
# likelihood ratio test: chi2=6.3092  , p=0.0975  , df=3
# parameter F test:         F=2.0963  , p=0.0990  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.6180  , p=0.1673  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=6.5206  , p=0.1635  , df=4
# likelihood ratio test: chi2=6.5031  , p=0.1646  , df=4
# parameter F test:         F=1.6180  , p=0.1673  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.4062  , p=0.2192  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=7.0957  , p=0.2136  , df=5
# likelihood ratio test: chi2=7.0749  , p=0.2151  , df=5
# parameter F test:         F=1.4062  , p=0.2192  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3228  , p=0.2438  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=8.0233  , p=0.2364  , df=6
# likelihood ratio test: chi2=7.9967  , p=0.2383  , df=6
# parameter F test:         F=1.3228  , p=0.2438  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1368  , p=0.3372  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=8.0583  , p=0.3275  , df=7
# likelihood ratio test: chi2=8.0315  , p=0.3298  , df=7
# parameter F test:         F=1.1368  , p=0.3372  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.0430  , p=0.4014  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=8.4637  , p=0.3895  , df=8
# likelihood ratio test: chi2=8.4340  , p=0.3923  , df=8
# parameter F test:         F=1.0430  , p=0.4014  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9462  , p=0.4836  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=8.6530  , p=0.4699  , df=9
# likelihood ratio test: chi2=8.6220  , p=0.4729  , df=9
# parameter F test:         F=0.9462  , p=0.4836  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9555  , p=0.4809  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=9.7254  , p=0.4649  , df=10
# likelihood ratio test: chi2=9.6862  , p=0.4684  , df=10
# parameter F test:         F=0.9555  , p=0.4809  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.7361  , p=0.0984  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=2.7429  , p=0.0977  , df=1
# likelihood ratio test: chi2=2.7398  , p=0.0979  , df=1
# parameter F test:         F=2.7361  , p=0.0984  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.8795  , p=0.0209  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=7.7912  , p=0.0203  , df=2
# likelihood ratio test: chi2=7.7662  , p=0.0206  , df=2
# parameter F test:         F=3.8795  , p=0.0209  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.6177  , p=0.0496  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=7.8989  , p=0.0481  , df=3
# likelihood ratio test: chi2=7.8732  , p=0.0487  , df=3
# parameter F test:         F=2.6177  , p=0.0496  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.2411  , p=0.0627  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=9.0320  , p=0.0603  , df=4
# likelihood ratio test: chi2=8.9983  , p=0.0611  , df=4
# parameter F test:         F=2.2411  , p=0.0627  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.8144  , p=0.1071  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=9.1557  , p=0.1030  , df=5
# likelihood ratio test: chi2=9.1211  , p=0.1043  , df=5
# parameter F test:         F=1.8144  , p=0.1071  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.5299  , p=0.1648  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=9.2795  , p=0.1585  , df=6
# likelihood ratio test: chi2=9.2439  , p=0.1603  , df=6
# parameter F test:         F=1.5299  , p=0.1648  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.3856  , p=0.2074  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=9.8218  , p=0.1989  , df=7
# likelihood ratio test: chi2=9.7819  , p=0.2013  , df=7
# parameter F test:         F=1.3856  , p=0.2074  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2421  , p=0.2707  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=10.0795 , p=0.2595  , df=8
# likelihood ratio test: chi2=10.0374 , p=0.2624  , df=8
# parameter F test:         F=1.2421  , p=0.2707  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.2569  , p=0.2563  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=11.4936 , p=0.2434  , df=9
# likelihood ratio test: chi2=11.4390 , p=0.2468  , df=9
# parameter F test:         F=1.2569  , p=0.2563  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.4063  , p=0.1718  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=14.3131 , p=0.1592  , df=10
# likelihood ratio test: chi2=14.2284 , p=0.1628  , df=10
# parameter F test:         F=1.4063  , p=0.1718  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1924  , p=0.6610  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=0.1929  , p=0.6605  , df=1
# likelihood ratio test: chi2=0.1929  , p=0.6605  , df=1
# parameter F test:         F=0.1924  , p=0.6610  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4141  , p=0.6611  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=0.8316  , p=0.6598  , df=2
# likelihood ratio test: chi2=0.8313  , p=0.6599  , df=2
# parameter F test:         F=0.4141  , p=0.6611  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.6095  , p=0.6089  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=1.8390  , p=0.6065  , df=3
# likelihood ratio test: chi2=1.8376  , p=0.6068  , df=3
# parameter F test:         F=0.6095  , p=0.6089  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6218  , p=0.6470  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=2.5061  , p=0.6435  , df=4
# likelihood ratio test: chi2=2.5035  , p=0.6440  , df=4
# parameter F test:         F=0.6218  , p=0.6470  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5589  , p=0.7316  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=2.8200  , p=0.7277  , df=5
# likelihood ratio test: chi2=2.8167  , p=0.7282  , df=5
# parameter F test:         F=0.5589  , p=0.7316  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4807  , p=0.8231  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=2.9156  , p=0.8194  , df=6
# likelihood ratio test: chi2=2.9121  , p=0.8198  , df=6
# parameter F test:         F=0.4807  , p=0.8231  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5468  , p=0.7992  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=3.8757  , p=0.7940  , df=7
# likelihood ratio test: chi2=3.8694  , p=0.7947  , df=7
# parameter F test:         F=0.5468  , p=0.7992  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5356  , p=0.8303  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=4.3462  , p=0.8246  , df=8
# likelihood ratio test: chi2=4.3384  , p=0.8254  , df=8
# parameter F test:         F=0.5356  , p=0.8303  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.8758  , p=0.5464  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=8.0089  , p=0.5332  , df=9
# likelihood ratio test: chi2=7.9824  , p=0.5359  , df=9
# parameter F test:         F=0.8758  , p=0.5464  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.7793  , p=0.6490  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=7.9314  , p=0.6355  , df=10
# likelihood ratio test: chi2=7.9053  , p=0.6381  , df=10
# parameter F test:         F=0.7793  , p=0.6490  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.5180  , p=0.2182  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=1.5217  , p=0.2174  , df=1
# likelihood ratio test: chi2=1.5208  , p=0.2175  , df=1
# parameter F test:         F=1.5180  , p=0.2182  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1606  , p=0.3137  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=2.3308  , p=0.3118  , df=2
# likelihood ratio test: chi2=2.3285  , p=0.3122  , df=2
# parameter F test:         F=1.1606  , p=0.3137  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8582  , p=0.4623  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=2.5895  , p=0.4593  , df=3
# likelihood ratio test: chi2=2.5867  , p=0.4598  , df=3
# parameter F test:         F=0.8582  , p=0.4623  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6557  , p=0.6229  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=2.6425  , p=0.6193  , df=4
# likelihood ratio test: chi2=2.6396  , p=0.6198  , df=4
# parameter F test:         F=0.6557  , p=0.6229  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5109  , p=0.7682  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=2.5782  , p=0.7647  , df=5
# likelihood ratio test: chi2=2.5755  , p=0.7651  , df=5
# parameter F test:         F=0.5109  , p=0.7682  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.4590  , p=0.8389  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=2.7838  , p=0.8355  , df=6
# likelihood ratio test: chi2=2.7806  , p=0.8358  , df=6
# parameter F test:         F=0.4590  , p=0.8389  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.9568  , p=0.4615  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=6.7824  , p=0.4519  , df=7
# likelihood ratio test: chi2=6.7634  , p=0.4539  , df=7
# parameter F test:         F=0.9568  , p=0.4615  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8929  , p=0.5216  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=7.2460  , p=0.5103  , df=8
# likelihood ratio test: chi2=7.2242  , p=0.5126  , df=8
# parameter F test:         F=0.8929  , p=0.5216  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.4669  , p=0.1552  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=13.4146 , p=0.1447  , df=9
# likelihood ratio test: chi2=13.3402 , p=0.1478  , df=9
# parameter F test:         F=1.4669  , p=0.1552  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2834  , p=0.2346  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=13.0631 , p=0.2202  , df=10
# likelihood ratio test: chi2=12.9925 , p=0.2241  , df=10
# parameter F test:         F=1.2834  , p=0.2346  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4767  , p=0.2245  , df_denom=1206, df_num=1
# ssr based chi2 test:   chi2=1.4804  , p=0.2237  , df=1
# likelihood ratio test: chi2=1.4795  , p=0.2239  , df=1
# parameter F test:         F=1.4767  , p=0.2245  , df_denom=1206, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.1331  , p=0.3224  , df_denom=1203, df_num=2
# ssr based chi2 test:   chi2=2.2757  , p=0.3205  , df=2
# likelihood ratio test: chi2=2.2736  , p=0.3209  , df=2
# parameter F test:         F=1.1331  , p=0.3224  , df_denom=1203, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8053  , p=0.4910  , df_denom=1200, df_num=3
# ssr based chi2 test:   chi2=2.4299  , p=0.4881  , df=3
# likelihood ratio test: chi2=2.4275  , p=0.4885  , df=3
# parameter F test:         F=0.8053  , p=0.4910  , df_denom=1200, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5851  , p=0.6735  , df_denom=1197, df_num=4
# ssr based chi2 test:   chi2=2.3582  , p=0.6702  , df=4
# likelihood ratio test: chi2=2.3559  , p=0.6706  , df=4
# parameter F test:         F=0.5851  , p=0.6735  , df_denom=1197, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5262  , p=0.7566  , df_denom=1194, df_num=5
# ssr based chi2 test:   chi2=2.6552  , p=0.7530  , df=5
# likelihood ratio test: chi2=2.6522  , p=0.7534  , df=5
# parameter F test:         F=0.5262  , p=0.7566  , df_denom=1194, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5020  , p=0.8072  , df_denom=1191, df_num=6
# ssr based chi2 test:   chi2=3.0449  , p=0.8032  , df=6
# likelihood ratio test: chi2=3.0410  , p=0.8037  , df=6
# parameter F test:         F=0.5020  , p=0.8072  , df_denom=1191, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2540  , p=0.2701  , df_denom=1188, df_num=7
# ssr based chi2 test:   chi2=8.8886  , p=0.2608  , df=7
# likelihood ratio test: chi2=8.8559  , p=0.2632  , df=7
# parameter F test:         F=1.2540  , p=0.2701  , df_denom=1188, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1740  , p=0.3114  , df_denom=1185, df_num=8
# ssr based chi2 test:   chi2=9.5269  , p=0.2998  , df=8
# likelihood ratio test: chi2=9.4893  , p=0.3027  , df=8
# parameter F test:         F=1.1740  , p=0.3114  , df_denom=1185, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.5940  , p=0.1120  , df_denom=1182, df_num=9
# ssr based chi2 test:   chi2=14.5768 , p=0.1032  , df=9
# likelihood ratio test: chi2=14.4891 , p=0.1060  , df=9
# parameter F test:         F=1.5940  , p=0.1120  , df_denom=1182, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3858  , p=0.1812  , df_denom=1179, df_num=10
# ssr based chi2 test:   chi2=14.1047 , p=0.1683  , df=10
# likelihood ratio test: chi2=14.0224 , p=0.1720  , df=10
# parameter F test:         F=1.3858  , p=0.1812  , df_denom=1179, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.3820  , p=0.0117  , df_denom=1205, df_num=1
# ssr based chi2 test:   chi2=6.3979  , p=0.0114  , df=1
# likelihood ratio test: chi2=6.3810  , p=0.0115  , df=1
# parameter F test:         F=6.3820  , p=0.0117  , df_denom=1205, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.5707  , p=0.0284  , df_denom=1202, df_num=2
# ssr based chi2 test:   chi2=7.1711  , p=0.0277  , df=2
# likelihood ratio test: chi2=7.1499  , p=0.0280  , df=2
# parameter F test:         F=3.5707  , p=0.0284  , df_denom=1202, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.4505  , p=0.0620  , df_denom=1199, df_num=3
# ssr based chi2 test:   chi2=7.3943  , p=0.0603  , df=3
# likelihood ratio test: chi2=7.3717  , p=0.0609  , df=3
# parameter F test:         F=2.4505  , p=0.0620  , df_denom=1199, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8095  , p=0.1246  , df_denom=1196, df_num=4
# ssr based chi2 test:   chi2=7.2926  , p=0.1212  , df=4
# likelihood ratio test: chi2=7.2706  , p=0.1223  , df=4
# parameter F test:         F=1.8095  , p=0.1246  , df_denom=1196, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.4383  , p=0.2077  , df_denom=1193, df_num=5
# ssr based chi2 test:   chi2=7.2578  , p=0.2022  , df=5
# likelihood ratio test: chi2=7.2360  , p=0.2037  , df=5
# parameter F test:         F=1.4383  , p=0.2077  , df_denom=1193, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4992  , p=0.1749  , df_denom=1190, df_num=6
# ssr based chi2 test:   chi2=9.0934  , p=0.1684  , df=6
# likelihood ratio test: chi2=9.0592  , p=0.1703  , df=6
# parameter F test:         F=1.4992  , p=0.1749  , df_denom=1190, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4670  , p=0.1750  , df_denom=1187, df_num=7
# ssr based chi2 test:   chi2=10.3988 , p=0.1671  , df=7
# likelihood ratio test: chi2=10.3540 , p=0.1694  , df=7
# parameter F test:         F=1.4670  , p=0.1750  , df_denom=1187, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2606  , p=0.2603  , df_denom=1184, df_num=8
# ssr based chi2 test:   chi2=10.2298 , p=0.2493  , df=8
# likelihood ratio test: chi2=10.1865 , p=0.2522  , df=8
# parameter F test:         F=1.2606  , p=0.2603  , df_denom=1184, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0869  , p=0.3694  , df_denom=1181, df_num=9
# ssr based chi2 test:   chi2=9.9392  , p=0.3554  , df=9
# likelihood ratio test: chi2=9.8982  , p=0.3588  , df=9
# parameter F test:         F=1.0869  , p=0.3694  , df_denom=1181, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.0664  , p=0.3853  , df_denom=1178, df_num=10
# ssr based chi2 test:   chi2=10.8541 , p=0.3690  , df=10
# likelihood ratio test: chi2=10.8053 , p=0.3729  , df=10
# parameter F test:         F=1.0664  , p=0.3853  , df_denom=1178, df_num=10
