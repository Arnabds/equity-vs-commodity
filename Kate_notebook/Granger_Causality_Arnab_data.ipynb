# %% [markdown]
# ## Granger Causality Test

# %% [markdown]
# Companies that Granger Causes Apple’s close differencing will be implemented in VAR.

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from statsmodels.tsa.stattools import grangercausalitytests

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
#warnings.filterwarnings("ignore", category=ValueError)
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=ValueError)

# %% [markdown]
# ## Function that export p-values for Granger Causality Test

# %%
## https://www.machinelearningplus.com/time-series/granger-causality-test-in-python/
def grangers_causation_matrix(data, variables,test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=10, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(10)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            #opt_lag = 1 + np.argmin(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

# %% [markdown]
# ## Import stock data from Yahoo Finance

# %%
tickers = ['DNZOY','ALV','ASEKY','BAC','CADUSD=X','CHFUSD=X','CL=F','F','FDX','GBPUSD=X','GBPUSD=X','GM','JCI','JPM','TM',
         'TRYUSD=X','WFC','X','^DJI','^GSPC','^IXIC','ALI=F']

data = yf.download(tickers, period="5y")
df = data['Close'].diff().copy()
# Out:
# [*********************100%***********************]  21 of 21 completed

# %%
df
# Out:
# Ticker                     ALI=F       ALV     ASEKY       BAC  CADUSD=X  \
# Date
# 2019-10-24 00:00:00+00:00    NaN       NaN       NaN       NaN       NaN
# 2019-10-25 00:00:00+00:00   5.50       NaN       NaN       NaN       NaN
# 2019-10-28 00:00:00+00:00  10.50 -0.589996  0.000000  0.120001  0.000445
# 2019-10-29 00:00:00+00:00  -6.00 -1.770004  0.430333  0.230000  0.000434
# 2019-10-30 00:00:00+00:00  15.25 -1.620003  0.000000 -0.449999 -0.001955
# ...                          ...       ...       ...       ...       ...
# 2024-10-21 00:00:00+00:00 -24.75 -2.719994  0.030000 -0.560001 -0.000205
# 2024-10-22 00:00:00+00:00  33.00  0.599998  0.000000  0.540001 -0.001776
# 2024-10-23 00:00:00+00:00  37.75 -0.900002  0.200000  0.040001  0.000905
# 2024-10-24 00:00:00+00:00 -15.00 -1.459999  0.000000  0.310001 -0.001072
# 2024-10-25 00:00:00+00:00   6.00       NaN       NaN       NaN -0.000678
#
# Ticker                     CHFUSD=X      CL=F     DNZOY         F       FDX  \
# Date
# 2019-10-24 00:00:00+00:00       NaN       NaN       NaN       NaN       NaN
# 2019-10-25 00:00:00+00:00       NaN  0.430000       NaN       NaN       NaN
# 2019-10-28 00:00:00+00:00 -0.001875 -0.849998 -0.040000 -0.110001  0.309998
# 2019-10-29 00:00:00+00:00 -0.000566 -0.270000  0.129999  0.030001 -0.389999
# 2019-10-30 00:00:00+00:00  0.000647 -0.480000  0.030001 -0.100000 -2.169998
# ...                             ...       ...       ...       ...       ...
# 2024-10-21 00:00:00+00:00  0.001335  1.339996 -0.160000 -0.220000 -5.589996
# 2024-10-22 00:00:00+00:00 -0.000641  1.529999 -0.099999  0.230000  0.980011
# 2024-10-23 00:00:00+00:00 -0.000160 -1.320000  0.160000 -0.049999 -1.740021
# 2024-10-24 00:00:00+00:00 -0.001613       NaN -0.030000  0.179999  4.820007
# 2024-10-25 00:00:00+00:00  0.001239       NaN       NaN       NaN       NaN
#
# Ticker                     ...        GM       JCI       JPM        TM  \
# Date                       ...
# 2019-10-24 00:00:00+00:00  ...       NaN       NaN       NaN       NaN
# 2019-10-25 00:00:00+00:00  ...       NaN       NaN       NaN       NaN
# 2019-10-28 00:00:00+00:00  ... -0.100002  0.109997  0.480003  0.059998
# 2019-10-29 00:00:00+00:00  ...  1.570000  0.690002 -0.080002  0.339996
# 2019-10-30 00:00:00+00:00  ... -0.299999 -0.150002 -0.699997  0.340012
# ...                        ...       ...       ...       ...       ...
# 2024-10-21 00:00:00+00:00  ... -0.250000 -0.270004 -2.369995 -2.360001
# 2024-10-22 00:00:00+00:00  ...  4.799999 -0.529999  1.119995  0.759995
# 2024-10-23 00:00:00+00:00  ... -0.810001 -0.159996 -0.709991  1.400009
# 2024-10-24 00:00:00+00:00  ... -0.199997  0.379997  1.569992 -0.900009
# 2024-10-25 00:00:00+00:00  ...       NaN       NaN       NaN       NaN
#
# Ticker                     TRYUSD=X       WFC         X        ^DJI  \
# Date
# 2019-10-24 00:00:00+00:00       NaN       NaN       NaN         NaN
# 2019-10-25 00:00:00+00:00       NaN       NaN       NaN         NaN
# 2019-10-28 00:00:00+00:00 -0.000177  0.080002  0.600000  132.660156
# 2019-10-29 00:00:00+00:00  0.001306  0.519997 -0.090000  -19.259766
# 2019-10-30 00:00:00+00:00 -0.000671 -0.139999 -0.210000  115.228516
# ...                             ...       ...       ...         ...
# 2024-10-21 00:00:00+00:00 -0.000072 -0.340004  1.099998 -344.308594
# 2024-10-22 00:00:00+00:00  0.000026  0.790001  0.000000   -6.710938
# 2024-10-23 00:00:00+00:00 -0.000006 -0.250000  0.590000 -409.941406
# 2024-10-24 00:00:00+00:00 -0.000013  0.870003 -0.009998 -140.589844
# 2024-10-25 00:00:00+00:00 -0.000018       NaN       NaN         NaN
#
# Ticker                         ^GSPC       ^IXIC
# Date
# 2019-10-24 00:00:00+00:00        NaN         NaN
# 2019-10-25 00:00:00+00:00        NaN         NaN
# 2019-10-28 00:00:00+00:00  16.869873   82.870117
# 2019-10-29 00:00:00+00:00  -2.530029  -49.140625
# 2019-10-30 00:00:00+00:00   9.880127   27.130859
# ...                              ...         ...
# 2024-10-21 00:00:00+00:00 -10.689941   50.458984
# 2024-10-22 00:00:00+00:00  -2.779785   39.759766
# 2024-10-23 00:00:00+00:00 -53.780273 -303.119141
# 2024-10-24 00:00:00+00:00  12.439941  138.839844
# 2024-10-25 00:00:00+00:00        NaN         NaN
#
# [1307 rows x 21 columns]

# %%
df = df.dropna()

# %%
df
# Out:
# Ticker                     ALI=F       ALV     ASEKY       BAC  CADUSD=X  \
# Date
# 2019-10-24 00:00:00+00:00    NaN       NaN       NaN       NaN       NaN
# 2019-10-25 00:00:00+00:00   5.50       NaN       NaN       NaN       NaN
# 2019-10-28 00:00:00+00:00  10.50 -0.589996  0.000000  0.120001  0.000445
# 2019-10-29 00:00:00+00:00  -6.00 -1.770004  0.430333  0.230000  0.000434
# 2019-10-30 00:00:00+00:00  15.25 -1.620003  0.000000 -0.449999 -0.001955
# ...                          ...       ...       ...       ...       ...
# 2024-10-21 00:00:00+00:00 -24.75 -2.719994  0.030000 -0.560001 -0.000205
# 2024-10-22 00:00:00+00:00  33.00  0.599998  0.000000  0.540001 -0.001776
# 2024-10-23 00:00:00+00:00  37.75 -0.900002  0.200000  0.040001  0.000905
# 2024-10-24 00:00:00+00:00 -15.00 -1.459999  0.000000  0.310001 -0.001072
# 2024-10-25 00:00:00+00:00   6.00       NaN       NaN       NaN -0.000663
#
# Ticker                     CHFUSD=X      CL=F     DNZOY         F       FDX  \
# Date
# 2019-10-24 00:00:00+00:00       NaN       NaN       NaN       NaN       NaN
# 2019-10-25 00:00:00+00:00       NaN  0.430000       NaN       NaN       NaN
# 2019-10-28 00:00:00+00:00 -0.001875 -0.849998 -0.040000 -0.110001  0.309998
# 2019-10-29 00:00:00+00:00 -0.000566 -0.270000  0.129999  0.030001 -0.389999
# 2019-10-30 00:00:00+00:00  0.000647 -0.480000  0.030001 -0.100000 -2.169998
# ...                             ...       ...       ...       ...       ...
# 2024-10-21 00:00:00+00:00  0.001335  1.339996 -0.160000 -0.220000 -5.589996
# 2024-10-22 00:00:00+00:00 -0.000641  1.529999 -0.099999  0.230000  0.980011
# 2024-10-23 00:00:00+00:00 -0.000160 -1.320000  0.160000 -0.049999 -1.740021
# 2024-10-24 00:00:00+00:00 -0.001613       NaN -0.030000  0.179999  4.820007
# 2024-10-25 00:00:00+00:00  0.001279       NaN       NaN       NaN       NaN
#
# Ticker                     ...        GM       JCI       JPM        TM  \
# Date                       ...
# 2019-10-24 00:00:00+00:00  ...       NaN       NaN       NaN       NaN
# 2019-10-25 00:00:00+00:00  ...       NaN       NaN       NaN       NaN
# 2019-10-28 00:00:00+00:00  ... -0.100002  0.109997  0.480003  0.059998
# 2019-10-29 00:00:00+00:00  ...  1.570000  0.690002 -0.080002  0.339996
# 2019-10-30 00:00:00+00:00  ... -0.299999 -0.150002 -0.699997  0.340012
# ...                        ...       ...       ...       ...       ...
# 2024-10-21 00:00:00+00:00  ... -0.250000 -0.270004 -2.369995 -2.360001
# 2024-10-22 00:00:00+00:00  ...  4.799999 -0.529999  1.119995  0.759995
# 2024-10-23 00:00:00+00:00  ... -0.810001 -0.159996 -0.709991  1.400009
# 2024-10-24 00:00:00+00:00  ... -0.199997  0.379997  1.569992 -0.900009
# 2024-10-25 00:00:00+00:00  ...       NaN       NaN       NaN       NaN
#
# Ticker                     TRYUSD=X       WFC         X        ^DJI  \
# Date
# 2019-10-24 00:00:00+00:00       NaN       NaN       NaN         NaN
# 2019-10-25 00:00:00+00:00       NaN       NaN       NaN         NaN
# 2019-10-28 00:00:00+00:00 -0.000177  0.080002  0.600000  132.660156
# 2019-10-29 00:00:00+00:00  0.001306  0.519997 -0.090000  -19.259766
# 2019-10-30 00:00:00+00:00 -0.000671 -0.139999 -0.210000  115.228516
# ...                             ...       ...       ...         ...
# 2024-10-21 00:00:00+00:00 -0.000072 -0.340004  1.099998 -344.308594
# 2024-10-22 00:00:00+00:00  0.000026  0.790001  0.000000   -6.710938
# 2024-10-23 00:00:00+00:00 -0.000006 -0.250000  0.590000 -409.941406
# 2024-10-24 00:00:00+00:00 -0.000013  0.870003 -0.009998 -140.589844
# 2024-10-25 00:00:00+00:00 -0.000015       NaN       NaN         NaN
#
# Ticker                         ^GSPC       ^IXIC
# Date
# 2019-10-24 00:00:00+00:00        NaN         NaN
# 2019-10-25 00:00:00+00:00        NaN         NaN
# 2019-10-28 00:00:00+00:00  16.869873   82.870117
# 2019-10-29 00:00:00+00:00  -2.530029  -49.140625
# 2019-10-30 00:00:00+00:00   9.880127   27.130859
# ...                              ...         ...
# 2024-10-21 00:00:00+00:00 -10.689941   50.458984
# 2024-10-22 00:00:00+00:00  -2.779785   39.759766
# 2024-10-23 00:00:00+00:00 -53.780273 -303.119141
# 2024-10-24 00:00:00+00:00  12.439941  138.839844
# 2024-10-25 00:00:00+00:00        NaN         NaN
#
# [1307 rows x 21 columns]

# %% [markdown]
# ## Apply Granger Causality test

# %%
ticker = ['ALV','ASEKY','BAC','CADUSD=X','CHFUSD=X','CL=F','F','FDX','GBPUSD=X','GBPUSD=X','GM','JCI','JPM','TM',
         'TRYUSD=X','WFC','X','^DJI','^GSPC','^IXIC','ALI=F']

GC_stock = []
optimal_lag = []

for t in ticker:
    test_result = grangercausalitytests(df[['DNZOY', t]], maxlag=10)
    p_values = [round(test_result[i+1][0]['ssr_ftest'][1],4) for i in range(10)]
    min_p_value = np.min(p_values)
    if min_p_value < 0.05:
        GC_stock.append(t)
        optimal_lag.append(1 + np.argmin(p_values))
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.2997  , p=0.0040  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=8.3204  , p=0.0039  , df=1
# likelihood ratio test: chi2=8.2919  , p=0.0040  , df=1
# parameter F test:         F=8.2997  , p=0.0040  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=6.3410  , p=0.0018  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=12.7348 , p=0.0017  , df=2
# likelihood ratio test: chi2=12.6680 , p=0.0018  , df=2
# parameter F test:         F=6.3410  , p=0.0018  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.2993  , p=0.0050  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=12.9733 , p=0.0047  , df=3
# likelihood ratio test: chi2=12.9039 , p=0.0048  , df=3
# parameter F test:         F=4.2993  , p=0.0050  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.3471  , p=0.0098  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=13.4892 , p=0.0091  , df=4
# likelihood ratio test: chi2=13.4141 , p=0.0094  , df=4
# parameter F test:         F=3.3471  , p=0.0098  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.0843  , p=0.0090  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=15.5642 , p=0.0082  , df=5
# likelihood ratio test: chi2=15.4643 , p=0.0086  , df=5
# parameter F test:         F=3.0843  , p=0.0090  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.7035  , p=0.0130  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=16.3988 , p=0.0118  , df=6
# likelihood ratio test: chi2=16.2878 , p=0.0123  , df=6
# parameter F test:         F=2.7035  , p=0.0130  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.3489  , p=0.0220  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=16.6504 , p=0.0198  , df=7
# likelihood ratio test: chi2=16.5360 , p=0.0206  , df=7
# parameter F test:         F=2.3489  , p=0.0220  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.1721  , p=0.0272  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=17.6266 , p=0.0242  , df=8
# likelihood ratio test: chi2=17.4983 , p=0.0253  , df=8
# parameter F test:         F=2.1721  , p=0.0272  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.6212  , p=0.0053  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=23.9709 , p=0.0043  , df=9
# likelihood ratio test: chi2=23.7342 , p=0.0047  , df=9
# parameter F test:         F=2.6212  , p=0.0053  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.4432  , p=0.0069  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=24.8678 , p=0.0056  , df=10
# likelihood ratio test: chi2=24.6130 , p=0.0061  , df=10
# parameter F test:         F=2.4432  , p=0.0069  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4472  , p=0.5038  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=0.4483  , p=0.5031  , df=1
# likelihood ratio test: chi2=0.4483  , p=0.5032  , df=1
# parameter F test:         F=0.4472  , p=0.5038  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2213  , p=0.8015  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=0.4444  , p=0.8008  , df=2
# likelihood ratio test: chi2=0.4443  , p=0.8008  , df=2
# parameter F test:         F=0.2213  , p=0.8015  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1870  , p=0.9053  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=0.5643  , p=0.9046  , df=3
# likelihood ratio test: chi2=0.5641  , p=0.9046  , df=3
# parameter F test:         F=0.1870  , p=0.9053  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3757  , p=0.8261  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=1.5142  , p=0.8241  , df=4
# likelihood ratio test: chi2=1.5133  , p=0.8243  , df=4
# parameter F test:         F=0.3757  , p=0.8261  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9612  , p=0.4405  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=4.8503  , p=0.4344  , df=5
# likelihood ratio test: chi2=4.8405  , p=0.4356  , df=5
# parameter F test:         F=0.9612  , p=0.4405  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.7742  , p=0.5902  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=4.6960  , p=0.5834  , df=6
# likelihood ratio test: chi2=4.6868  , p=0.5846  , df=6
# parameter F test:         F=0.7742  , p=0.5902  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.7540  , p=0.6262  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=5.3445  , p=0.6180  , df=7
# likelihood ratio test: chi2=5.3327  , p=0.6194  , df=7
# parameter F test:         F=0.7540  , p=0.6262  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6560  , p=0.7306  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=5.3236  , p=0.7225  , df=8
# likelihood ratio test: chi2=5.3119  , p=0.7238  , df=8
# parameter F test:         F=0.6560  , p=0.7306  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.6329  , p=0.7696  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=5.7876  , p=0.7610  , df=9
# likelihood ratio test: chi2=5.7737  , p=0.7623  , df=9
# parameter F test:         F=0.6329  , p=0.7696  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.6088  , p=0.8074  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=6.1970  , p=0.7985  , df=10
# likelihood ratio test: chi2=6.1810  , p=0.7998  , df=10
# parameter F test:         F=0.6088  , p=0.8074  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.6457  , p=0.0565  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=3.6548  , p=0.0559  , df=1
# likelihood ratio test: chi2=3.6493  , p=0.0561  , df=1
# parameter F test:         F=3.6457  , p=0.0565  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.3151  , p=0.0992  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=4.6495  , p=0.0978  , df=2
# likelihood ratio test: chi2=4.6406  , p=0.0982  , df=2
# parameter F test:         F=2.3151  , p=0.0992  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6327  , p=0.1800  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=4.9267  , p=0.1772  , df=3
# likelihood ratio test: chi2=4.9166  , p=0.1780  , df=3
# parameter F test:         F=1.6327  , p=0.1800  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.4238  , p=0.2238  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=5.7382  , p=0.2196  , df=4
# likelihood ratio test: chi2=5.7246  , p=0.2207  , df=4
# parameter F test:         F=1.4238  , p=0.2238  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.8377  , p=0.1027  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=9.2731  , p=0.0987  , df=5
# likelihood ratio test: chi2=9.2375  , p=0.1000  , df=5
# parameter F test:         F=1.8377  , p=0.1027  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.8452  , p=0.0872  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=11.1926 , p=0.0826  , df=6
# likelihood ratio test: chi2=11.1408 , p=0.0841  , df=6
# parameter F test:         F=1.8452  , p=0.0872  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.5400  , p=0.1497  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=10.9161 , p=0.1423  , df=7
# likelihood ratio test: chi2=10.8668 , p=0.1445  , df=7
# parameter F test:         F=1.5400  , p=0.1497  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.3954  , p=0.1940  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=11.3236 , p=0.1840  , df=8
# likelihood ratio test: chi2=11.2705 , p=0.1868  , df=8
# parameter F test:         F=1.3954  , p=0.1940  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.3025  , p=0.2308  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=11.9118 , p=0.2183  , df=9
# likelihood ratio test: chi2=11.8530 , p=0.2217  , df=9
# parameter F test:         F=1.3025  , p=0.2308  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1708  , p=0.3064  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=11.9167 , p=0.2907  , df=10
# likelihood ratio test: chi2=11.8578 , p=0.2947  , df=10
# parameter F test:         F=1.1708  , p=0.3064  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.5557  , p=0.1102  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=2.5621  , p=0.1095  , df=1
# likelihood ratio test: chi2=2.5593  , p=0.1096  , df=1
# parameter F test:         F=2.5557  , p=0.1102  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.7356  , p=0.0653  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=5.4941  , p=0.0641  , df=2
# likelihood ratio test: chi2=5.4816  , p=0.0645  , df=2
# parameter F test:         F=2.7356  , p=0.0653  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.0915  , p=0.0996  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=6.3112  , p=0.0974  , df=3
# likelihood ratio test: chi2=6.2947  , p=0.0981  , df=3
# parameter F test:         F=2.0915  , p=0.0996  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.1072  , p=0.0778  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=8.4922  , p=0.0751  , df=4
# likelihood ratio test: chi2=8.4624  , p=0.0760  , df=4
# parameter F test:         F=2.1072  , p=0.0778  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.6371  , p=0.1472  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=8.2613  , p=0.1424  , df=5
# likelihood ratio test: chi2=8.2330  , p=0.1439  , df=5
# parameter F test:         F=1.6371  , p=0.1472  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.4737  , p=0.1837  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=8.9387  , p=0.1771  , df=6
# likelihood ratio test: chi2=8.9056  , p=0.1790  , df=6
# parameter F test:         F=1.4737  , p=0.1837  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1724  , p=0.3157  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=8.3106  , p=0.3060  , df=7
# likelihood ratio test: chi2=8.2820  , p=0.3084  , df=7
# parameter F test:         F=1.1724  , p=0.3157  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1342  , p=0.3371  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=9.2044  , p=0.3253  , df=8
# likelihood ratio test: chi2=9.1692  , p=0.3282  , df=8
# parameter F test:         F=1.1342  , p=0.3371  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9793  , p=0.4553  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=8.9558  , p=0.4414  , df=9
# likelihood ratio test: chi2=8.9225  , p=0.4445  , df=9
# parameter F test:         F=0.9793  , p=0.4553  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9423  , p=0.4930  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=9.5915  , p=0.4770  , df=10
# likelihood ratio test: chi2=9.5533  , p=0.4805  , df=10
# parameter F test:         F=0.9423  , p=0.4930  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1516  , p=0.6971  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=0.1519  , p=0.6967  , df=1
# likelihood ratio test: chi2=0.1519  , p=0.6967  , df=1
# parameter F test:         F=0.1516  , p=0.6971  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5477  , p=0.2132  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=3.1082  , p=0.2114  , df=2
# likelihood ratio test: chi2=3.1042  , p=0.2118  , df=2
# parameter F test:         F=1.5477  , p=0.2132  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3079  , p=0.2703  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=3.9467  , p=0.2673  , df=3
# likelihood ratio test: chi2=3.9403  , p=0.2680  , df=3
# parameter F test:         F=1.3079  , p=0.2703  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.4845  , p=0.2046  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=5.9827  , p=0.2004  , df=4
# likelihood ratio test: chi2=5.9679  , p=0.2016  , df=4
# parameter F test:         F=1.4845  , p=0.2046  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2483  , p=0.2842  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=6.2994  , p=0.2782  , df=5
# likelihood ratio test: chi2=6.2829  , p=0.2797  , df=5
# parameter F test:         F=1.2483  , p=0.2842  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.0111  , p=0.4163  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=6.1332  , p=0.4084  , df=6
# likelihood ratio test: chi2=6.1176  , p=0.4101  , df=6
# parameter F test:         F=1.0111  , p=0.4163  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8968  , p=0.5081  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=6.3570  , p=0.4987  , df=7
# likelihood ratio test: chi2=6.3403  , p=0.5006  , df=7
# parameter F test:         F=0.8968  , p=0.5081  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8334  , p=0.5731  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=6.7634  , p=0.5624  , df=8
# likelihood ratio test: chi2=6.7444  , p=0.5644  , df=8
# parameter F test:         F=0.8334  , p=0.5731  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7896  , p=0.6261  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=7.2210  , p=0.6141  , df=9
# likelihood ratio test: chi2=7.1993  , p=0.6164  , df=9
# parameter F test:         F=0.7896  , p=0.6261  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.7776  , p=0.6507  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=7.9146  , p=0.6372  , df=10
# likelihood ratio test: chi2=7.8885  , p=0.6397  , df=10
# parameter F test:         F=0.7776  , p=0.6507  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0028  , p=0.9581  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=0.0028  , p=0.9580  , df=1
# likelihood ratio test: chi2=0.0028  , p=0.9580  , df=1
# parameter F test:         F=0.0028  , p=0.9581  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1324  , p=0.8760  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=0.2658  , p=0.8755  , df=2
# likelihood ratio test: chi2=0.2658  , p=0.8755  , df=2
# parameter F test:         F=0.1324  , p=0.8760  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7592  , p=0.5171  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=2.2908  , p=0.5143  , df=3
# likelihood ratio test: chi2=2.2887  , p=0.5147  , df=3
# parameter F test:         F=0.7592  , p=0.5171  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7825  , p=0.5365  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=3.1536  , p=0.5325  , df=4
# likelihood ratio test: chi2=3.1495  , p=0.5331  , df=4
# parameter F test:         F=0.7825  , p=0.5365  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6310  , p=0.6761  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=3.1842  , p=0.6716  , df=5
# likelihood ratio test: chi2=3.1800  , p=0.6723  , df=5
# parameter F test:         F=0.6310  , p=0.6761  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6567  , p=0.6848  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=3.9831  , p=0.6790  , df=6
# likelihood ratio test: chi2=3.9765  , p=0.6799  , df=6
# parameter F test:         F=0.6567  , p=0.6848  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5444  , p=0.8011  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=3.8589  , p=0.7959  , df=7
# likelihood ratio test: chi2=3.8527  , p=0.7966  , df=7
# parameter F test:         F=0.5444  , p=0.8011  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8343  , p=0.5723  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=6.7705  , p=0.5616  , df=8
# likelihood ratio test: chi2=6.7515  , p=0.5637  , df=8
# parameter F test:         F=0.8343  , p=0.5723  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.8893  , p=0.5341  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=8.1327  , p=0.5208  , df=9
# likelihood ratio test: chi2=8.1052  , p=0.5236  , df=9
# parameter F test:         F=0.8893  , p=0.5341  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9069  , p=0.5259  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=9.2313  , p=0.5103  , df=10
# likelihood ratio test: chi2=9.1959  , p=0.5136  , df=10
# parameter F test:         F=0.9069  , p=0.5259  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.8335  , p=0.0159  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=5.8480  , p=0.0156  , df=1
# likelihood ratio test: chi2=5.8339  , p=0.0157  , df=1
# parameter F test:         F=5.8335  , p=0.0159  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.7612  , p=0.0235  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=7.5537  , p=0.0229  , df=2
# likelihood ratio test: chi2=7.5301  , p=0.0232  , df=2
# parameter F test:         F=3.7612  , p=0.0235  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.6787  , p=0.0457  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=8.0832  , p=0.0443  , df=3
# likelihood ratio test: chi2=8.0562  , p=0.0449  , df=3
# parameter F test:         F=2.6787  , p=0.0457  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.2142  , p=0.0655  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=8.9236  , p=0.0630  , df=4
# likelihood ratio test: chi2=8.8906  , p=0.0639  , df=4
# parameter F test:         F=2.2142  , p=0.0655  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.3394  , p=0.0053  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=16.8511 , p=0.0048  , df=5
# likelihood ratio test: chi2=16.7341 , p=0.0050  , df=5
# parameter F test:         F=3.3394  , p=0.0053  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.8560  , p=0.0091  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=17.3238 , p=0.0082  , df=6
# likelihood ratio test: chi2=17.2000 , p=0.0086  , df=6
# parameter F test:         F=2.8560  , p=0.0091  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.4146  , p=0.0186  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=17.1163 , p=0.0167  , df=7
# likelihood ratio test: chi2=16.9954 , p=0.0174  , df=7
# parameter F test:         F=2.4146  , p=0.0186  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.4618  , p=0.0120  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=19.9779 , p=0.0104  , df=8
# likelihood ratio test: chi2=19.8132 , p=0.0111  , df=8
# parameter F test:         F=2.4618  , p=0.0120  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.4404  , p=0.0094  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=22.3175 , p=0.0079  , df=9
# likelihood ratio test: chi2=22.1121 , p=0.0085  , df=9
# parameter F test:         F=2.4404  , p=0.0094  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.2051  , p=0.0155  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=22.4452 , p=0.0130  , df=10
# likelihood ratio test: chi2=22.2373 , p=0.0139  , df=10
# parameter F test:         F=2.2051  , p=0.0155  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0029  , p=0.9572  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=0.0029  , p=0.9572  , df=1
# likelihood ratio test: chi2=0.0029  , p=0.9572  , df=1
# parameter F test:         F=0.0029  , p=0.9572  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5283  , p=0.5897  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=1.0611  , p=0.5883  , df=2
# likelihood ratio test: chi2=1.0606  , p=0.5884  , df=2
# parameter F test:         F=0.5283  , p=0.5897  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4521  , p=0.7159  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=1.3642  , p=0.7140  , df=3
# likelihood ratio test: chi2=1.3634  , p=0.7141  , df=3
# parameter F test:         F=0.4521  , p=0.7159  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3820  , p=0.8216  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=1.5397  , p=0.8196  , df=4
# likelihood ratio test: chi2=1.5387  , p=0.8198  , df=4
# parameter F test:         F=0.3820  , p=0.8216  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4591  , p=0.8068  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=2.3167  , p=0.8038  , df=5
# likelihood ratio test: chi2=2.3144  , p=0.8041  , df=5
# parameter F test:         F=0.4591  , p=0.8068  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.3723  , p=0.8968  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=2.2585  , p=0.8945  , df=6
# likelihood ratio test: chi2=2.2564  , p=0.8947  , df=6
# parameter F test:         F=0.3723  , p=0.8968  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.4930  , p=0.8402  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=3.4946  , p=0.8358  , df=7
# likelihood ratio test: chi2=3.4895  , p=0.8363  , df=7
# parameter F test:         F=0.4930  , p=0.8402  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6165  , p=0.7646  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=5.0030  , p=0.7573  , df=8
# likelihood ratio test: chi2=4.9926  , p=0.7584  , df=8
# parameter F test:         F=0.6165  , p=0.7646  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7231  , p=0.6880  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=6.6132  , p=0.6773  , df=9
# likelihood ratio test: chi2=6.5950  , p=0.6792  , df=9
# parameter F test:         F=0.7231  , p=0.6880  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9682  , p=0.4695  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=9.8546  , p=0.4533  , df=10
# likelihood ratio test: chi2=9.8142  , p=0.4569  , df=10
# parameter F test:         F=0.9682  , p=0.4695  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2282  , p=0.6330  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=0.2287  , p=0.6325  , df=1
# likelihood ratio test: chi2=0.2287  , p=0.6325  , df=1
# parameter F test:         F=0.2282  , p=0.6330  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2279  , p=0.7962  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=0.4578  , p=0.7954  , df=2
# likelihood ratio test: chi2=0.4577  , p=0.7955  , df=2
# parameter F test:         F=0.2279  , p=0.7962  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1913  , p=0.9023  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=0.5773  , p=0.9016  , df=3
# likelihood ratio test: chi2=0.5772  , p=0.9016  , df=3
# parameter F test:         F=0.1913  , p=0.9023  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2418  , p=0.9147  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=0.9745  , p=0.9136  , df=4
# likelihood ratio test: chi2=0.9741  , p=0.9137  , df=4
# parameter F test:         F=0.2418  , p=0.9147  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.2605  , p=0.9346  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=1.3144  , p=0.9334  , df=5
# likelihood ratio test: chi2=1.3137  , p=0.9335  , df=5
# parameter F test:         F=0.2605  , p=0.9346  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6743  , p=0.6705  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=4.0901  , p=0.6645  , df=6
# likelihood ratio test: chi2=4.0832  , p=0.6654  , df=6
# parameter F test:         F=0.6743  , p=0.6705  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5489  , p=0.7975  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=3.8910  , p=0.7922  , df=7
# likelihood ratio test: chi2=3.8847  , p=0.7930  , df=7
# parameter F test:         F=0.5489  , p=0.7975  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5573  , p=0.8133  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=4.5227  , p=0.8072  , df=8
# likelihood ratio test: chi2=4.5142  , p=0.8080  , df=8
# parameter F test:         F=0.5573  , p=0.8133  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.4461  , p=0.9101  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=4.0796  , p=0.9061  , df=9
# likelihood ratio test: chi2=4.0727  , p=0.9066  , df=9
# parameter F test:         F=0.4461  , p=0.9101  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.4889  , p=0.8980  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=4.9765  , p=0.8927  , df=10
# likelihood ratio test: chi2=4.9662  , p=0.8934  , df=10
# parameter F test:         F=0.4889  , p=0.8980  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2282  , p=0.6330  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=0.2287  , p=0.6325  , df=1
# likelihood ratio test: chi2=0.2287  , p=0.6325  , df=1
# parameter F test:         F=0.2282  , p=0.6330  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2279  , p=0.7962  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=0.4578  , p=0.7954  , df=2
# likelihood ratio test: chi2=0.4577  , p=0.7955  , df=2
# parameter F test:         F=0.2279  , p=0.7962  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1913  , p=0.9023  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=0.5773  , p=0.9016  , df=3
# likelihood ratio test: chi2=0.5772  , p=0.9016  , df=3
# parameter F test:         F=0.1913  , p=0.9023  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2418  , p=0.9147  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=0.9745  , p=0.9136  , df=4
# likelihood ratio test: chi2=0.9741  , p=0.9137  , df=4
# parameter F test:         F=0.2418  , p=0.9147  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.2605  , p=0.9346  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=1.3144  , p=0.9334  , df=5
# likelihood ratio test: chi2=1.3137  , p=0.9335  , df=5
# parameter F test:         F=0.2605  , p=0.9346  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6743  , p=0.6705  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=4.0901  , p=0.6645  , df=6
# likelihood ratio test: chi2=4.0832  , p=0.6654  , df=6
# parameter F test:         F=0.6743  , p=0.6705  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.5489  , p=0.7975  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=3.8910  , p=0.7922  , df=7
# likelihood ratio test: chi2=3.8847  , p=0.7930  , df=7
# parameter F test:         F=0.5489  , p=0.7975  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.5573  , p=0.8133  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=4.5227  , p=0.8072  , df=8
# likelihood ratio test: chi2=4.5142  , p=0.8080  , df=8
# parameter F test:         F=0.5573  , p=0.8133  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.4461  , p=0.9101  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=4.0796  , p=0.9061  , df=9
# likelihood ratio test: chi2=4.0727  , p=0.9066  , df=9
# parameter F test:         F=0.4461  , p=0.9101  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.4889  , p=0.8980  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=4.9765  , p=0.8927  , df=10
# likelihood ratio test: chi2=4.9662  , p=0.8934  , df=10
# parameter F test:         F=0.4889  , p=0.8980  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=9.4216  , p=0.0022  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=9.4451  , p=0.0021  , df=1
# likelihood ratio test: chi2=9.4083  , p=0.0022  , df=1
# parameter F test:         F=9.4216  , p=0.0022  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.7991  , p=0.0031  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=11.6464 , p=0.0030  , df=2
# likelihood ratio test: chi2=11.5905 , p=0.0030  , df=2
# parameter F test:         F=5.7991  , p=0.0031  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.9359  , p=0.0083  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=11.8768 , p=0.0078  , df=3
# likelihood ratio test: chi2=11.8186 , p=0.0080  , df=3
# parameter F test:         F=3.9359  , p=0.0083  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.7146  , p=0.0052  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=14.9704 , p=0.0048  , df=4
# likelihood ratio test: chi2=14.8780 , p=0.0050  , df=4
# parameter F test:         F=3.7146  , p=0.0052  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.5748  , p=0.0033  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=18.0393 , p=0.0029  , df=5
# likelihood ratio test: chi2=17.9053 , p=0.0031  , df=5
# parameter F test:         F=3.5748  , p=0.0033  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.0667  , p=0.0055  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=18.6013 , p=0.0049  , df=6
# likelihood ratio test: chi2=18.4587 , p=0.0052  , df=6
# parameter F test:         F=3.0667  , p=0.0055  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.7962  , p=0.0069  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=19.8214 , p=0.0060  , df=7
# likelihood ratio test: chi2=19.6595 , p=0.0064  , df=7
# parameter F test:         F=2.7962  , p=0.0069  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.1279  , p=0.0017  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=25.3827 , p=0.0013  , df=8
# likelihood ratio test: chi2=25.1178 , p=0.0015  , df=8
# parameter F test:         F=3.1279  , p=0.0017  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.1866  , p=0.0008  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=29.1416 , p=0.0006  , df=9
# likelihood ratio test: chi2=28.7928 , p=0.0007  , df=9
# parameter F test:         F=3.1866  , p=0.0008  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.9179  , p=0.0013  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=29.7003 , p=0.0010  , df=10
# likelihood ratio test: chi2=29.3378 , p=0.0011  , df=10
# parameter F test:         F=2.9179  , p=0.0013  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.7967  , p=0.0947  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=2.8037  , p=0.0940  , df=1
# likelihood ratio test: chi2=2.8004  , p=0.0942  , df=1
# parameter F test:         F=2.7967  , p=0.0947  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5032  , p=0.2228  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=3.0190  , p=0.2210  , df=2
# likelihood ratio test: chi2=3.0152  , p=0.2214  , df=2
# parameter F test:         F=1.5032  , p=0.2228  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.7076  , p=0.1636  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=5.1529  , p=0.1609  , df=3
# likelihood ratio test: chi2=5.1419  , p=0.1617  , df=3
# parameter F test:         F=1.7076  , p=0.1636  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2969  , p=0.2693  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=5.2267  , p=0.2648  , df=4
# likelihood ratio test: chi2=5.2154  , p=0.2659  , df=4
# parameter F test:         F=1.2969  , p=0.2693  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.5757  , p=0.1640  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=7.9513  , p=0.1589  , df=5
# likelihood ratio test: chi2=7.9251  , p=0.1604  , df=5
# parameter F test:         F=1.5757  , p=0.1640  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3466  , p=0.2333  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=8.1679  , p=0.2261  , df=6
# likelihood ratio test: chi2=8.1403  , p=0.2280  , df=6
# parameter F test:         F=1.3466  , p=0.2333  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2364  , p=0.2794  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=8.7642  , p=0.2700  , df=7
# likelihood ratio test: chi2=8.7324  , p=0.2724  , df=7
# parameter F test:         F=1.2364  , p=0.2794  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1447  , p=0.3302  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=9.2895  , p=0.3185  , df=8
# likelihood ratio test: chi2=9.2537  , p=0.3214  , df=8
# parameter F test:         F=1.1447  , p=0.3302  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.7894  , p=0.0660  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=16.3637 , p=0.0597  , df=9
# likelihood ratio test: chi2=16.2529 , p=0.0618  , df=9
# parameter F test:         F=1.7894  , p=0.0660  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.7584  , p=0.0638  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=17.8979 , p=0.0567  , df=10
# likelihood ratio test: chi2=17.7654 , p=0.0591  , df=10
# parameter F test:         F=1.7584  , p=0.0638  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.7158  , p=0.0541  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=3.7251  , p=0.0536  , df=1
# likelihood ratio test: chi2=3.7193  , p=0.0538  , df=1
# parameter F test:         F=3.7158  , p=0.0541  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.7745  , p=0.0628  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=5.5722  , p=0.0617  , df=2
# likelihood ratio test: chi2=5.5593  , p=0.0621  , df=2
# parameter F test:         F=2.7745  , p=0.0628  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.9151  , p=0.1253  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=5.7790  , p=0.1229  , df=3
# likelihood ratio test: chi2=5.7651  , p=0.1236  , df=3
# parameter F test:         F=1.9151  , p=0.1253  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.6674  , p=0.1552  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=6.7198  , p=0.1515  , df=4
# likelihood ratio test: chi2=6.7011  , p=0.1526  , df=4
# parameter F test:         F=1.6674  , p=0.1552  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.8137  , p=0.1073  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=9.1521  , p=0.1031  , df=5
# likelihood ratio test: chi2=9.1174  , p=0.1045  , df=5
# parameter F test:         F=1.8137  , p=0.1073  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.9194  , p=0.0746  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=11.6426 , p=0.0704  , df=6
# likelihood ratio test: chi2=11.5865 , p=0.0719  , df=6
# parameter F test:         F=1.9194  , p=0.0746  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.8978  , p=0.0665  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=13.4531 , p=0.0618  , df=7
# likelihood ratio test: chi2=13.3782 , p=0.0634  , df=7
# parameter F test:         F=1.8978  , p=0.0665  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.7244  , p=0.0885  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=13.9936 , p=0.0819  , df=8
# likelihood ratio test: chi2=13.9125 , p=0.0841  , df=8
# parameter F test:         F=1.7244  , p=0.0885  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.5677  , p=0.1200  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=14.3368 , p=0.1108  , df=9
# likelihood ratio test: chi2=14.2517 , p=0.1136  , df=9
# parameter F test:         F=1.5677  , p=0.1200  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3680  , p=0.1897  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=13.9240 , p=0.1765  , df=10
# likelihood ratio test: chi2=13.8436 , p=0.1802  , df=10
# parameter F test:         F=1.3680  , p=0.1897  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=15.9407 , p=0.0001  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=15.9804 , p=0.0001  , df=1
# likelihood ratio test: chi2=15.8755 , p=0.0001  , df=1
# parameter F test:         F=15.9407 , p=0.0001  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.9575  , p=0.0004  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=15.9812 , p=0.0003  , df=2
# likelihood ratio test: chi2=15.8762 , p=0.0004  , df=2
# parameter F test:         F=7.9575  , p=0.0004  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.2144  , p=0.0014  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=15.7346 , p=0.0013  , df=3
# likelihood ratio test: chi2=15.6327 , p=0.0013  , df=3
# parameter F test:         F=5.2144  , p=0.0014  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.3566  , p=0.0017  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=17.5578 , p=0.0015  , df=4
# likelihood ratio test: chi2=17.4309 , p=0.0016  , df=4
# parameter F test:         F=4.3566  , p=0.0017  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=4.4705  , p=0.0005  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=22.5588 , p=0.0004  , df=5
# likelihood ratio test: chi2=22.3497 , p=0.0004  , df=5
# parameter F test:         F=4.4705  , p=0.0005  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.9117  , p=0.0007  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=23.7271 , p=0.0006  , df=6
# likelihood ratio test: chi2=23.4957 , p=0.0006  , df=6
# parameter F test:         F=3.9117  , p=0.0007  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=3.3819  , p=0.0014  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=23.9731 , p=0.0012  , df=7
# likelihood ratio test: chi2=23.7368 , p=0.0013  , df=7
# parameter F test:         F=3.3819  , p=0.0014  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=3.2857  , p=0.0010  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=26.6638 , p=0.0008  , df=8
# likelihood ratio test: chi2=26.3716 , p=0.0009  , df=8
# parameter F test:         F=3.2857  , p=0.0010  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.0134  , p=0.0015  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=27.5581 , p=0.0011  , df=9
# likelihood ratio test: chi2=27.2459 , p=0.0013  , df=9
# parameter F test:         F=3.0134  , p=0.0015  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.6383  , p=0.0035  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=26.8538 , p=0.0027  , df=10
# likelihood ratio test: chi2=26.5570 , p=0.0031  , df=10
# parameter F test:         F=2.6383  , p=0.0035  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.5926  , p=0.2072  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=1.5965  , p=0.2064  , df=1
# likelihood ratio test: chi2=1.5955  , p=0.2065  , df=1
# parameter F test:         F=1.5926  , p=0.2072  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8322  , p=0.4354  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=1.6713  , p=0.4336  , df=2
# likelihood ratio test: chi2=1.6701  , p=0.4338  , df=2
# parameter F test:         F=0.8322  , p=0.4354  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0467  , p=0.3709  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=3.1585  , p=0.3678  , df=3
# likelihood ratio test: chi2=3.1544  , p=0.3684  , df=3
# parameter F test:         F=1.0467  , p=0.3709  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.2525  , p=0.0115  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=13.1079 , p=0.0108  , df=4
# likelihood ratio test: chi2=13.0370 , p=0.0111  , df=4
# parameter F test:         F=3.2525  , p=0.0115  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.6313  , p=0.0225  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=13.2778 , p=0.0209  , df=5
# likelihood ratio test: chi2=13.2050 , p=0.0215  , df=5
# parameter F test:         F=2.6313  , p=0.0225  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.2446  , p=0.0369  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=13.6152 , p=0.0342  , df=6
# likelihood ratio test: chi2=13.5386 , p=0.0352  , df=6
# parameter F test:         F=2.2446  , p=0.0369  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.0613  , p=0.0449  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=14.6119 , p=0.0413  , df=7
# likelihood ratio test: chi2=14.5237 , p=0.0426  , df=7
# parameter F test:         F=2.0613  , p=0.0449  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.7876  , p=0.0754  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=14.5068 , p=0.0695  , df=8
# likelihood ratio test: chi2=14.4197 , p=0.0715  , df=8
# parameter F test:         F=1.7876  , p=0.0754  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.6556  , p=0.0951  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=15.1406 , p=0.0871  , df=9
# likelihood ratio test: chi2=15.0457 , p=0.0897  , df=9
# parameter F test:         F=1.6556  , p=0.0951  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.5307  , p=0.1229  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=15.5801 , p=0.1123  , df=10
# likelihood ratio test: chi2=15.4796 , p=0.1155  , df=10
# parameter F test:         F=1.5307  , p=0.1229  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.0404  , p=0.0446  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=4.0505  , p=0.0442  , df=1
# likelihood ratio test: chi2=4.0437  , p=0.0443  , df=1
# parameter F test:         F=4.0404  , p=0.0446  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.0319  , p=0.1315  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=4.0808  , p=0.1300  , df=2
# likelihood ratio test: chi2=4.0739  , p=0.1304  , df=2
# parameter F test:         F=2.0319  , p=0.1315  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4805  , p=0.2181  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=4.4675  , p=0.2152  , df=3
# likelihood ratio test: chi2=4.4593  , p=0.2160  , df=3
# parameter F test:         F=1.4805  , p=0.2181  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.1419  , p=0.3352  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=4.6021  , p=0.3306  , df=4
# likelihood ratio test: chi2=4.5933  , p=0.3316  , df=4
# parameter F test:         F=1.1419  , p=0.3352  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.2306  , p=0.2924  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=6.2100  , p=0.2863  , df=5
# likelihood ratio test: chi2=6.1941  , p=0.2878  , df=5
# parameter F test:         F=1.2306  , p=0.2924  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.1280  , p=0.3436  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=6.8420  , p=0.3357  , df=6
# likelihood ratio test: chi2=6.8225  , p=0.3376  , df=6
# parameter F test:         F=1.1280  , p=0.3436  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.9469  , p=0.4691  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=6.7121  , p=0.4595  , df=7
# likelihood ratio test: chi2=6.6934  , p=0.4615  , df=7
# parameter F test:         F=0.9469  , p=0.4691  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.8795  , p=0.5331  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=7.1372  , p=0.5219  , df=8
# likelihood ratio test: chi2=7.1161  , p=0.5242  , df=8
# parameter F test:         F=0.8795  , p=0.5331  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.7959  , p=0.6202  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=7.2784  , p=0.6082  , df=9
# likelihood ratio test: chi2=7.2564  , p=0.6104  , df=9
# parameter F test:         F=0.7959  , p=0.6202  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8788  , p=0.5526  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=8.9448  , p=0.5374  , df=10
# likelihood ratio test: chi2=8.9115  , p=0.5405  , df=10
# parameter F test:         F=0.8788  , p=0.5526  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.3222  , p=0.1278  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=2.3280  , p=0.1271  , df=1
# likelihood ratio test: chi2=2.3257  , p=0.1272  , df=1
# parameter F test:         F=2.3222  , p=0.1278  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.5089  , p=0.0302  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=7.0471  , p=0.0295  , df=2
# likelihood ratio test: chi2=7.0266  , p=0.0298  , df=2
# parameter F test:         F=3.5089  , p=0.0302  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.3453  , p=0.0713  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=7.0771  , p=0.0695  , df=3
# likelihood ratio test: chi2=7.0564  , p=0.0701  , df=3
# parameter F test:         F=2.3453  , p=0.0713  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.9768  , p=0.0958  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=7.9670  , p=0.0928  , df=4
# likelihood ratio test: chi2=7.9407  , p=0.0938  , df=4
# parameter F test:         F=1.9768  , p=0.0958  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.6084  , p=0.1549  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=8.1162  , p=0.1499  , df=5
# likelihood ratio test: chi2=8.0889  , p=0.1514  , df=5
# parameter F test:         F=1.6084  , p=0.1549  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3814  , p=0.2187  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=8.3790  , p=0.2116  , df=6
# likelihood ratio test: chi2=8.3499  , p=0.2136  , df=6
# parameter F test:         F=1.3814  , p=0.2187  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.3406  , p=0.2274  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=9.5031  , p=0.2185  , df=7
# likelihood ratio test: chi2=9.4656  , p=0.2209  , df=7
# parameter F test:         F=1.3406  , p=0.2274  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2004  , p=0.2951  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=9.7411  , p=0.2837  , df=8
# likelihood ratio test: chi2=9.7018  , p=0.2866  , df=8
# parameter F test:         F=1.2004  , p=0.2951  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.1880  , p=0.2986  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=10.8647 , p=0.2851  , df=9
# likelihood ratio test: chi2=10.8157 , p=0.2886  , df=9
# parameter F test:         F=1.1880  , p=0.2986  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3455  , p=0.2009  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=13.6953 , p=0.1873  , df=10
# likelihood ratio test: chi2=13.6175 , p=0.1912  , df=10
# parameter F test:         F=1.3455  , p=0.2009  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4473  , p=0.5038  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=0.4484  , p=0.5031  , df=1
# likelihood ratio test: chi2=0.4483  , p=0.5031  , df=1
# parameter F test:         F=0.4473  , p=0.5038  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8393  , p=0.4322  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=1.6857  , p=0.4305  , df=2
# likelihood ratio test: chi2=1.6845  , p=0.4307  , df=2
# parameter F test:         F=0.8393  , p=0.4322  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7845  , p=0.5026  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=2.3674  , p=0.4997  , df=3
# likelihood ratio test: chi2=2.3651  , p=0.5002  , df=3
# parameter F test:         F=0.7845  , p=0.5026  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7304  , p=0.5712  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=2.9435  , p=0.5673  , df=4
# likelihood ratio test: chi2=2.9399  , p=0.5679  , df=4
# parameter F test:         F=0.7304  , p=0.5712  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.7862  , p=0.5596  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=3.9673  , p=0.5541  , df=5
# likelihood ratio test: chi2=3.9608  , p=0.5551  , df=5
# parameter F test:         F=0.7862  , p=0.5596  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.6667  , p=0.6766  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=4.0441  , p=0.6707  , df=6
# likelihood ratio test: chi2=4.0373  , p=0.6716  , df=6
# parameter F test:         F=0.6667  , p=0.6766  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.6890  , p=0.6815  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=4.8840  , p=0.6741  , df=7
# likelihood ratio test: chi2=4.8741  , p=0.6753  , df=7
# parameter F test:         F=0.6890  , p=0.6815  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=0.6845  , p=0.7056  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=5.5547  , p=0.6970  , df=8
# likelihood ratio test: chi2=5.5418  , p=0.6984  , df=8
# parameter F test:         F=0.6845  , p=0.7056  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0173  , p=0.4238  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=9.3030  , p=0.4098  , df=9
# likelihood ratio test: chi2=9.2670  , p=0.4130  , df=9
# parameter F test:         F=1.0173  , p=0.4238  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8896  , p=0.5423  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=9.0547  , p=0.5269  , df=10
# likelihood ratio test: chi2=9.0206  , p=0.5301  , df=10
# parameter F test:         F=0.8896  , p=0.5423  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.8893  , p=0.1695  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=1.8940  , p=0.1687  , df=1
# likelihood ratio test: chi2=1.8925  , p=0.1689  , df=1
# parameter F test:         F=1.8893  , p=0.1695  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.4795  , p=0.2282  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=2.9714  , p=0.2263  , df=2
# likelihood ratio test: chi2=2.9678  , p=0.2268  , df=2
# parameter F test:         F=1.4795  , p=0.2282  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0209  , p=0.3825  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=3.0805  , p=0.3794  , df=3
# likelihood ratio test: chi2=3.0765  , p=0.3800  , df=3
# parameter F test:         F=1.0209  , p=0.3825  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7644  , p=0.5485  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=3.0805  , p=0.5444  , df=4
# likelihood ratio test: chi2=3.0766  , p=0.5451  , df=4
# parameter F test:         F=0.7644  , p=0.5485  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.6474  , p=0.6635  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=3.2670  , p=0.6589  , df=5
# likelihood ratio test: chi2=3.2626  , p=0.6596  , df=5
# parameter F test:         F=0.6474  , p=0.6635  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5735  , p=0.7517  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=3.4789  , p=0.7468  , df=6
# likelihood ratio test: chi2=3.4738  , p=0.7474  , df=6
# parameter F test:         F=0.5735  , p=0.7517  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.0656  , p=0.3834  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=7.5539  , p=0.3736  , df=7
# likelihood ratio test: chi2=7.5303  , p=0.3758  , df=7
# parameter F test:         F=1.0656  , p=0.3834  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.0286  , p=0.4122  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=8.3473  , p=0.4003  , df=8
# likelihood ratio test: chi2=8.3184  , p=0.4030  , df=8
# parameter F test:         F=1.0286  , p=0.4122  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.5563  , p=0.1236  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=14.2327 , p=0.1143  , df=9
# likelihood ratio test: chi2=14.1488 , p=0.1171  , df=9
# parameter F test:         F=1.5563  , p=0.1236  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3491  , p=0.1991  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=13.7318 , p=0.1856  , df=10
# likelihood ratio test: chi2=13.6536 , p=0.1894  , df=10
# parameter F test:         F=1.3491  , p=0.1991  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.7887  , p=0.1813  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=1.7932  , p=0.1805  , df=1
# likelihood ratio test: chi2=1.7918  , p=0.1807  , df=1
# parameter F test:         F=1.7887  , p=0.1813  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.3482  , p=0.2601  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=2.7076  , p=0.2583  , df=2
# likelihood ratio test: chi2=2.7045  , p=0.2587  , df=2
# parameter F test:         F=1.3482  , p=0.2601  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0240  , p=0.3811  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=3.0899  , p=0.3780  , df=3
# likelihood ratio test: chi2=3.0860  , p=0.3786  , df=3
# parameter F test:         F=1.0240  , p=0.3811  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7502  , p=0.5579  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=3.0234  , p=0.5539  , df=4
# likelihood ratio test: chi2=3.0196  , p=0.5546  , df=4
# parameter F test:         F=0.7502  , p=0.5579  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5861  , p=0.7107  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=2.9577  , p=0.7065  , df=5
# likelihood ratio test: chi2=2.9541  , p=0.7071  , df=5
# parameter F test:         F=0.5861  , p=0.7107  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.5519  , p=0.7688  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=3.3474  , p=0.7642  , df=6
# likelihood ratio test: chi2=3.3427  , p=0.7648  , df=6
# parameter F test:         F=0.5519  , p=0.7688  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.2572  , p=0.2683  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=8.9121  , p=0.2590  , df=7
# likelihood ratio test: chi2=8.8792  , p=0.2614  , df=7
# parameter F test:         F=1.2572  , p=0.2683  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2159  , p=0.2858  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=9.8671  , p=0.2745  , df=8
# likelihood ratio test: chi2=9.8268  , p=0.2774  , df=8
# parameter F test:         F=1.2159  , p=0.2858  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.5840  , p=0.1150  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=14.4854 , p=0.1061  , df=9
# likelihood ratio test: chi2=14.3985 , p=0.1088  , df=9
# parameter F test:         F=1.5840  , p=0.1150  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.3651  , p=0.1911  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=13.8944 , p=0.1779  , df=10
# likelihood ratio test: chi2=13.8144 , p=0.1816  , df=10
# parameter F test:         F=1.3651  , p=0.1911  , df_denom=1176, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.9457  , p=0.0149  , df_denom=1203, df_num=1
# ssr based chi2 test:   chi2=5.9605  , p=0.0146  , df=1
# likelihood ratio test: chi2=5.9459  , p=0.0148  , df=1
# parameter F test:         F=5.9457  , p=0.0149  , df_denom=1203, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.4539  , p=0.0319  , df_denom=1200, df_num=2
# ssr based chi2 test:   chi2=6.9365  , p=0.0312  , df=2
# likelihood ratio test: chi2=6.9166  , p=0.0315  , df=2
# parameter F test:         F=3.4539  , p=0.0319  , df_denom=1200, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.4063  , p=0.0658  , df_denom=1197, df_num=3
# ssr based chi2 test:   chi2=7.2610  , p=0.0640  , df=3
# likelihood ratio test: chi2=7.2392  , p=0.0647  , df=3
# parameter F test:         F=2.4063  , p=0.0658  , df_denom=1197, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.7807  , p=0.1303  , df_denom=1194, df_num=4
# ssr based chi2 test:   chi2=7.1766  , p=0.1268  , df=4
# likelihood ratio test: chi2=7.1553  , p=0.1279  , df=4
# parameter F test:         F=1.7807  , p=0.1303  , df_denom=1194, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.4614  , p=0.1997  , df_denom=1191, df_num=5
# ssr based chi2 test:   chi2=7.3745  , p=0.1942  , df=5
# likelihood ratio test: chi2=7.3520  , p=0.1957  , df=5
# parameter F test:         F=1.4614  , p=0.1997  , df_denom=1191, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.3663  , p=0.2250  , df_denom=1188, df_num=6
# ssr based chi2 test:   chi2=8.2874  , p=0.2178  , df=6
# likelihood ratio test: chi2=8.2590  , p=0.2197  , df=6
# parameter F test:         F=1.3663  , p=0.2250  , df_denom=1188, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.4108  , p=0.1969  , df_denom=1185, df_num=7
# ssr based chi2 test:   chi2=10.0004 , p=0.1885  , df=7
# likelihood ratio test: chi2=9.9590  , p=0.1909  , df=7
# parameter F test:         F=1.4108  , p=0.1969  , df_denom=1185, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.2543  , p=0.2638  , df_denom=1182, df_num=8
# ssr based chi2 test:   chi2=10.1784 , p=0.2527  , df=8
# likelihood ratio test: chi2=10.1354 , p=0.2557  , df=8
# parameter F test:         F=1.2543  , p=0.2638  , df_denom=1182, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0709  , p=0.3815  , df_denom=1179, df_num=9
# ssr based chi2 test:   chi2=9.7930  , p=0.3675  , df=9
# likelihood ratio test: chi2=9.7532  , p=0.3708  , df=9
# parameter F test:         F=1.0709  , p=0.3815  , df_denom=1179, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.0411  , p=0.4061  , df_denom=1176, df_num=10
# ssr based chi2 test:   chi2=10.5972 , p=0.3897  , df=10
# likelihood ratio test: chi2=10.5506 , p=0.3936  , df=10
# parameter F test:         F=1.0411  , p=0.4061  , df_denom=1176, df_num=10

# %%
GC_stock
# Out:
# ['ALV', 'F', 'GM', 'TM', 'TRYUSD=X', 'WFC', 'X', 'ALI=F']

# %%
optimal_lag
# Out:
# [np.int64(2),
#  np.int64(5),
#  np.int64(9),
#  np.int64(1),
#  np.int64(4),
#  np.int64(1),
#  np.int64(2),
#  np.int64(1)]

# %% [markdown]
# From this table, we found that the followings causality:
# - Tesla causes Meta, Ford, Palladium
# - Apple causes Microsoft, NVIDIA, Amazon, Meta, Gold, Palladium
# - Google causes Microsoft, Amazon, Meta, Oil, Ford, Palladium
# - Microsoft causes Apple, Google, Amazon, Meta, Gold, Ford, Palladium
# - NVIDIA causes Google, Microsoft, Amazon, Meta, Gold
# - Amazon causes Tesla, TGold, Ford, Palladium
# - Meta causes Amazon, TSMC, Ford, Palladium
# - TSMC causes Apple, Gold, Ford, Palladium
# - Gold causes Oil, Palladium
# - Oil causes Google, Microsoft, Gold, Palladium
# - Ford causes Tesla, NVIDIA, TSMC, Gold, Oil, Palladium
# - Palladium causes Tesla
