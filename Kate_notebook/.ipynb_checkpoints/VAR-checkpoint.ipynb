# %% [markdown]
# # VAR

# %%
import pandas as pd
import numpy as np

## Plotting
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime
from sklearn.metrics import mean_squared_error

from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import acf, pacf, grangercausalitytests
from statsmodels.tsa.statespace.varmax import VARMAX

## Import TimeSeriesSplit
from sklearn.model_selection import TimeSeriesSplit

import yfinance as yf

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss

# %%
# Import data
df = pd.read_csv('../Data/dataset_others.csv')

# %%
df
# Out:
#                            Date  CADUSD=X_Open  CADUSD=X_Close  CADUSD=X_High  \
# 0     2019-11-26 00:00:00+00:00       0.751665        0.751705       0.752842
# 1     2019-11-27 00:00:00+00:00       0.753597        0.753636       0.754205
# 2     2019-11-29 00:00:00+00:00       0.753125        0.753029       0.753211
# 3     2019-12-02 00:00:00+00:00       0.752734        0.752791       0.753296
# 4     2019-12-03 00:00:00+00:00       0.751552        0.751710       0.752899
# ...                         ...            ...             ...            ...
# 1232  2024-10-22 00:00:00+00:00       0.722883        0.722883       0.723877
# 1233  2024-10-23 00:00:00+00:00       0.723788        0.723788       0.723809
# 1234  2024-10-24 00:00:00+00:00       0.722716        0.722716       0.724008
# 1235  2024-10-25 00:00:00+00:00       0.721850        0.721850       0.722648
# 1236  2024-10-28 00:00:00+00:00       0.719652        0.719652       0.720326
#
#       CADUSD=X_Low  CADUSD=X_Volume  CADUSD=X_Change  CADUSD=X_Gain  \
# 0         0.750999              0.0        -0.000418       0.000000
# 1         0.752502              0.0         0.001932       0.001932
# 2         0.751145              0.0        -0.000607       0.000000
# 3         0.751569              0.0        -0.000238       0.000000
# 4         0.750728              0.0        -0.001081       0.000000
# ...            ...              ...              ...            ...
# 1232      0.722684              0.0        -0.001776       0.000000
# 1233      0.721433              0.0         0.000905       0.000905
# 1234      0.721480              0.0        -0.001072       0.000000
# 1235      0.720170              0.0        -0.000866       0.000000
# 1236      0.719031              0.0        -0.002197       0.000000
#
#       CADUSD=X_Loss  CADUSD=X_Avg_Gain  ...  F_change_in_price      F_RSI  \
# 0          0.000418           0.000289  ...           0.010000  62.087549
# 1          0.000000           0.000427  ...           0.090000  67.610216
# 2          0.000607           0.000427  ...          -0.040000  62.910674
# 3          0.000238           0.000419  ...          -0.050000  57.178300
# 4          0.001081           0.000419  ...          -0.120000  45.657569
# ...             ...                ...  ...                ...        ...
# 1232       0.001776           0.000308  ...           0.230000  63.192190
# 1233       0.000000           0.000245  ...          -0.049999  59.825069
# 1234       0.001072           0.000245  ...           0.179999  67.105734
# 1235       0.000866           0.000245  ...          -0.170000  56.038726
# 1236       0.002197           0.000245  ...           0.300000  67.090123
#
#       F_k_percent  F_r_percent    F_MACD  F_MACD_EMA     F_ROC         F_PVT  \
# 0       73.913071   -26.086929  0.006892    0.002249 -0.331855  2.394865e+06
# 1       89.583482   -10.416518  0.019164    0.005663  0.220269  2.768411e+06
# 2       81.250149   -18.749851  0.025755    0.009711  0.221244  2.710846e+06
# 3       70.833433   -29.166567  0.027163    0.013223  2.270145  2.505366e+06
# 4       45.833433   -54.166567  0.019687    0.014522  1.137661  1.963927e+06
# ...           ...          ...       ...         ...       ...           ...
# 1232    91.764633    -8.235367  0.063288    0.007636  6.315788  6.779642e+07
# 1233    80.219848   -19.780152  0.071755    0.020460  4.635769  6.762839e+07
# 1234    98.850548    -1.149452  0.091931    0.034754  7.149667  6.835647e+07
# 1235    72.631549   -27.368451  0.093129    0.046429  4.237286  6.776479e+07
# 1236    97.894690    -2.105310  0.116938    0.060531  6.460670  7.041972e+07
#
#       F_Bollinger_Upper  F_Bollinger_Lower
# 0              9.188927           8.586074
# 1              9.183159           8.647842
# 2              9.165730           8.712270
# 3              9.172619           8.717381
# 4              9.166840           8.712161
# ...                 ...                ...
# 1232          11.195281          10.306719
# 1233          11.223237          10.297763
# 1234          11.282170          10.320830
# 1235          11.312438          10.329562
# 1236          11.399086          10.301914
#
# [1237 rows x 155 columns]

# %%
df.columns
# Out:
# Index(['Date', 'CADUSD=X_Open', 'CADUSD=X_Close', 'CADUSD=X_High',
#        'CADUSD=X_Low', 'CADUSD=X_Volume', 'CADUSD=X_Change', 'CADUSD=X_Gain',
#        'CADUSD=X_Loss', 'CADUSD=X_Avg_Gain',
#        ...
#        'F_change_in_price', 'F_RSI', 'F_k_percent', 'F_r_percent', 'F_MACD',
#        'F_MACD_EMA', 'F_ROC', 'F_PVT', 'F_Bollinger_Upper',
#        'F_Bollinger_Lower'],
#       dtype='object', length=155)

# %%
# Extract _change_in_price columns
change_in_price_cols = [col for col in df.columns if '_change_in_price' in col]

# %%
df_change = df[change_in_price_cols].copy()

# %%
df_change
# Out:
#       CADUSD=X_change_in_price  GM_change_in_price  JCI_change_in_price  \
# 0                    -0.000418            0.099998             0.330002
# 1                     0.001932            0.230000             0.160000
# 2                    -0.000607           -0.139999            -0.279999
# 3                    -0.000238           -0.119999            -0.560001
# 4                    -0.001081           -0.350002            -0.480000
# ...                        ...                 ...                  ...
# 1232                 -0.001776            4.799999            -0.529999
# 1233                  0.000905           -0.810001            -0.159996
# 1234                 -0.001072           -0.199997             0.379997
# 1235                 -0.000866           -0.650002            -0.120003
# 1236                 -0.002197            0.660000             0.990005
#
#       TM_change_in_price  TRYUSD=X_change_in_price  ^IXIC_change_in_price  \
# 0              -0.569992                 -0.000812              15.439453
# 1              -0.309998                 -0.000532              57.250000
# 2              -1.449997                  0.000039             -39.709961
# 3               0.059998                  0.000314             -97.479492
# 4               0.459991                  0.000223             -47.350586
# ...                  ...                       ...                    ...
# 1232            0.759995                  0.000026              39.759766
# 1233            1.400009                 -0.000006            -303.119141
# 1234           -0.900009                 -0.000013             138.839844
# 1235            1.570007                 -0.000016             103.119141
# 1236            4.630005                  0.000004              48.580078
#
#       F_change_in_price
# 0              0.010000
# 1              0.090000
# 2             -0.040000
# 3             -0.050000
# 4             -0.120000
# ...                 ...
# 1232           0.230000
# 1233          -0.049999
# 1234           0.179999
# 1235          -0.170000
# 1236           0.300000
#
# [1237 rows x 7 columns]

# %% [markdown]
# ## Granger-Causality

# %%
GC_stock = []
optimal_lag = []

for t in change_in_price_cols:
    df1 = df[['F_change_in_price', t]].copy()
    test_result = grangercausalitytests(df1.dropna(), maxlag=10)
    p_values = [round(test_result[i+1][0]['ssr_ftest'][1],4) for i in range(10)]
    min_p_value = np.min(p_values)
    if min_p_value < 0.05:
        GC_stock.append(t)
        optimal_lag.append(1 + np.argmin(p_values))
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.8966  , p=0.0153  , df_denom=1233, df_num=1
# ssr based chi2 test:   chi2=5.9109  , p=0.0150  , df=1
# likelihood ratio test: chi2=5.8968  , p=0.0152  , df=1
# parameter F test:         F=5.8966  , p=0.0153  , df_denom=1233, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.2926  , p=0.0375  , df_denom=1230, df_num=2
# ssr based chi2 test:   chi2=6.6120  , p=0.0367  , df=2
# likelihood ratio test: chi2=6.5943  , p=0.0370  , df=2
# parameter F test:         F=3.2926  , p=0.0375  , df_denom=1230, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.4183  , p=0.0647  , df_denom=1227, df_num=3
# ssr based chi2 test:   chi2=7.2963  , p=0.0630  , df=3
# likelihood ratio test: chi2=7.2748  , p=0.0636  , df=3
# parameter F test:         F=2.4183  , p=0.0647  , df_denom=1227, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.8530  , p=0.1164  , df_denom=1224, df_num=4
# ssr based chi2 test:   chi2=7.4664  , p=0.1132  , df=4
# likelihood ratio test: chi2=7.4439  , p=0.1142  , df=4
# parameter F test:         F=1.8530  , p=0.1164  , df_denom=1224, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.2976  , p=0.0432  , df_denom=1221, df_num=5
# ssr based chi2 test:   chi2=11.5914 , p=0.0408  , df=5
# likelihood ratio test: chi2=11.5372 , p=0.0417  , df=5
# parameter F test:         F=2.2976  , p=0.0432  , df_denom=1221, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.3393  , p=0.0299  , df_denom=1218, df_num=6
# ssr based chi2 test:   chi2=14.1856 , p=0.0276  , df=6
# likelihood ratio test: chi2=14.1045 , p=0.0285  , df=6
# parameter F test:         F=2.3393  , p=0.0299  , df_denom=1218, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.9988  , p=0.0523  , df_denom=1215, df_num=7
# ssr based chi2 test:   chi2=14.1643 , p=0.0483  , df=7
# likelihood ratio test: chi2=14.0833 , p=0.0497  , df=7
# parameter F test:         F=1.9988  , p=0.0523  , df_denom=1215, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.3937  , p=0.0146  , df_denom=1212, df_num=8
# ssr based chi2 test:   chi2=19.4179 , p=0.0128  , df=8
# likelihood ratio test: chi2=19.2661 , p=0.0135  , df=8
# parameter F test:         F=2.3937  , p=0.0146  , df_denom=1212, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.0372  , p=0.0324  , df_denom=1209, df_num=9
# ssr based chi2 test:   chi2=18.6230 , p=0.0286  , df=9
# likelihood ratio test: chi2=18.4832 , p=0.0300  , df=9
# parameter F test:         F=2.0372  , p=0.0324  , df_denom=1209, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.9644  , p=0.0338  , df_denom=1206, df_num=10
# ssr based chi2 test:   chi2=19.9865 , p=0.0294  , df=10
# likelihood ratio test: chi2=19.8254 , p=0.0309  , df=10
# parameter F test:         F=1.9644  , p=0.0338  , df_denom=1206, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1912  , p=0.6620  , df_denom=1233, df_num=1
# ssr based chi2 test:   chi2=0.1917  , p=0.6615  , df=1
# likelihood ratio test: chi2=0.1917  , p=0.6615  , df=1
# parameter F test:         F=0.1912  , p=0.6620  , df_denom=1233, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.1369  , p=0.0438  , df_denom=1230, df_num=2
# ssr based chi2 test:   chi2=6.2992  , p=0.0429  , df=2
# likelihood ratio test: chi2=6.2832  , p=0.0432  , df=2
# parameter F test:         F=3.1369  , p=0.0438  , df_denom=1230, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.2904  , p=0.0767  , df_denom=1227, df_num=3
# ssr based chi2 test:   chi2=6.9104  , p=0.0748  , df=3
# likelihood ratio test: chi2=6.8911  , p=0.0755  , df=3
# parameter F test:         F=2.2904  , p=0.0767  , df_denom=1227, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.5537  , p=0.0375  , df_denom=1224, df_num=4
# ssr based chi2 test:   chi2=10.2901 , p=0.0358  , df=4
# likelihood ratio test: chi2=10.2474 , p=0.0365  , df=4
# parameter F test:         F=2.5537  , p=0.0375  , df_denom=1224, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.0595  , p=0.0680  , df_denom=1221, df_num=5
# ssr based chi2 test:   chi2=10.3901 , p=0.0649  , df=5
# likelihood ratio test: chi2=10.3465 , p=0.0660  , df=5
# parameter F test:         F=2.0595  , p=0.0680  , df_denom=1221, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.8623  , p=0.0841  , df_denom=1218, df_num=6
# ssr based chi2 test:   chi2=11.2932 , p=0.0797  , df=6
# likelihood ratio test: chi2=11.2417 , p=0.0812  , df=6
# parameter F test:         F=1.8623  , p=0.0841  , df_denom=1218, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.5728  , p=0.1394  , df_denom=1215, df_num=7
# ssr based chi2 test:   chi2=11.1456 , p=0.1324  , df=7
# likelihood ratio test: chi2=11.0954 , p=0.1345  , df=7
# parameter F test:         F=1.5728  , p=0.1394  , df_denom=1215, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.4417  , p=0.1746  , df_denom=1212, df_num=8
# ssr based chi2 test:   chi2=11.6955 , p=0.1653  , df=8
# likelihood ratio test: chi2=11.6402 , p=0.1680  , df=8
# parameter F test:         F=1.4417  , p=0.1746  , df_denom=1212, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.3570  , p=0.2030  , df_denom=1209, df_num=9
# ssr based chi2 test:   chi2=12.4050 , p=0.1914  , df=9
# likelihood ratio test: chi2=12.3428 , p=0.1947  , df=9
# parameter F test:         F=1.3570  , p=0.2030  , df_denom=1209, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.2148  , p=0.2766  , df_denom=1206, df_num=10
# ssr based chi2 test:   chi2=12.3597 , p=0.2617  , df=10
# likelihood ratio test: chi2=12.2979 , p=0.2656  , df=10
# parameter F test:         F=1.2148  , p=0.2766  , df_denom=1206, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.6860  , p=0.1944  , df_denom=1233, df_num=1
# ssr based chi2 test:   chi2=1.6901  , p=0.1936  , df=1
# likelihood ratio test: chi2=1.6889  , p=0.1937  , df=1
# parameter F test:         F=1.6860  , p=0.1944  , df_denom=1233, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.2716  , p=0.0383  , df_denom=1230, df_num=2
# ssr based chi2 test:   chi2=6.5697  , p=0.0374  , df=2
# likelihood ratio test: chi2=6.5523  , p=0.0378  , df=2
# parameter F test:         F=3.2716  , p=0.0383  , df_denom=1230, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.2736  , p=0.0784  , df_denom=1227, df_num=3
# ssr based chi2 test:   chi2=6.8596  , p=0.0765  , df=3
# likelihood ratio test: chi2=6.8406  , p=0.0772  , df=3
# parameter F test:         F=2.2736  , p=0.0784  , df_denom=1227, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.7453  , p=0.1376  , df_denom=1224, df_num=4
# ssr based chi2 test:   chi2=7.0326  , p=0.1342  , df=4
# likelihood ratio test: chi2=7.0127  , p=0.1352  , df=4
# parameter F test:         F=1.7453  , p=0.1376  , df_denom=1224, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.8318  , p=0.1038  , df_denom=1221, df_num=5
# ssr based chi2 test:   chi2=9.2413  , p=0.0998  , df=5
# likelihood ratio test: chi2=9.2068  , p=0.1011  , df=5
# parameter F test:         F=1.8318  , p=0.1038  , df_denom=1221, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.1321  , p=0.0472  , df_denom=1218, df_num=6
# ssr based chi2 test:   chi2=12.9292 , p=0.0442  , df=6
# likelihood ratio test: chi2=12.8618 , p=0.0453  , df=6
# parameter F test:         F=2.1321  , p=0.0472  , df_denom=1218, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.1056  , p=0.0403  , df_denom=1215, df_num=7
# ssr based chi2 test:   chi2=14.9210 , p=0.0370  , df=7
# likelihood ratio test: chi2=14.8312 , p=0.0382  , df=7
# parameter F test:         F=2.1056  , p=0.0403  , df_denom=1215, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.2507  , p=0.0219  , df_denom=1212, df_num=8
# ssr based chi2 test:   chi2=18.2584 , p=0.0194  , df=8
# likelihood ratio test: chi2=18.1241 , p=0.0203  , df=8
# parameter F test:         F=2.2507  , p=0.0219  , df_denom=1212, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.3816  , p=0.0114  , df_denom=1209, df_num=9
# ssr based chi2 test:   chi2=21.7709 , p=0.0096  , df=9
# likelihood ratio test: chi2=21.5801 , p=0.0103  , df=9
# parameter F test:         F=2.3816  , p=0.0114  , df_denom=1209, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.2556  , p=0.0131  , df_denom=1206, df_num=10
# ssr based chi2 test:   chi2=22.9487 , p=0.0109  , df=10
# likelihood ratio test: chi2=22.7367 , p=0.0118  , df=10
# parameter F test:         F=2.2556  , p=0.0131  , df_denom=1206, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.7104  , p=0.0170  , df_denom=1233, df_num=1
# ssr based chi2 test:   chi2=5.7243  , p=0.0167  , df=1
# likelihood ratio test: chi2=5.7111  , p=0.0169  , df=1
# parameter F test:         F=5.7104  , p=0.0170  , df_denom=1233, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.3633  , p=0.0349  , df_denom=1230, df_num=2
# ssr based chi2 test:   chi2=6.7540  , p=0.0341  , df=2
# likelihood ratio test: chi2=6.7356  , p=0.0345  , df=2
# parameter F test:         F=3.3633  , p=0.0349  , df_denom=1230, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.2321  , p=0.0828  , df_denom=1227, df_num=3
# ssr based chi2 test:   chi2=6.7344  , p=0.0809  , df=3
# likelihood ratio test: chi2=6.7161  , p=0.0815  , df=3
# parameter F test:         F=2.2321  , p=0.0828  , df_denom=1227, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.7181  , p=0.0285  , df_denom=1224, df_num=4
# ssr based chi2 test:   chi2=10.9523 , p=0.0271  , df=4
# likelihood ratio test: chi2=10.9039 , p=0.0277  , df=4
# parameter F test:         F=2.7181  , p=0.0285  , df_denom=1224, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.1803  , p=0.0541  , df_denom=1221, df_num=5
# ssr based chi2 test:   chi2=10.9999 , p=0.0514  , df=5
# likelihood ratio test: chi2=10.9511 , p=0.0524  , df=5
# parameter F test:         F=2.1803  , p=0.0541  , df_denom=1221, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.8187  , p=0.0921  , df_denom=1218, df_num=6
# ssr based chi2 test:   chi2=11.0286 , p=0.0875  , df=6
# likelihood ratio test: chi2=10.9795 , p=0.0890  , df=6
# parameter F test:         F=1.8187  , p=0.0921  , df_denom=1218, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.6849  , p=0.1087  , df_denom=1215, df_num=7
# ssr based chi2 test:   chi2=11.9400 , p=0.1025  , df=7
# likelihood ratio test: chi2=11.8824 , p=0.1045  , df=7
# parameter F test:         F=1.6849  , p=0.1087  , df_denom=1215, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.4904  , p=0.1560  , df_denom=1212, df_num=8
# ssr based chi2 test:   chi2=12.0905 , p=0.1472  , df=8
# likelihood ratio test: chi2=12.0314 , p=0.1498  , df=8
# parameter F test:         F=1.4904  , p=0.1560  , df_denom=1212, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.3661  , p=0.1986  , df_denom=1209, df_num=9
# ssr based chi2 test:   chi2=12.4883 , p=0.1872  , df=9
# likelihood ratio test: chi2=12.4252 , p=0.1904  , df=9
# parameter F test:         F=1.3661  , p=0.1986  , df_denom=1209, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.5732  , p=0.1091  , df_denom=1206, df_num=10
# ssr based chi2 test:   chi2=16.0061 , p=0.0995  , df=10
# likelihood ratio test: chi2=15.9026 , p=0.1025  , df=10
# parameter F test:         F=1.5732  , p=0.1091  , df_denom=1206, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.9229  , p=0.3369  , df_denom=1233, df_num=1
# ssr based chi2 test:   chi2=0.9252  , p=0.3361  , df=1
# likelihood ratio test: chi2=0.9248  , p=0.3362  , df=1
# parameter F test:         F=0.9229  , p=0.3369  , df_denom=1233, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.7658  , p=0.1715  , df_denom=1230, df_num=2
# ssr based chi2 test:   chi2=3.5459  , p=0.1698  , df=2
# likelihood ratio test: chi2=3.5408  , p=0.1703  , df=2
# parameter F test:         F=1.7658  , p=0.1715  , df_denom=1230, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.2816  , p=0.0776  , df_denom=1227, df_num=3
# ssr based chi2 test:   chi2=6.8840  , p=0.0757  , df=3
# likelihood ratio test: chi2=6.8649  , p=0.0763  , df=3
# parameter F test:         F=2.2816  , p=0.0776  , df_denom=1227, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.3812  , p=0.0498  , df_denom=1224, df_num=4
# ssr based chi2 test:   chi2=9.5949  , p=0.0478  , df=4
# likelihood ratio test: chi2=9.5578  , p=0.0486  , df=4
# parameter F test:         F=2.3812  , p=0.0498  , df_denom=1224, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.2208  , p=0.0068  , df_denom=1221, df_num=5
# ssr based chi2 test:   chi2=16.2493 , p=0.0062  , df=5
# likelihood ratio test: chi2=16.1431 , p=0.0064  , df=5
# parameter F test:         F=3.2208  , p=0.0068  , df_denom=1221, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=4.4832  , p=0.0002  , df_denom=1218, df_num=6
# ssr based chi2 test:   chi2=27.1861 , p=0.0001  , df=6
# likelihood ratio test: chi2=26.8902 , p=0.0002  , df=6
# parameter F test:         F=4.4832  , p=0.0002  , df_denom=1218, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=3.8923  , p=0.0003  , df_denom=1215, df_num=7
# ssr based chi2 test:   chi2=27.5827 , p=0.0003  , df=7
# likelihood ratio test: chi2=27.2780 , p=0.0003  , df=7
# parameter F test:         F=3.8923  , p=0.0003  , df_denom=1215, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=4.3276  , p=0.0000  , df_denom=1212, df_num=8
# ssr based chi2 test:   chi2=35.1067 , p=0.0000  , df=8
# likelihood ratio test: chi2=34.6146 , p=0.0000  , df=8
# parameter F test:         F=4.3276  , p=0.0000  , df_denom=1212, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.8378  , p=0.0001  , df_denom=1209, df_num=9
# ssr based chi2 test:   chi2=35.0831 , p=0.0001  , df=9
# likelihood ratio test: chi2=34.5913 , p=0.0001  , df=9
# parameter F test:         F=3.8378  , p=0.0001  , df_denom=1209, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.6615  , p=0.0001  , df_denom=1206, df_num=10
# ssr based chi2 test:   chi2=37.2527 , p=0.0001  , df=10
# likelihood ratio test: chi2=36.6984 , p=0.0001  , df=10
# parameter F test:         F=3.6615  , p=0.0001  , df_denom=1206, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=7.0049  , p=0.0082  , df_denom=1233, df_num=1
# ssr based chi2 test:   chi2=7.0220  , p=0.0081  , df=1
# likelihood ratio test: chi2=7.0021  , p=0.0081  , df=1
# parameter F test:         F=7.0049  , p=0.0082  , df_denom=1233, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.8107  , p=0.0224  , df_denom=1230, df_num=2
# ssr based chi2 test:   chi2=7.6524  , p=0.0218  , df=2
# likelihood ratio test: chi2=7.6287  , p=0.0221  , df=2
# parameter F test:         F=3.8107  , p=0.0224  , df_denom=1230, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.5498  , p=0.0543  , df_denom=1227, df_num=3
# ssr based chi2 test:   chi2=7.6929  , p=0.0528  , df=3
# likelihood ratio test: chi2=7.6690  , p=0.0534  , df=3
# parameter F test:         F=2.5498  , p=0.0543  , df_denom=1227, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.3774  , p=0.0502  , df_denom=1224, df_num=4
# ssr based chi2 test:   chi2=9.5794  , p=0.0481  , df=4
# likelihood ratio test: chi2=9.5423  , p=0.0489  , df=4
# parameter F test:         F=2.3774  , p=0.0502  , df_denom=1224, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.8923  , p=0.0929  , df_denom=1221, df_num=5
# ssr based chi2 test:   chi2=9.5466  , p=0.0891  , df=5
# likelihood ratio test: chi2=9.5098  , p=0.0904  , df=5
# parameter F test:         F=1.8923  , p=0.0929  , df_denom=1221, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.6737  , p=0.1239  , df_denom=1218, df_num=6
# ssr based chi2 test:   chi2=10.1497 , p=0.1185  , df=6
# likelihood ratio test: chi2=10.1081 , p=0.1202  , df=6
# parameter F test:         F=1.6737  , p=0.1239  , df_denom=1218, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.7803  , p=0.0874  , df_denom=1215, df_num=7
# ssr based chi2 test:   chi2=12.6159 , p=0.0820  , df=7
# likelihood ratio test: chi2=12.5516 , p=0.0838  , df=7
# parameter F test:         F=1.7803  , p=0.0874  , df_denom=1215, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.5446  , p=0.1373  , df_denom=1212, df_num=8
# ssr based chi2 test:   chi2=12.5301 , p=0.1291  , df=8
# likelihood ratio test: chi2=12.4666 , p=0.1316  , df=8
# parameter F test:         F=1.5446  , p=0.1373  , df_denom=1212, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.1365  , p=0.0241  , df_denom=1209, df_num=9
# ssr based chi2 test:   chi2=19.5306 , p=0.0210  , df=9
# likelihood ratio test: chi2=19.3769 , p=0.0222  , df=9
# parameter F test:         F=2.1365  , p=0.0241  , df_denom=1209, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.9777  , p=0.0324  , df_denom=1206, df_num=10
# ssr based chi2 test:   chi2=20.1214 , p=0.0281  , df=10
# likelihood ratio test: chi2=19.9582 , p=0.0297  , df=10
# parameter F test:         F=1.9777  , p=0.0324  , df_denom=1206, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=1233, df_num=1
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=1
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=1
# parameter F test:         F=1.6216  , p=0.2031  , df_denom=1233, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=1232, df_num=2
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=2
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=2
# parameter F test:         F=0.8440  , p=0.4302  , df_denom=1232, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=-0.0307 , p=1.0000  , df_denom=1230, df_num=3
# ssr based chi2 test:   chi2=-0.0924 , p=1.0000  , df=3
# likelihood ratio test: chi2=-0.0924 , p=1.0000  , df=3
# parameter F test:         F=0.0301  , p=0.8624  , df_denom=1230, df_num=1
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=1228, df_num=4
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=4
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=4
# parameter F test:         F=0.5409  , p=0.7058  , df_denom=1228, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=-0.0082 , p=1.0000  , df_denom=1226, df_num=5
# ssr based chi2 test:   chi2=-0.0413 , p=1.0000  , df=5
# likelihood ratio test: chi2=-0.0413 , p=1.0000  , df=5
# parameter F test:         F=0.0298  , p=0.8630  , df_denom=1226, df_num=1
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=-0.0000 , p=1.0000  , df_denom=1224, df_num=6
# ssr based chi2 test:   chi2=-0.0000 , p=1.0000  , df=6
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=6
# parameter F test:         F=0.4417  , p=0.8511  , df_denom=1224, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=-0.0097 , p=1.0000  , df_denom=1222, df_num=7
# ssr based chi2 test:   chi2=-0.0681 , p=1.0000  , df=7
# likelihood ratio test: chi2=-0.0681 , p=1.0000  , df=7
# parameter F test:         F=0.0649  , p=0.7990  , df_denom=1222, df_num=1
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=-0.0011 , p=1.0000  , df_denom=1220, df_num=8
# ssr based chi2 test:   chi2=-0.0087 , p=1.0000  , df=8
# likelihood ratio test: chi2=-0.0087 , p=1.0000  , df=8
# parameter F test:         F=0.0043  , p=0.9476  , df_denom=1220, df_num=1
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=-0.0000 , p=1.0000  , df_denom=1218, df_num=9
# ssr based chi2 test:   chi2=-0.0000 , p=1.0000  , df=9
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=9
# parameter F test:         F=1.3921  , p=0.1865  , df_denom=1218, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.0000  , p=1.0000  , df_denom=1216, df_num=10
# ssr based chi2 test:   chi2=0.0000  , p=1.0000  , df=10
# likelihood ratio test: chi2=-0.0000 , p=1.0000  , df=10
# parameter F test:         F=1.3362  , p=0.2056  , df_denom=1216, df_num=10
# C:\Users\teres\anaconda3\envs\equity_vs_commodity\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 3, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\teres\anaconda3\envs\equity_vs_commodity\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 5, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\teres\anaconda3\envs\equity_vs_commodity\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 7, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\teres\anaconda3\envs\equity_vs_commodity\Lib\site-packages\statsmodels\base\model.py:1894: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 8, but rank is 1
#   warnings.warn('covariance of constraints does not have full '

# %%
GC_stock
# Out:
# ['CADUSD=X_change_in_price',
#  'GM_change_in_price',
#  'JCI_change_in_price',
#  'TM_change_in_price',
#  'TRYUSD=X_change_in_price',
#  '^IXIC_change_in_price']

# %%
optimal_lag
# Out:
# [np.int64(8), np.int64(4), np.int64(9), np.int64(1), np.int64(8), np.int64(1)]

# %% [markdown]
# ## ALV_change_in_price Granger-Causes DNZOY_change_in_price

# %%
fig, ax = plt.subplots(2, figsize = (15, 10))

ax[0].plot(df_change['F_change_in_price'])
ax[1].plot(df_change['CADUSD=X_change_in_price'])
ax[0].set_ylabel('Ford')
ax[1].set_ylabel('CADUSD')
fig.supxlabel('Time')
plt.show()

# %%
plt.figure(figsize = (15, 10))
sns.scatterplot(data = df_change, x = 'CADUSD=X_change_in_price', y = 'F_change_in_price')
plt.show()

# %%
df_change_CADUSD = df_change[['F_change_in_price', 'CADUSD=X_change_in_price']].copy()

# %%
df_change_CADUSD
# Out:
#       F_change_in_price  CADUSD=X_change_in_price
# 0              0.010000                 -0.000418
# 1              0.090000                  0.001932
# 2             -0.040000                 -0.000607
# 3             -0.050000                 -0.000238
# 4             -0.120000                 -0.001081
# ...                 ...                       ...
# 1232           0.230000                 -0.001776
# 1233          -0.049999                  0.000905
# 1234           0.179999                 -0.001072
# 1235          -0.170000                 -0.000866
# 1236           0.300000                 -0.002197
#
# [1237 rows x 2 columns]

# %%
forecast_length = 5

train_ALV = df_change_ALV.iloc[:-forecast_length]
test_ALV = df_change_ALV.iloc[-forecast_length:]

model_ALV = VAR(train_ALV)
sorted_order_ALV = model_ALV.select_order(maxlags = 10)
sorted_order_ALV.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
var_model_ALV = model_ALV.fit(10)
forecast_var_ALV = pd.DataFrame(var_model_ALV.forecast(train_ALV.values, 
                                              steps=forecast_length), 
                           columns=train_ALV.columns, 
                           index=test_ALV.index)
forecast_var_ALV = pd.concat([forecast_var_ALV['DNZOY_change_in_price'], test_ALV['DNZOY_change_in_price']], axis = 1)

# %%
forecast_var_ALV.columns = ['DNZOY Prediction','DNZOY True Value']
forecast_var_ALV
# Out:
#       DNZOY Prediction  DNZOY True Value
# 1232          0.056695          0.160000
# 1233          0.016759         -0.160000
# 1234          0.042466         -0.099999
# 1235         -0.013659          0.160000
# 1236          0.016398         -0.030000

# %% [markdown]
# ## F_change_in_price Granger-Causes DNZOY_change_in_price

# %%
fig, ax = plt.subplots(2, figsize = (15, 10))

ax[0].plot(df_change['DNZOY_change_in_price'])
ax[1].plot(df_change['F_change_in_price'])
ax[0].set_ylabel('DNZOY')
ax[1].set_ylabel('F')
fig.supxlabel('Time')
plt.show()

# %%
plt.figure(figsize = (15, 10))
sns.scatterplot(data = df_change, x = 'F_change_in_price', y = 'DNZOY_change_in_price')
# Out:
# <Axes: xlabel='F_change_in_price', ylabel='DNZOY_change_in_price'>

# %%
df_change_F = df_change[['DNZOY_change_in_price', 'F_change_in_price']].copy()
train_F = df_change_F.iloc[:-forecast_length]
test_F = df_change_F.iloc[-forecast_length:]

model_F = VAR(train_F)
sorted_order_F = model_F.select_order(maxlags = 10)
sorted_order_F.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
var_model_F = model_F.fit(10)
forecast_var_F = pd.DataFrame(var_model_F.forecast(train_F.values, 
                                              steps=forecast_length), 
                           columns=train_F.columns, 
                           index=test_F.index)
forecast_var_F = pd.concat([forecast_var_F['DNZOY_change_in_price'], test_F['DNZOY_change_in_price']], axis = 1)
forecast_var_F.columns = ['DNZOY Prediction', 'DNZOY True Value']
forecast_var_F
# Out:
#       DNZOY Prediction  DNZOY True Value
# 1232          0.036772          0.160000
# 1233          0.027656         -0.160000
# 1234          0.013695         -0.099999
# 1235          0.024676          0.160000
# 1236         -0.016338         -0.030000

# %% [markdown]
# ## GM_change_in_price Granger-Causes DNZOY_change_in_price

# %%
fig, ax = plt.subplots(2, figsize = (15, 10))

ax[0].plot(df_change['DNZOY_change_in_price'])
ax[1].plot(df_change['GM_change_in_price'])
ax[0].set_ylabel('DNZOY')
ax[1].set_ylabel('GM')
fig.supxlabel('Time')
plt.show()

# %%
plt.figure(figsize = (15, 10))
sns.scatterplot(data = df_change, x = 'GM_change_in_price', y = 'DNZOY_change_in_price')
# Out:
# <Axes: xlabel='GM_change_in_price', ylabel='DNZOY_change_in_price'>

# %%
df_change_GM = df_change[['DNZOY_change_in_price', 'GM_change_in_price']].copy()
train_GM = df_change_GM.iloc[:-forecast_length]
test_GM = df_change_GM.iloc[-forecast_length:]

model_GM = VAR(train_GM)
sorted_order_GM = model_GM.select_order(maxlags = 10)
sorted_order_GM.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
var_model_GM = model_GM.fit(10)
forecast_var_GM = pd.DataFrame(var_model_GM.forecast(train_GM.values, 
                                              steps=forecast_length), 
                           columns=train_GM.columns, 
                           index=test_GM.index)
forecast_var_GM = pd.concat([forecast_var_GM['DNZOY_change_in_price'], test_GM['DNZOY_change_in_price']], axis = 1)
forecast_var_GM.columns = ['DNZOY Prediction', 'DNZOY True Value']
forecast_var_GM
# Out:
#       DNZOY Prediction  DNZOY True Value
# 1232          0.068524          0.160000
# 1233          0.002103         -0.160000
# 1234          0.031583         -0.099999
# 1235          0.018955          0.160000
# 1236         -0.047565         -0.030000

# %% [markdown]
# ## TM_change_in_price Granger-Causes DNZOY_change_in_price

# %%
fig, ax = plt.subplots(2, figsize = (15, 10))

ax[0].plot(df_change['DNZOY_change_in_price'])
ax[1].plot(df_change['TM_change_in_price'])
ax[0].set_ylabel('DNZOY')
ax[1].set_ylabel('TM')
fig.supxlabel('Time')
plt.show()

# %%
plt.figure(figsize = (15, 10))
sns.scatterplot(data = df_change, x = 'TM_change_in_price', y = 'DNZOY_change_in_price')
# Out:
# <Axes: xlabel='TM_change_in_price', ylabel='DNZOY_change_in_price'>

# %%
df_change_TM = df_change[['DNZOY_change_in_price', 'TM_change_in_price']].copy()
train_TM = df_change_TM.iloc[:-forecast_length]
test_TM = df_change_TM.iloc[-forecast_length:]

model_TM = VAR(train_TM)
sorted_order_TM = model_TM.select_order(maxlags = 10)
sorted_order_TM.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
var_model_TM = model_TM.fit(10)
forecast_var_TM = pd.DataFrame(var_model_TM.forecast(train_TM.values, 
                                              steps=forecast_length), 
                           columns=train_TM.columns, 
                           index=test_TM.index)
forecast_var_TM = pd.concat([forecast_var_TM['DNZOY_change_in_price'], test_TM['DNZOY_change_in_price']], axis = 1)
forecast_var_TM.columns = ['DNZOY Prediction', 'DNZOY True Value']
forecast_var_TM
# Out:
#       DNZOY Prediction  DNZOY True Value
# 1232          0.049654          0.160000
# 1233          0.008744         -0.160000
# 1234          0.001352         -0.099999
# 1235          0.024368          0.160000
# 1236         -0.047301         -0.030000

# %% [markdown]
# ## TRYUSD_change_in_price Granger-Causes DNZOY_change_in_price

# %%
fig, ax = plt.subplots(2, figsize = (15, 10))

ax[0].plot(df_change['DNZOY_change_in_price'])
ax[1].plot(df_change['TRYUSD=X_change_in_price'])
ax[0].set_ylabel('DNZOY')
ax[1].set_ylabel('TRYUSD')
fig.supxlabel('Time')
plt.show()

# %%
plt.figure(figsize = (15, 10))
sns.scatterplot(data = df_change, x = 'TRYUSD=X_change_in_price', y = 'DNZOY_change_in_price')
# Out:
# <Axes: xlabel='TRYUSD=X_change_in_price', ylabel='DNZOY_change_in_price'>

# %%
df_change_TRYUSD = df_change[['DNZOY_change_in_price', 'TRYUSD=X_change_in_price']].copy()
train_TRYUSD = df_change_TRYUSD.iloc[:-forecast_length]
test_TRYUSD = df_change_TRYUSD.iloc[-forecast_length:]

model_TRYUSD = VAR(train_TRYUSD)
sorted_order_TRYUSD = model_TRYUSD.select_order(maxlags = 10)
sorted_order_TRYUSD.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
var_model_TRYUSD = model_TRYUSD.fit(10)
forecast_var_TRYUSD = pd.DataFrame(var_model_TRYUSD.forecast(train_TRYUSD.values, 
                                              steps=forecast_length), 
                           columns=train_TRYUSD.columns, 
                           index=test_TRYUSD.index)
forecast_var_TRYUSD = pd.concat([forecast_var_TRYUSD['DNZOY_change_in_price'], test_TRYUSD['DNZOY_change_in_price']], axis = 1)
forecast_var_TRYUSD.columns = ['DNZOY Prediction', 'DNZOY True Value']
forecast_var_TRYUSD
# Out:
#       DNZOY Prediction  DNZOY True Value
# 1232          0.004050          0.160000
# 1233          0.004043         -0.160000
# 1234         -0.001499         -0.099999
# 1235          0.007029          0.160000
# 1236         -0.013277         -0.030000

# %% [markdown]
# ## WFC_change_in_price Granger-Causes DNZOY_change_in_price

# %%
fig, ax = plt.subplots(2, figsize = (15, 10))

ax[0].plot(df_change['DNZOY_change_in_price'])
ax[1].plot(df_change['WFC_change_in_price'])
ax[0].set_ylabel('DNZOY')
ax[1].set_ylabel('WFC')
fig.supxlabel('Time')
plt.show()

# %%
plt.figure(figsize = (15, 10))
sns.scatterplot(data = df_change, x = 'WFC_change_in_price', y = 'DNZOY_change_in_price')
# Out:
# <Axes: xlabel='WFC_change_in_price', ylabel='DNZOY_change_in_price'>

# %%
df_change_WFC = df_change[['DNZOY_change_in_price', 'WFC_change_in_price']].copy()
train_WFC = df_change_WFC.iloc[:-forecast_length]
test_WFC = df_change_WFC.iloc[-forecast_length:]

model_WFC = VAR(train_WFC)
sorted_order_WFC = model_WFC.select_order(maxlags = 10)
sorted_order_WFC.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
var_model_WFC = model_WFC.fit(10)
forecast_var_WFC = pd.DataFrame(var_model_WFC.forecast(train_WFC.values, 
                                              steps=forecast_length), 
                           columns=train_WFC.columns, 
                           index=test_WFC.index)
forecast_var_WFC = pd.concat([forecast_var_WFC['DNZOY_change_in_price'], test_WFC['DNZOY_change_in_price']], axis = 1)
forecast_var_WFC.columns = ['DNZOY Prediction', 'DNZOY True Value']
forecast_var_WFC
# Out:
#       DNZOY Prediction  DNZOY True Value
# 1232          0.065864          0.160000
# 1233          0.004821         -0.160000
# 1234          0.026625         -0.099999
# 1235          0.018778          0.160000
# 1236          0.015252         -0.030000

# %% [markdown]
# ## ALI=F_change_in_price Granger-Causes DNZOY_change_in_price

# %%
fig, ax = plt.subplots(2, figsize = (15, 10))

ax[0].plot(df_change['DNZOY_change_in_price'])
ax[1].plot(df_change['ALI=F_change_in_price'])
ax[0].set_ylabel('DNZOY')
ax[1].set_ylabel('ALI=F')
fig.supxlabel('Time')
plt.show()

# %%
plt.figure(figsize = (15, 10))
sns.scatterplot(data = df_change, x = 'ALI=F_change_in_price', y = 'DNZOY_change_in_price')
# Out:
# <Axes: xlabel='ALI=F_change_in_price', ylabel='DNZOY_change_in_price'>

# %%
df_change_ALI = df_change[['DNZOY_change_in_price', 'ALI=F_change_in_price']].copy()
train_ALI = df_change_ALI.iloc[:-forecast_length]
test_ALI = df_change_ALI.iloc[-forecast_length:]

model_ALI = VAR(train_ALI)
sorted_order_ALI = model_ALI.select_order(maxlags = 10)
sorted_order_ALI.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
var_model_ALI = model_ALI.fit(10)
forecast_var_ALI = pd.DataFrame(var_model_ALI.forecast(train_ALI.values, 
                                              steps=forecast_length), 
                           columns=train_ALI.columns, 
                           index=test_ALI.index)
forecast_var_ALI = pd.concat([forecast_var_ALI['DNZOY_change_in_price'], test_ALI['DNZOY_change_in_price']], axis = 1)
forecast_var_ALI.columns = ['DNZOY Prediction', 'DNZOY True Value']
forecast_var_ALI
# Out:
#       DNZOY Prediction  DNZOY True Value
# 1232          0.013710          0.160000
# 1233         -0.059531         -0.160000
# 1234          0.020670         -0.099999
# 1235          0.047824          0.160000
# 1236         -0.014115         -0.030000

# %%
acc = sum(forecast_var_ALI['DNZOY Prediction']*forecast_var_ALI['DNZOY True Value'] > 0)/forecast_length

# %%
acc
# Out:
# 0.8

# %% [markdown]
# ## Train_test_split

# %%
train = df_change_ALI.iloc[:-forecast_length]
test = df_change_ALI.iloc[-forecast_length:]

# %%
cv = TimeSeriesSplit(10, test_size=forecast_length)
MSE = np.zeros(9)

for train_index, test_index in cv.split(train):
    t_tt = train.iloc[train_index]
    t_ho = train.iloc[test_index]
    model = VAR(t_tt)
    for i in range(1, 10):
        var_model = model.fit(i)
        pred = var_model.forecast(t_tt.values, steps=forecast_length)
        MSE[i - 1] = np.sqrt(mean_squared_error(t_ho['DNZOY_change_in_price'].values, pred[:, 0]))

order_optimal = np.argmin(MSE) + 1

# %% [markdown]
# ## Apply the order optimal to the test set

# %%
model_best = VAR(train)
var_model_best = model_best.fit(order_optimal)
pred_best = var_model_best.forecast(train.values, steps=forecast_length)
pred_best
# Out:
# array([[-1.41095318e-02,  5.46670055e-02],
#        [-1.77661485e-02, -9.70503572e+00],
#        [ 1.90062738e-02,  1.16244327e+00],
#        [ 1.20873880e-02, -2.03659967e+00],
#        [-2.54750330e-03, -8.68384629e-01]])

# %%
test
# Out:
#       DNZOY_change_in_price  ALI=F_change_in_price
# 1232               0.160000                  62.50
# 1233              -0.160000                 -24.75
# 1234              -0.099999                  33.00
# 1235               0.160000                  37.75
# 1236              -0.030000                 -15.00

# %%
np.sqrt(mean_squared_error(t_ho['DNZOY_change_in_price'].values, pred[:, 0]))
# Out:
# np.float64(0.24363409660613103)

# %%
pred
# Out:
# array([[-1.47189658e-02,  1.83605460e+00],
#        [-4.65620775e-02,  9.23430606e-01],
#        [ 4.88462135e-02, -2.26719135e+01],
#        [-5.37152066e-02, -6.43984447e-01],
#        [ 3.54691889e-02,  7.68526420e+00]])

# %%
sum(pred_best[:, 0]*test.loc[:,'DNZOY_change_in_price'] > 0)/forecast_length
# Out:
# 0.6

# %%
MSE
# Out:
# array([0.2422987 , 0.24224633, 0.24257524, 0.24220301, 0.24219753,
#        0.23588533, 0.23997185, 0.23945841, 0.2436341 ])

# %%
np.argmin(MSE)
# Out:
# np.int64(5)

# %%
pred[:, 0]
# Out:
# array([-0.01471897, -0.04656208,  0.04884621, -0.05371521,  0.03546919])

# %%
t_ho
# Out:
#       DNZOY_change_in_price  ALI=F_change_in_price
# 1227              -0.020000                  49.00
# 1228               0.020000                 -36.00
# 1229              -0.500000                 -18.25
# 1230               0.060000                   9.75
# 1231              -0.190001                 -21.50
