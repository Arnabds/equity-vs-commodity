# %% [markdown]
# # Read congressional data

# %%
import pandas as pd
import numpy as np

# %%
# Read SenatorCleaned.csv

df_senate = pd.read_csv('../Data/SenatorCleaned.csv')

# %%
df_senate
# Out:
#        Unnamed: 0                 Name Transaction.Date   Owner Ticker  \
# 0               1   Sheldon Whitehouse       11/25/2014    Self      M
# 1               2   Sheldon Whitehouse       12/18/2014    Self   BEAV
# 2               3   Sheldon Whitehouse       12/18/2014    Self   KORS
# 3               4   Sheldon Whitehouse       12/18/2014    Self      T
# 4               5   Sheldon Whitehouse       12/18/2014    Self   KEYS
# ...           ...                  ...              ...     ...    ...
# 15661       15662      Lamar Alexander        5/31/2019  Spouse     --
# 15662       15663      Lamar Alexander         4/1/2016  Spouse     --
# 15663       15664      Lamar Alexander         9/6/2017  Spouse     --
# 15664       15665      Lamar Alexander         9/7/2017  Spouse     --
# 15665       15666      Lamar Alexander        9/13/2017  Spouse     --
#
#                                               Asset.Name          Asset.Type  \
# 0                                    Macy's, Inc. (NYSE)               Stock
# 1                            B/E Aerospace Inc. (NASDAQ)               Stock
# 2                   Michael Kors Holdings Limited (NYSE)               Stock
# 3                                      AT&T, Inc. (NYSE)               Stock
# 4                     Keysight Technologies, Inc. (NYSE)               Stock
# ...                                                  ...                 ...
# 15661  Little Star Partnership\r\nCompany: Little Sta...    Other Securities
# 15662  Montgomery County\r\nRate/Coupon: 5.00\r\nMatu...  Municipal Security
# 15663  Sevier County Tenn Pub Bldg\r\nRate/Coupon: 5....  Municipal Security
# 15664  Wilson County Tenn GO\r\nRate/Coupon: 5.00%\r\...  Municipal Security
# 15665  Metropolitan Govt Nashville Water and Sewer\r\...  Municipal Security
#
#                  Type    Amount  \
# 0            Purchase    1001.0
# 1         Sale (Full)   15001.0
# 2      Sale (Partial)    1001.0
# 3            Purchase    1001.0
# 4         Sale (Full)    1001.0
# ...               ...       ...
# 15661        Purchase  100001.0
# 15662     Sale (Full)   15001.0
# 15663        Purchase   50001.0
# 15664        Purchase   50001.0
# 15665        Purchase   15001.0
#
#                                                  Comment
# 0                                                     --
# 1                                                     --
# 2                                                     --
# 3                                                     --
# 4      Agilent Tech common stock completed a spinoff ...
# ...                                                  ...
# 15661  Little Star Partnership is a family Company ow...
# 15662                                                 --
# 15663                                                 --
# 15664                                                 --
# 15665                                                 --
#
# [15666 rows x 10 columns]

# %%
# stock_prices_2023_to_now
df_stock_price = pd.read_csv('../Data/stock_prices_2023_to_now.csv')

# %%
df_stock_price
# Out:
#               Date Ticker       Close
# 0       2023-01-03  AAGIY   45.799999
# 1       2023-01-03    AAP  151.539993
# 2       2023-01-03   AAPL  125.070000
# 3       2023-01-03   ABBV  162.380005
# 4       2023-01-03   ABNB   84.900002
# ...            ...    ...         ...
# 187121  2024-07-17      X   38.139999
# 187122  2024-07-17  XNGSY   30.719999
# 187123  2024-07-17    XOM  117.639999
# 187124  2024-07-17      Z   52.720001
# 187125  2024-07-17    ZTS  182.050003
#
# [187126 rows x 3 columns]

# %%
# congress-trading-all
df_congress = pd.read_csv('../Data/congress-trading-all.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[11], line 2
#       1 # congress-trading-all
# ----> 2 df_congress = pd.read_csv('../Data/congress-trading-all.csv')
#
# File ~\anaconda3\envs\equity_vs_commodity\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\envs\equity_vs_commodity\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~\anaconda3\envs\equity_vs_commodity\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~\anaconda3\envs\equity_vs_commodity\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File ~\anaconda3\envs\equity_vs_commodity\Lib\codecs.py:322, in BufferedIncrementalDecoder.decode(self, input, final)
#     319 def decode(self, input, final=False):
#     320     # decode input (taking the buffer into account)
#     321     data = self.buffer + input
# --> 322     (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323     # keep undecoded input until the next call
#     324     self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa3 in position 209833: invalid start byte
